# %% [markdown]
# <p style="font-size:18px; font-weight:bold;"> 2025 Olivia Debnath</p>
# <p style="font-size:14px;">Dana-Farber Cancer Institute & Harvard Medical School</p>

# %% [markdown]
# **Hypothesis 2 (H₂): Facilitated co-expression & functional dependence**
#
# If a lowly expressed gene (POI: Protein of Interest) maintains stable but widespread co-expression (≥10%) with multiple interactors across diverse cell types, its function is cellularly indispensable despite its low abundance.
#
# 🔹 Why this hypothesis?
# Some genes are not highly expressed, but they are still critical for cellular homeostasis and operate in a facilitated interaction manner, where multiple weakly co-expressed partners compensate for expression variability.
#
# For example:
#
# MLH1 (MutL Homolog 1) is a key DNA mismatch repair (MMR) gene but does not show strong expression peaks in any single cell type.
# Instead, MLH1 and its partners (e.g., PMS2, MSH2, MSH6) maintain steady but weak co-expression across multiple proliferating cell states—suggesting functional compensation rather than strong enrichment.
#
# Technical pipeline (adjusted based on previous exploratory analyses):
#
# If a lowly expressed POI (≤ Median% expression across clusters in a tissue) is consistently co-expressed with one or more interactors (≥30%), it remains functionally relevant, as its interactors might compensate for its deficiency. We can reduce the cut-off to 20% for now to pick up a few more cases for MLH1.
#
# Certain genes—like MLH1 (Mismatch Repair)— are weakly expressed (often <10% across most clusters or even <5%) but still cell-essential due to their role in highly conserved pathways. Instead of relying on strong co-expression (Hypothesis 1), these genes depend on their highly expressed interactors to maintain functionality.
#
# 🔍 H₂ filtering strategy:
#
# 1. POI expression threshold:
#
# - Identify cases where POI expression ≥ median % expression of the gene across clusters within the same tissue (adaptive thresholding).
# - This allows the detection of functional low-expression genes while ignoring highly abundant ones.
#
# 2. Interactor rescue requirements:
#
# - At least one interactor must be expressed at ≥30% in the same cell type/state.
# - If multiple interactors are highly expressed, it strengthens the functional dependence hypothesis.
#
#
# 3. Rescue strength annotation: (new column: "Rescue Category")
#
#     - Weak Rescue (10-30%) → Interaction present, but not strong.
#     - Moderate Rescue (30-50%) → Likely functionally relevant.
#     - High Rescue (50-80%) → Strong compensatory effect.
#     - Robust Rescue (80-100%) → Near-total functional compensation.

# %%
import os
print(os.path.exists("./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/"))
# Out:
# True

# %%
#Define input directory: 
input_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/"  

#Dynamically find all relevant input files
input_files = sorted([f for f in os.listdir(input_dir) if f.endswith("_filtered_S0_17042025.csv")]) 
print(input_files) 

#Print total count of files
print(f"\n✅ Total Input Files Found: {len(input_files)}")
# Out:
# ['ACSF3_PPI_filtered_S0_17042025.csv', 'ACTB_PPI_filtered_S0_17042025.csv', 'ACY1_PPI_filtered_S0_17042025.csv', 'ADIPOQ_PPI_filtered_S0_17042025.csv', 'AGXT_PPI_filtered_S0_17042025.csv', 'AHCY_PPI_filtered_S0_17042025.csv', 'AIPL1_PPI_filtered_S0_17042025.csv', 'ALAS2_PPI_filtered_S0_17042025.csv', 'ALDOA_PPI_filtered_S0_17042025.csv', 'ALOX5_PPI_filtered_S0_17042025.csv', 'AMPD2_PPI_filtered_S0_17042025.csv', 'ANKRD1_PPI_filtered_S0_17042025.csv', 'ANXA11_PPI_filtered_S0_17042025.csv', 'AP2S1_PPI_filtered_S0_17042025.csv', 'APOA1_PPI_filtered_S0_17042025.csv', 'APOD_PPI_filtered_S0_17042025.csv', 'ASNS_PPI_filtered_S0_17042025.csv', 'ATPAF2_PPI_filtered_S0_17042025.csv', 'BAG3_PPI_filtered_S0_17042025.csv', 'BANF1_PPI_filtered_S0_17042025.csv', 'BCL10_PPI_filtered_S0_17042025.csv', 'BFSP2_PPI_filtered_S0_17042025.csv', 'BLK_PPI_filtered_S0_17042025.csv', 'C1QA_PPI_filtered_S0_17042025.csv', 'C1QB_PPI_filtered_S0_17042025.csv', 'C1QC_PPI_filtered_S0_17042025.csv', 'CA8_PPI_filtered_S0_17042025.csv', 'CACNB4_PPI_filtered_S0_17042025.csv', 'CCBE1_PPI_filtered_S0_17042025.csv', 'CCDC103_PPI_filtered_S0_17042025.csv', 'CD151_PPI_filtered_S0_17042025.csv', 'CDA_PPI_filtered_S0_17042025.csv', 'CDC73_PPI_filtered_S0_17042025.csv', 'CDK4_PPI_filtered_S0_17042025.csv', 'CDKN1A_PPI_filtered_S0_17042025.csv', 'CDKN2C_PPI_filtered_S0_17042025.csv', 'CFP_PPI_filtered_S0_17042025.csv', 'CHN1_PPI_filtered_S0_17042025.csv', 'CHRNG_PPI_filtered_S0_17042025.csv', 'CLCNKA_PPI_filtered_S0_17042025.csv', 'CLDN19_PPI_filtered_S0_17042025.csv', 'CLN6_PPI_filtered_S0_17042025.csv', 'COL10A1_PPI_filtered_S0_17042025.csv', 'COL2A1_PPI_filtered_S0_17042025.csv', 'COMP_PPI_filtered_S0_17042025.csv', 'COQ8A_PPI_filtered_S0_17042025.csv', 'CRADD_PPI_filtered_S0_17042025.csv', 'CREB1_PPI_filtered_S0_17042025.csv', 'CRYAA_PPI_filtered_S0_17042025.csv', 'CRYAB_PPI_filtered_S0_17042025.csv', 'CRYBB1_PPI_filtered_S0_17042025.csv', 'CSNK1D_PPI_filtered_S0_17042025.csv', 'CSNK1E_PPI_filtered_S0_17042025.csv', 'CTH_PPI_filtered_S0_17042025.csv', 'CTNNA3_PPI_filtered_S0_17042025.csv', 'CUL3_PPI_filtered_S0_17042025.csv', 'CXCL16_PPI_filtered_S0_17042025.csv', 'CYP4F12_PPI_filtered_S0_17042025.csv', 'DCX_PPI_filtered_S0_17042025.csv', 'DDX20_PPI_filtered_S0_17042025.csv', 'DIABLO_PPI_filtered_S0_17042025.csv', 'DMC1_PPI_filtered_S0_17042025.csv', 'DOLK_PPI_filtered_S0_17042025.csv', 'DUSP23_PPI_filtered_S0_17042025.csv', 'EFEMP1_PPI_filtered_S0_17042025.csv', 'EFHC1_PPI_filtered_S0_17042025.csv', 'EIF2B1_PPI_filtered_S0_17042025.csv', 'EIF2B4_PPI_filtered_S0_17042025.csv', 'EMD_PPI_filtered_S0_17042025.csv', 'ESR2_PPI_filtered_S0_17042025.csv', 'EXOC8_PPI_filtered_S0_17042025.csv', 'EZH2_PPI_filtered_S0_17042025.csv', 'FA2H_PPI_filtered_S0_17042025.csv', 'FADD_PPI_filtered_S0_17042025.csv', 'FAM161A_PPI_filtered_S0_17042025.csv', 'FAM187A_PPI_filtered_S0_17042025.csv', 'FASLG_PPI_filtered_S0_17042025.csv', 'FBP1_PPI_filtered_S0_17042025.csv', 'FGD4_PPI_filtered_S0_17042025.csv', 'FKBP6_PPI_filtered_S0_17042025.csv', 'FOXD4_PPI_filtered_S0_17042025.csv', 'FOXP3_PPI_filtered_S0_17042025.csv', 'FTH1_PPI_filtered_S0_17042025.csv', 'FUCA1_PPI_filtered_S0_17042025.csv', 'GAD1_PPI_filtered_S0_17042025.csv', 'GALE_PPI_filtered_S0_17042025.csv', 'GALT_PPI_filtered_S0_17042025.csv', 'GATA2_PPI_filtered_S0_17042025.csv', 'GCK_PPI_filtered_S0_17042025.csv', 'GCM2_PPI_filtered_S0_17042025.csv', 'GFAP_PPI_filtered_S0_17042025.csv', 'GLYCTK_PPI_filtered_S0_17042025.csv', 'GMPPB_PPI_filtered_S0_17042025.csv', 'GNAI3_PPI_filtered_S0_17042025.csv', 'GNE_PPI_filtered_S0_17042025.csv', 'GOSR2_PPI_filtered_S0_17042025.csv', 'GRN_PPI_filtered_S0_17042025.csv', 'GSS_PPI_filtered_S0_17042025.csv', 'GSTA2_PPI_filtered_S0_17042025.csv', 'GSTZ1_PPI_filtered_S0_17042025.csv', 'GYG1_PPI_filtered_S0_17042025.csv', 'GYPA_PPI_filtered_S0_17042025.csv', 'HBD_PPI_filtered_S0_17042025.csv', 'HCFC1_PPI_filtered_S0_17042025.csv', 'HGD_PPI_filtered_S0_17042025.csv', 'HMBS_PPI_filtered_S0_17042025.csv' ...
#
# ✅ Total Input Files Found: 242

# %%
#Specify output directory: 
output_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/"
os.makedirs(output_dir, exist_ok=True)  #Ensure output directory exists

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1). POI expression cutoff: - POI must be ≥ median expression % (across clusters in that tissue). - We use the tissue-specific median rather than a fixed 30% cutoff, because some genes (e.g., MLH1) have consistently low but functional expression.
#
# 2). Interactor expression cutoff: - At least one interactor must be ≥20% expression (instead of the 30% threshold used in H₁).

# %%
#Applied code from PPI_CellxGene_H2_corr_27022025.ipynb on all PPI cases: 

#**Define Expression Cutoffs for H₂**
WEAK_COMPENSATION = 20   #At least 20% interactor expression
MODERATE_COMPENSATION = 30  #At least 30% interactor expression
STRONG_COMPENSATION = 50  #At least 50% interactor expression

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
import matplotlib.pyplot as plt

# %% [markdown]
# We need to remove cases where both the POI & the interactor are ≥30% expression to prevent redundancy with H3 (strong co-expression & functional disruption). However, if the POI is ≥30% but the interactor is <30%, we still keep those cases.

# %%
def process_H2_file(df, protein_of_interest):
    """ 
    Filters for H₂: Facilitated Co-Operation
    - POI must be expressed at least at the **median expression %** (within its tissue).
    - At least one interactor must be highly expressed (≥20%) in the same cell type.
    - **POI expression is explicitly retained & displayed.**
    """

    print(f"\n🔍STEP-1: Computing tissue median expression for {protein_of_interest}...")

    #Step-1: Compute POI-Specific Median Expression Cutoff
    #Computes median expression % of POI across all cell types in each tissue
    #If POI is absent in a tissue, it won't be processed
    tissue_median_expr = df[df["Gene Symbol"] == protein_of_interest].groupby("Tissue")["%Cells Expressing Gene"].median()

    if tissue_median_expr.empty:
        print(f"⚠️WARNING: {protein_of_interest} does not meet median expression in any tissue. Skipping file.")
        return None

    print(f"📊Tissue-specific median expression for {protein_of_interest}:\n{tissue_median_expr}\n")

    #Merge computed tissue-specific median expression into df for reference
    df = df.merge(tissue_median_expr.rename("Tissue_Median_Exp"), on="Tissue", how="left")

    #Explicitly store POI expression per cell type
    #This ensures that even after filtering, POI expression remains in output
    poi_expression_dict = df[df["Gene Symbol"] == protein_of_interest].set_index(["Tissue", "Cell Type"])["%Cells Expressing Gene"].to_dict()
    df["POI_Expression_%"] = df.apply(lambda row: poi_expression_dict.get((row["Tissue"], row["Cell Type"]), np.nan), axis=1)

    #Ensure POI_Above_Median is explicitly written (True/False instead of NaN)
    # - If POI expression in a cell type is ≥ tissue median, it's marked as True
    df["POI_Above_Median"] = df["POI_Expression_%"] >= df["Tissue_Median_Exp"]
    df["POI_Above_Median"] = df["POI_Above_Median"].fillna(False).astype(bool) #Convert NaN to False where applicable

    #STEP-2: Extract only POI rows that pass the median expression cutoff
    #Ensures POI_Expression_% is stored per tissue-cell type.
    #Ensures POI_Above_Median is explicitly marked True or False
    #Since Jupyter prints full df before filtering, some False values will still show in output logs
    main_protein_present = df[df["POI_Above_Median"]]

    print(f"✅STEP-2: Found {len(main_protein_present)} clusters where {protein_of_interest} is expressed above median.")
    print(main_protein_present.head(), "\n")

    if main_protein_present.empty:
        print(f"⚠️WARNING: {protein_of_interest} does not surpass median expression threshold in any tissue. Skipping file.")
        return None

    #STEP-3: Identify interactors that are **highly expressed** (≥20%)
    #Filters only interactors (excluding POI itself) where %Cells Expressing Gene is ≥ 20%
    interactors_present = df[(df["Gene Symbol"] != protein_of_interest) & (df["%Cells Expressing Gene"] >= WEAK_COMPENSATION)]

    print(f"✅STEP-3: Found {len(interactors_present)} interactors with ≥20% expression.")
    print(interactors_present.head(), "\n")

    if interactors_present.empty:
        print(f"⚠️WARNING: No interactors reach ≥20% expression. Skipping file.")
        return None

    #STEP-4: Identify valid interactions (POI + at least one interactor in the same cluster)
    #Merges clusters where POI is above median with clusters where an interactor is ≥ 20%
    valid_interactions = pd.merge(
        main_protein_present[["Tissue", "Cell Type"]],
        interactors_present[["Tissue", "Cell Type"]],
        on=["Tissue", "Cell Type"], how="inner"
    ).drop_duplicates()

    print(f"✅STEP-4: Found {len(valid_interactions)} valid POI-interactor pairs.")
    print(valid_interactions.head(), "\n")

    if valid_interactions.empty:
        print(f"⚠️WARNING: No valid POI-interactor pairs found for {protein_of_interest}. Skipping file.")
        return None

    #STEP-5: Merge valid interactions back into the dataset
    #Ensures only rows with a POI-interactor pair are retained
    df = df.merge(valid_interactions, on=["Tissue", "Cell Type"], how="inner")

    print(f"✅STEP-5: Filtered dataset now contains {len(df)} rows.")
    print(df.head(), "\n")

    #STEP-6: Define Compensation Category Based on Interactor Expression
    #Categorizes interactions based on interactor expression level
    conditions = [
        df["%Cells Expressing Gene"] >= STRONG_COMPENSATION,  #Robust Compensation (≥50%)
        df["%Cells Expressing Gene"] >= 30,  #Moderate Compensation (30-49%)  <-- ✅ FIXED RANGE
        df["%Cells Expressing Gene"] >= 20  #Weak Compensation (20-29%)  <-- ✅ FIXED RANGE
    ]
    categories = ["Robust Compensation (≥50%)", "Moderate Compensation (30-49%)", "Weak Compensation (20-29%)"]

    df["Compensation Category"] = np.select(conditions, categories, default="No Compensation (<20%)")

    #STEP-7: Remove Lowly Expressed Interactors (<20%)
    #Interactions that fail the ≥20% expression cutoff are removed
    df = df[df["Compensation Category"] != "No Compensation (<20%)"]

    print(f"✅STEP-7: Final dataset contains {len(df)} rows after removing non-compensating interactors.")

    return df

# %%
output_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/"


for file in input_files:
    input_path = os.path.join(input_dir, file)
    
    print(f"\n📂 Processing file: {file}")

    #Extract POI from filename
    protein_of_interest = file.split("_")[0]
    print(f"🧬 Identified POI: {protein_of_interest}")

    #Read CSV (Fix encoding issues)
    df = pd.read_csv(input_path, encoding="utf-8")  
    print(f"✅ Loaded {file} | Shape: {df.shape}")

    if df.empty:
        print(f"⚠️ Skipping {file} as it's empty.")
        continue

    #Process file using H2 criteria
    processed_df = process_H2_file(df, protein_of_interest)

    if processed_df is None or processed_df.empty:
        print(f"⚠️ WARNING: No valid data after processing {file}. Skipping...")
        continue

    #Save output in Excel format (Fix encoding issues)**
    output_file = os.path.join(output_dir, file.replace("_S0_17042025", "_S2_H2_24042025").replace(".csv", ".xlsx")) 
    processed_df.to_excel(output_file, index=False, engine= "openpyxl")  

    print(f"✅ Successfully saved H2 output: {output_file}")
# Out:
# 📂 Processing file: ACSF3_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ACSF3
# ✅ Loaded ACSF3_PPI_filtered_S0_17042025.csv | Shape: (8536, 14)
#
# 🔍STEP-1: Computing tissue median expression for ACSF3...
# 📊Tissue-specific median expression for ACSF3:
# Tissue
# adipose tissue     3.109360
# adrenal gland      2.270799
# bladder organ      0.532229
# blood              2.002172
# bone marrow        2.725964
# brain              1.130856
# breast             0.736955
# colon              1.333889
# cortex             0.509045
# embryo             2.143559
# endocrine gland    1.601069
# esophagus          1.419061
# exocrine gland     1.568245
# eye                1.578902
# fallopian tube     0.704561
# forelimb           0.218341
# gallbladder        0.329399
# heart              3.107043
# hindlimb           0.548948
# intestine          0.599917
# kidney             2.582015
# large intestine    1.109918
# liver              1.606673
# lung               2.031746
# lymph node         2.383717
# ovary              0.799124
# pancreas           0.785913
# placenta           1.161046
# prostate gland     0.699055
# small intestine    1.339386
# spinal cord        2.640185
# spleen             1.382351
# stomach            1.104433
# testis             1.084188
# uterus             0.633737
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 4304 clusters where ACSF3 is expressed above median.
#             Tissue       Cell Type  Cell Count Tissue Composition Gene Symbol  \
# 12  adipose tissue          T cell       31314              0.23%       ACSF3
# 13  adipose tissue          T cell       31314              0.00%       KRT40
# 14  adipose tissue          T cell       31314              0.60%       RAB28
# 15  adipose tissue          T cell       31314              0.23%      TRIM27
# 40  adipose tissue  dendritic cell        2534              0.03%       ACSF3
#
#     Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 12    1.861006            0.099010                     1053.0
# 13    1.394297            0.001654                        1.0
# 14    1.920648            0.111452                     2674.0
# 15    1.847201            0.096131                     1042.0
# 40    1.865613            0.099971                      113.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 12                3.362713           0.448116    3.362713
# 13                0.003193          -2.652755    0.003193
# 14                8.539311           0.844386    8.539311
# 15                3.327585           0.356395    3.327585
# 40                4.459353           0.478726    4.459353
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 12                0.469263           0.265193     1.585829            3.10936
# 13                0.000000           0.265193     0.054316            3.10936
# 14                0.529232           0.265193     3.680456            3.10936
# 15                0.455383           0.265193     1.566226            3.10936
# 40                0.473895           0.265193     2.026338            3.10936
#
#     POI_Expression_%  POI_Above_Median
# 12          3.362713              True
# 13          3.362713              True
# 14          3.362713              True
# 15          3.362713              True
# 40          4.459353              True
#
# ✅STEP-3: Found 23 interactors with ≥20% expression.
#              Tissue                                Cell Type  Cell Count  \
# 58   adipose tissue         fibro/adipogenic progenitor cell       15985
# 106  adipose tissue                    mesenchymal stem cell       29293
# 110  adipose tissue  mesenchymal stem cell of adipose tissue       29276
# 170  adipose tissue                           precursor cell       51326
# 178  adipose tissue                          progenitor cell       22033
#
#     Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 58               1.00%       RAB28    1.911776            0.109601
# 106              1.51%       RAB28    1.913907            0.110046
# 110              1.51%       RAB28    1.913923            0.110049
# 170              2.64%       RAB28    1.908120            0.108838
# 178              1.13%       RAB28    1.900381            0.107224
#
#      Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 58                      4504.0               28.176415           0.785442
# 106                     6777.0               23.135220           0.799601
# 110                     6776.0               23.145238           0.799702
# 170                    11845.0               23.077972           0.761148
# 178                     5068.0               23.001861           0.709729
#
#      Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 58    28.176415                0.520311           0.265193    11.531729
# 106   23.135220                0.522454           0.265193     9.516108
# 110   23.145238                0.522469           0.265193     9.520122
# 170   23.077972                0.516635           0.265193     9.490882
# 178   23.001861                0.508853           0.265193     9.457324
#
#      Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 58             3.10936          4.116359              True
# 106            3.10936          3.717612              True
# 110            3.10936          3.716355              True
# 170            3.10936          3.824572              True
# 178            3.10936          3.966777              True
#
# ✅STEP-4: Found 16 valid POI-interactor pairs.
#             Tissue                                Cell Type
# 0   adipose tissue         fibro/adipogenic progenitor cell
# 4   adipose tissue                    mesenchymal stem cell
# 8   adipose tissue  mesenchymal stem cell of adipose tissue
# 12  adipose tissue                           precursor cell
# 16  adipose tissue                          progenitor cell
#
# ✅STEP-5: Filtered dataset now contains 64 rows.
#            Tissue                         Cell Type  Cell Count  \
# 0  adipose tissue  fibro/adipogenic progenitor cell       15985
# 1  adipose tissue  fibro/adipogenic progenitor cell       15985
# 2  adipose tissue  fibro/adipogenic progenitor cell       15985
# 3  adipose tissue  fibro/adipogenic progenitor cell       15985
# 4  adipose tissue             mesenchymal stem cell       29293
#
#   Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 0              0.15%       ACSF3    1.754613            0.076817
# 1                NaN       KRT40         NaN                 NaN
# 2              1.00%       RAB28    1.911776            0.109601
# 3              0.15%      TRIM27    1.762295            0.078419
# 4              0.24%       ACSF3    1.731139            0.071920
#
#    Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 0                      658.0                4.116359          -0.258769
# 1                        NaN                     NaN                NaN
# 2                     4504.0               28.176415           0.785442
# 3                      693.0                4.335314          -0.207728
# 4                     1089.0                3.717612          -0.414738
#
#    Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 0    4.116359                0.362288           0.265193     1.844498
# 1         NaN                     NaN           0.265193          NaN
# 2   28.176415                0.520311           0.265193    11.531729
# 3    4.335314                0.370012           0.265193     1.935169
# 4    3.717612                0.338685           0.265193     1.675557
#
#    Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 0            3.10936          4.116359              True
# 1            3.10936          4.116359              True
# 2            3.10936          4.116359              True
# 3            3.10936          4.116359              True
# 4            3.10936          3.717612              True
#
# ✅STEP-7: Final dataset contains 17 rows after removing non-compensating interactors.
# ✅ Successfully saved H2 output: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/ACSF3_PPI_filtered_S2_H2_24042025.xlsx
#
# 📂 Processing file: ACTB_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ACTB
# ✅ Loaded ACTB_PPI_filtered_S0_17042025.csv | Shape: (6423, 14)
#
# 🔍STEP-1: Computing tissue median expression for ACTB...
# 📊Tissue-specific median expression for ACTB:
# Tissue
# adipose tissue     45.231006
# adrenal gland      68.370251
# bladder organ      87.440584
# blood              98.049599
# bone marrow        99.200320
# brain              56.615831
# breast             88.984748
# colon              93.858337
# cortex             99.866436
# embryo             67.906137
# endocrine gland    98.701746
# esophagus          88.769813
# exocrine gland     85.436092
# eye                18.705368
# fallopian tube     95.120786
# forelimb           99.971922
# gallbladder        65.877821
# heart              47.654941
# hindlimb           99.489541
# intestine          96.867600
# kidney             90.386710
# large intestine    90.469762
# liver              91.032172
# lung               87.271370
# lymph node         98.151833
# ovary              95.608321
# pancreas           79.209553
# placenta           90.084093
# prostate gland     81.762436
# small intestine    96.658606
# spinal cord        68.992179
# spleen             98.092342
# stomach            94.033211
# testis             70.775348
# uterus             94.992300
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 3246 clusters where ACTB is expressed above median.
#            Tissue                        Cell Type  Cell Count  \
# 0  adipose tissue                           B cell       16003
# 1  adipose tissue                           B cell       16003
# 2  adipose tissue                           B cell       16003
# 3  adipose tissue  CD4-positive, alpha-beta T cell       11653
# 4  adipose tissue  CD4-positive, alpha-beta T cell       11653
#
#   Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 0              2.68%        ACTB    2.213406            0.172522
# 1              1.16%       ACTG1    1.903755            0.107928
# 2              0.02%        CFL2    1.571997            0.038722
# 3              2.14%        ACTB    2.346958            0.200381
# 4              1.61%       ACTG1    2.098781            0.148611
#
#    Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 0                    12027.0               75.154659           0.249570
# 1                     5220.0               32.618884          -0.513513
# 2                       85.0                0.531150          -1.331076
# 3                     9620.0               82.553849           0.578686
# 4                     7240.0               62.129924          -0.032903
#
#    Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 0   75.154659                0.311695           0.270718    30.240685
# 1   32.618884                0.170905           0.270718    13.170059
# 2    0.531150                0.020063           0.270718     0.274629
# 3   82.553849                0.372417           0.270718    33.224650
# 4   62.129924                0.259578           0.270718    25.009944
#
#    Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 0          45.231006         75.154659              True
# 1          45.231006         75.154659              True
# 2          45.231006         75.154659              True
# 3          45.231006         82.553849              True
# 4          45.231006         82.553849              True
#
# ✅STEP-3: Found 1981 interactors with ≥20% expression.
#             Tissue                        Cell Type  Cell Count  \
# 1   adipose tissue                           B cell       16003
# 4   adipose tissue  CD4-positive, alpha-beta T cell       11653
# 7   adipose tissue  CD8-positive, alpha-beta T cell        5441
# 10  adipose tissue                           T cell       31314
# 19  adipose tissue                alpha-beta T cell       20182
#
#    Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 1               1.16%       ACTG1    1.903755            0.107928
# 4               1.61%       ACTG1    2.098781            0.148611
# 7               0.75%       ACTG1    2.107666            0.150464
# 10              3.25%       ACTG1    2.133164            0.155783
# 19              2.63%       ACTG1    2.127793            0.154663
#
#     Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 1                      5220.0               32.618884          -0.513513
# 4                      7240.0               62.129924          -0.032903
# 7                      3346.0               61.496049          -0.011008
# 10                    14581.0               46.563837           0.051828
# 19                    11797.0               58.453077           0.038591
#
#     Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 1    32.618884                0.170905           0.270718    13.170059
# 4    62.129924                0.259578           0.270718    25.009944
# 7    61.496049                0.263618           0.270718    24.758010
# 10   46.563837                0.275211           0.270718    18.789763
# 19   58.453077                0.272769           0.270718    23.544482
#
#     Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 1           45.231006         75.154659              True
# 4           45.231006         82.553849              True
# 7           45.231006         86.215769              True
# 10          45.231006         62.151115              True
# 19          45.231006         78.703795              True
#
# ✅STEP-4: Found 1051 valid POI-interactor pairs.
#             Tissue                        Cell Type
# 0   adipose tissue                           B cell
# 3   adipose tissue  CD4-positive, alpha-beta T cell
# 6   adipose tissue  CD8-positive, alpha-beta T cell
# 9   adipose tissue                           T cell
# 12  adipose tissue                alpha-beta T cell
#
# ✅STEP-5: Filtered dataset now contains 3153 rows.
#            Tissue                        Cell Type  Cell Count  \
# 0  adipose tissue                           B cell       16003
# 1  adipose tissue                           B cell       16003
# 2  adipose tissue                           B cell       16003
# 3  adipose tissue  CD4-positive, alpha-beta T cell       11653
# 4  adipose tissue  CD4-positive, alpha-beta T cell       11653
#
#   Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 0              2.68%        ACTB    2.213406            0.172522
# 1              1.16%       ACTG1    1.903755            0.107928
# 2              0.02%        CFL2    1.571997            0.038722
# 3              2.14%        ACTB    2.346958            0.200381
# 4              1.61%       ACTG1    2.098781            0.148611
#
#    Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 0                    12027.0               75.154659           0.249570
# 1                     5220.0               32.618884          -0.513513
# 2                       85.0                0.531150          -1.331076
# 3                     9620.0               82.553849           0.578686
# 4                     7240.0               62.129924          -0.032903
#
#    Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 0   75.154659                0.311695           0.270718    30.240685
# 1   32.618884                0.170905           0.270718    13.170059
# 2    0.531150                0.020063           0.270718     0.274629
# 3   82.553849                0.372417           0.270718    33.224650
# 4   62.129924                0.259578           0.270718    25.009944
#
#    Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 0          45.231006         75.154659              True
# 1          45.231006         75.154659              True
# 2          45.231006         75.154659              True
# 3          45.231006         82.553849              True
# 4          45.231006         82.553849              True
#
# ✅STEP-7: Final dataset contains 2108 rows after removing non-compensating interactors.
# ✅ Successfully saved H2 output: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/ACTB_PPI_filtered_S2_H2_24042025.xlsx
#
# 📂 Processing file: ACY1_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ACY1
# ✅ Loaded ACY1_PPI_filtered_S0_17042025.csv | Shape: (1933, 14)
#
# 🔍STEP-1: Computing tissue median expression for ACY1...
# 📊Tissue-specific median expression for ACY1:
# Tissue
# adipose tissue     0.291115
# adrenal gland      0.869215
# bladder organ      0.010654
# blood              0.404040
# bone marrow        0.141319
# brain              0.161365
# breast             0.132035
# colon              0.181677
# cortex             0.161692
# embryo             0.188537
# endocrine gland    0.278988
# esophagus          0.056433
# exocrine gland     0.218746
# eye                0.268598
# fallopian tube     0.232739
# forelimb           0.136950
# gallbladder        0.082554
# heart              0.227402
# hindlimb           0.071934
# intestine          0.978953
# kidney             1.489392
# large intestine    0.172712
# liver              0.162565
# lung               0.267020
# lymph node         0.363292
# ovary              0.065266
# pancreas           0.207612
# placenta           0.072127
# prostate gland     0.311514
# small intestine    0.201715
# spinal cord        0.299593
# spleen             0.136439
# stomach            0.114979
# uterus             0.018384
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 979 clusters where ACY1 is expressed above median.
#             Tissue                    Cell Type  Cell Count  \
# 4   adipose tissue                    adipocyte       72587
# 5   adipose tissue  adipocyte of omentum tissue       15436
# 7   adipose tissue       connective tissue cell      188588
# 8   adipose tissue             contractile cell       16234
# 10  adipose tissue             endothelial cell       45303
#
#    Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 4               0.08%        ACY1    1.697748            0.064954
# 5               0.04%        ACY1    1.692393            0.063837
# 7               0.18%        ACY1    1.755913            0.077088
# 8               0.02%        ACY1    1.901634            0.107485
# 10              0.03%        ACY1    1.765160            0.079017
#
#     Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 4                       354.0                0.487691          -0.500959
# 5                       160.0                1.036538          -0.554528
# 7                       809.0                0.428977           0.080965
# 8                        79.0                0.486633           1.538847
# 10                      141.0                0.311238           0.173478
#
#     Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 4     0.487691                0.342792           0.259887     0.384170
# 5     1.036538                0.331222           0.259887     0.599081
# 7     0.428977                0.468473           0.259887     0.410958
# 8     0.486633                0.783341           0.259887     0.559967
# 10    0.311238                0.488454           0.259887     0.371854
#
#     Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 4            0.291115          0.487691              True
# 5            0.291115          1.036538              True
# 7            0.291115          0.428977              True
# 8            0.291115          0.486633              True
# 10           0.291115          0.311238              True
#
# ✅STEP-3: Found 0 interactors with ≥20% expression.
# Empty DataFrame
# Columns: [Tissue, Cell Type, Cell Count, Tissue Composition, Gene Symbol, Expression, Expression, Scaled, Num_Cells_Expressing_Gene, %Cells Expressing Gene, Expression_Zscore, Robustness, Expression_Specificity, Cluster_Diversity, scRNA_score, Tissue_Median_Exp, POI_Expression_%, POI_Above_Median]
# Index: []
#
# ⚠️WARNING: No interactors reach ≥20% expression. Skipping file.
# ⚠️ WARNING: No valid data after processing ACY1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing file: ADIPOQ_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ADIPOQ
# ✅ Loaded ADIPOQ_PPI_filtered_S0_17042025.csv | Shape: (19236, 14)
#
# 🔍STEP-1: Computing tissue median expression for ADIPOQ...
# 📊Tissue-specific median expression for ADIPOQ:
# Tissue
# adipose tissue     7.483692
# adrenal gland      0.022706
# bladder organ      0.007253
# blood              0.006352
# bone marrow        0.006931
# brain              0.007426
# breast             0.042336
# colon              0.005145
# cortex             0.001779
# embryo             0.013749
# endocrine gland    0.005793
# esophagus          0.072595
# exocrine gland     0.006300
# eye                0.005109
# heart              0.254745
# intestine          0.007167
# kidney             0.009108
# large intestine    0.021404
# liver              0.011619
# lung               0.007146
# lymph node         0.009188
# ovary              0.001731
# pancreas           0.022280
# placenta           0.002113
# prostate gland     0.012323
# small intestine    0.002031
# spinal cord        0.079957
# stomach            0.015840
# testis             0.066667
# uterus             0.002825
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 9765 clusters where ADIPOQ is expressed above median.
#             Tissue  Cell Type  Cell Count Tissue Composition Gene Symbol  \
# 84  adipose tissue  adipocyte       72587             10.53%      ADIPOQ
# 85  adipose tissue  adipocyte       72587              0.01%      AMIGO1
# 86  adipose tissue  adipocyte       72587              3.70%     BCL2L13
# 87  adipose tissue  adipocyte       72587              0.00%         BIK
# 88  adipose tissue  adipocyte       72587              0.73%       BTNL9
#
#     Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 84    2.214872            0.172828                    47255.0
# 85    1.712179            0.067965                       31.0
# 86    1.772362            0.080519                    16598.0
# 87    1.717250            0.069023                        7.0
# 88    1.954836            0.118583                     3280.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 84               65.101189           2.046578   65.101189
# 85                0.042707          -0.515779    0.042707
# 86               22.866353          -0.209010   22.866353
# 87                0.009644          -0.489927    0.009644
# 88                4.518715           0.721107    4.518715
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 84                0.488586           0.494737    26.334857           7.483692
# 85                0.189106           0.494737     0.191673           7.483692
# 86                0.224960           0.494737     9.335473           7.483692
# 87                0.192127           0.494737     0.179656           7.483692
# 88                0.333669           0.494737     2.039901           7.483692
#
#     POI_Expression_%  POI_Above_Median
# 84         65.101189              True
# 85         65.101189              True
# 86         65.101189              True
# 87         65.101189              True
# 88         65.101189              True
#
# ✅STEP-3: Found 116 interactors with ≥20% expression.
#              Tissue                    Cell Type  Cell Count  \
# 86   adipose tissue                    adipocyte       72587
# 107  adipose tissue  adipocyte of omentum tissue       15436
# 193  adipose tissue             contractile cell       16234
# 235  adipose tissue             endothelial cell       45303
# 655  adipose tissue                   mural cell       10411
#
#     Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 86               3.70%     BCL2L13    1.772362            0.080519
# 107              0.81%     BCL2L13    1.773292            0.080713
# 193              1.02%       BTNL9    2.578021            0.248581
# 235              4.43%       BTNL9    2.967050            0.329734
# 655              1.12%       BTNL9    2.584356            0.249903
#
#      Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 86                     16598.0               22.866353          -0.209010
# 107                     3636.0               23.555325          -0.204268
# 193                     4594.0               28.298632           3.897638
# 235                    19902.0               43.930866           5.880615
# 655                     5015.0               48.170205           3.929926
#
#      Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 86    22.866353                0.224960           0.494737     9.335473
# 107   23.555325                0.225514           0.494737     9.611283
# 193   28.298632                0.704932           0.494737    11.700373
# 235   43.930866                0.936695           0.494737    18.045972
# 655   48.170205                0.708705           0.494737    19.650511
#
#      Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 86            7.483692         65.101189              True
# 107           7.483692         61.674009              True
# 193           7.483692         13.551805              True
# 235           7.483692          9.206896              True
# 655           7.483692         19.344924              True
#
# ✅STEP-4: Found 66 valid POI-interactor pairs.
#             Tissue                    Cell Type
# 0   adipose tissue                    adipocyte
# 21  adipose tissue  adipocyte of omentum tissue
# 42  adipose tissue             contractile cell
# 63  adipose tissue             endothelial cell
# 84  adipose tissue                   mural cell
#
# ✅STEP-5: Filtered dataset now contains 1386 rows.
#            Tissue  Cell Type  Cell Count Tissue Composition Gene Symbol  \
# 0  adipose tissue  adipocyte       72587             10.53%      ADIPOQ
# 1  adipose tissue  adipocyte       72587              0.01%      AMIGO1
# 2  adipose tissue  adipocyte       72587              3.70%     BCL2L13
# 3  adipose tissue  adipocyte       72587              0.00%         BIK
# 4  adipose tissue  adipocyte       72587              0.73%       BTNL9
#
#    Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 0    2.214872            0.172828                    47255.0
# 1    1.712179            0.067965                       31.0
# 2    1.772362            0.080519                    16598.0
# 3    1.717250            0.069023                        7.0
# 4    1.954836            0.118583                     3280.0
#
#    %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 0               65.101189           2.046578   65.101189
# 1                0.042707          -0.515779    0.042707
# 2               22.866353          -0.209010   22.866353
# 3                0.009644          -0.489927    0.009644
# 4                4.518715           0.721107    4.518715
#
#    Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 0                0.488586           0.494737    26.334857           7.483692
# 1                0.189106           0.494737     0.191673           7.483692
# 2                0.224960           0.494737     9.335473           7.483692
# 3                0.192127           0.494737     0.179656           7.483692
# 4                0.333669           0.494737     2.039901           7.483692
#
#    POI_Expression_%  POI_Above_Median
# 0         65.101189              True
# 1         65.101189              True
# 2         65.101189              True
# 3         65.101189              True
# 4         65.101189              True
#
# ✅STEP-7: Final dataset contains 76 rows after removing non-compensating interactors.
# ✅ Successfully saved H2 output: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/ADIPOQ_PPI_filtered_S2_H2_24042025.xlsx
#
# 📂 Processing file: AGXT_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: AGXT
# ✅ Loaded AGXT_PPI_filtered_S0_17042025.csv | Shape: (8703, 14)
#
# 🔍STEP-1: Computing tissue median expression for AGXT...
# 📊Tissue-specific median expression for AGXT:
# Tissue
# adipose tissue     0.006725
# adrenal gland      0.076395
# blood              0.005876
# bone marrow        0.006120
# brain              0.004382
# breast             0.021650
# colon              0.024650
# embryo             0.075216
# endocrine gland    0.001066
# esophagus          0.038197
# exocrine gland     0.005755
# eye                0.003020
# fallopian tube     0.001889
# forelimb           0.019996
# gallbladder        0.009299
# heart              0.000875
# hindlimb           0.031396
# intestine          0.025224
# kidney             0.075815
# large intestine    0.076717
# liver              2.861470
# lung               0.005687
# lymph node         0.003550
# ovary              0.002113
# pancreas           0.146638
# placenta           0.005848
# prostate gland     0.009374
# small intestine    0.026669
# spleen             0.003487
# stomach            0.037707
# uterus             0.002907
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 4419 clusters where AGXT is expressed above median.
#             Tissue  Cell Type  Cell Count Tissue Composition Gene Symbol  \
# 9   adipose tissue  adipocyte       72587              0.00%        AGXT
# 10  adipose tissue  adipocyte       72587              0.00%      CYSRT1
# 11  adipose tissue  adipocyte       72587              1.74%        FOSB
# 12  adipose tissue  adipocyte       72587                NaN       KRT31
# 13  adipose tissue  adipocyte       72587              0.00%       KRT34
#
#     Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 9     1.870753            0.101044                        8.0
# 10    1.673444            0.059885                        7.0
# 11    2.042545            0.136880                     7805.0
# 12         NaN                 NaN                        NaN
# 13    2.376584            0.206561                        2.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 9                 0.011021          -0.203085    0.011021
# 10                0.009644          -0.892367    0.009644
# 11               10.752614           0.397058   10.752614
# 12                     NaN                NaN         NaN
# 13                0.002755           1.563996    0.002755
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 9                 0.368416                0.3     0.211775           0.006725
# 10                0.215848                0.3     0.150197           0.006725
# 11                0.501253                0.3     4.561547           0.006725
# 12                     NaN                0.3          NaN           0.006725
# 13                0.759546                0.3     0.364920           0.006725
#
#     POI_Expression_%  POI_Above_Median
# 9           0.011021              True
# 10          0.011021              True
# 11          0.011021              True
# 12          0.011021              True
# 13          0.011021              True
#
# ✅STEP-3: Found 581 interactors with ≥20% expression.
#             Tissue               Cell Type  Cell Count Tissue Composition  \
# 2   adipose tissue                  T cell       31314              2.50%
# 29  adipose tissue       alpha-beta T cell       20182              2.06%
# 38  adipose tissue  connective tissue cell      188588             12.73%
# 83  adipose tissue              fibroblast       77972              7.49%
# 92  adipose tissue      hematopoietic cell      121993             10.60%
#
#    Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 2         FOSB    2.144202            0.158086                    11217.0
# 29        FOSB    2.125639            0.154213                     9265.0
# 38        FOSB    2.529307            0.238419                    57123.0
# 83        FOSB    2.687552            0.271430                    33617.0
# 92        FOSB    2.360814            0.203271                    47575.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 2                35.821039           0.752188   35.821039
# 29               45.907244           0.687339   45.907244
# 38               30.289838           2.097523   30.289838
# 83               43.114195           2.650341   43.114195
# 92               38.998139           1.508905   38.998139
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 2                 0.579858                0.3    14.620359           0.006725
# 29                0.565504                0.3    18.649099           0.006725
# 38                0.877638                0.3    12.526990           0.006725
# 83                1.000000                0.3    17.705678           0.006725
# 92                0.747352                0.3    15.958196           0.006725
#
#     POI_Expression_%  POI_Above_Median
# 2           0.006387             False
# 29          0.004955             False
# 38          0.009014              True
# 83          0.005130             False
# 92          0.004918             False
#
# ✅STEP-4: Found 260 valid POI-interactor pairs.
#             Tissue                                Cell Type
# 0   adipose tissue                   connective tissue cell
# 9   adipose tissue                    mesenchymal stem cell
# 18  adipose tissue  mesenchymal stem cell of adipose tissue
# 27  adipose tissue                             preadipocyte
# 36  adipose tissue                   subcutaneous adipocyte
#
# ✅STEP-5: Filtered dataset now contains 2340 rows.
#            Tissue               Cell Type  Cell Count Tissue Composition  \
# 0  adipose tissue  connective tissue cell      188588              0.00%
# 1  adipose tissue  connective tissue cell      188588              0.00%
# 2  adipose tissue  connective tissue cell      188588             12.73%
# 3  adipose tissue  connective tissue cell      188588                NaN
# 4  adipose tissue  connective tissue cell      188588              0.00%
#
#   Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 0        AGXT    1.832963            0.093160                       17.0
# 1      CYSRT1    1.887487            0.104534                       15.0
# 2        FOSB    2.529307            0.238419                    57123.0
# 3       KRT31         NaN                 NaN                        NaN
# 4       KRT34    2.239040            0.177869                        3.0
#
#    %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 0                0.009014          -0.335102    0.009014
# 1                0.007954          -0.144627    0.007954
# 2               30.289838           2.097523   30.289838
# 3                     NaN                NaN         NaN
# 4                0.001591           1.083499    0.001591
#
#    Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 0                0.339195                0.3     0.199284           0.006725
# 1                0.381355                0.3     0.215724           0.006725
# 2                0.877638                0.3    12.526990           0.006725
# 3                     NaN                0.3          NaN           0.006725
# 4                0.653191                0.3     0.321913           0.006725
#
#    POI_Expression_%  POI_Above_Median
# 0          0.009014              True
# 1          0.009014              True
# 2          0.009014              True
# 3          0.009014              True
# 4          0.009014              True
#
# ✅STEP-7: Final dataset contains 260 rows after removing non-compensating interactors.
# ✅ Successfully saved H2 output: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/AGXT_PPI_filtered_S2_H2_24042025.xlsx
#
# 📂 Processing file: AHCY_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: AHCY
# ✅ Loaded AHCY_PPI_filtered_S0_17042025.csv | Shape: (4266, 14)
#
# 🔍STEP-1: Computing tissue median expression for AHCY...
# 📊Tissue-specific median expression for AHCY:
# Tissue
# adipose tissue     0.843694
# adrenal gland      5.987538
# bladder organ      0.461306
# blood              2.127385
# bone marrow        4.352911
# brain              1.338645
# breast             2.021617
# colon              2.608294
# cortex             0.180951
# embryo             4.434577
# endocrine gland    4.135338
# esophagus          2.657473
# exocrine gland     1.767423
# eye                0.727067
# fallopian tube     0.830408
# forelimb           8.045977
# gallbladder        3.880022
# heart              1.148235
# hindlimb           7.929782
# intestine          3.631997
# kidney             4.188668
# large intestine    1.562500
# liver              3.718779
# lung               2.099448
# lymph node         2.377353
# ovary              2.123272
# pancreas           1.677775
# placenta           1.567021
# prostate gland     2.095190
# small intestine    2.759908
# spinal cord        1.082691
# spleen             1.666408
# stomach            1.769912
# testis             9.321646
# uterus             1.101548
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 2154 clusters where AHCY is expressed above median.
#             Tissue         Cell Type  Cell Count Tissue Composition  \
# 14  adipose tissue        blood cell        3586              0.01%
# 15  adipose tissue        blood cell        3586              0.00%
# 18  adipose tissue  contractile cell       16234              0.03%
# 19  adipose tissue  contractile cell       16234              0.03%
# 20  adipose tissue    dendritic cell        2534              0.01%
#
#    Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 14        AHCY    1.664237            0.057964                       32.0
# 15     C1orf50    1.493924            0.022436                        5.0
# 18        AHCY    1.907277            0.108663                      148.0
# 19     C1orf50    1.901640            0.107487                      154.0
# 20        AHCY    1.880957            0.103172                       37.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 14                0.892359          -0.749563    0.892359
# 15                0.139431          -2.235444    0.139431
# 18                0.911667           1.370815    0.911667
# 19                0.948626           1.321635    0.948626
# 20                1.460142           1.141187    1.460142
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 14                0.286898           0.270718     0.525846           0.843694
# 15                0.000000           0.270718     0.109916           0.843694
# 18                0.696306           0.270718     0.697333           0.843694
# 19                0.686811           0.270718     0.708318           0.843694
# 20                0.651969           0.270718     0.898988           0.843694
#
#     POI_Expression_%  POI_Above_Median
# 14          0.892359              True
# 15          0.892359              True
# 18          0.911667              True
# 19          0.911667              True
# 20          1.460142              True
#
# ✅STEP-3: Found 0 interactors with ≥20% expression.
# Empty DataFrame
# Columns: [Tissue, Cell Type, Cell Count, Tissue Composition, Gene Symbol, Expression, Expression, Scaled, Num_Cells_Expressing_Gene, %Cells Expressing Gene, Expression_Zscore, Robustness, Expression_Specificity, Cluster_Diversity, scRNA_score, Tissue_Median_Exp, POI_Expression_%, POI_Above_Median]
# Index: []
#
# ⚠️WARNING: No interactors reach ≥20% expression. Skipping file.
# ⚠️ WARNING: No valid data after processing AHCY_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing file: AIPL1_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: AIPL1
# ✅ Loaded AIPL1_PPI_filtered_S0_17042025.csv | Shape: (2664, 14)
#
# 🔍STEP-1: Computing tissue median expression for AIPL1...
# 📊Tissue-specific median expression for AIPL1:
# Tissue
# adipose tissue     0.079448
# adrenal gland      0.018033
# bladder organ      0.010235
# blood              0.014669
# bone marrow        0.009054
# brain              0.038697
# breast             0.024850
# colon              0.018475
# cortex             0.009474
# embryo             0.024544
# endocrine gland    0.009259
# esophagus          0.195503
# exocrine gland     0.011719
# eye                3.019996
# fallopian tube     0.010621
# forelimb           0.005158
# gallbladder        0.018598
# heart              0.121551
# hindlimb           0.022237
# intestine          0.011875
# kidney             0.016929
# large intestine    0.054941
# liver              0.054523
# lung               0.041911
# lymph node         0.010727
# ovary              0.010388
# pancreas           0.027474
# placenta           0.039638
# prostate gland     0.053147
# small intestine    0.009375
# spinal cord        0.011491
# spleen             0.004450
# stomach            0.009873
# testis             0.137760
# uterus             0.006929
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 1356 clusters where AIPL1 is expressed above median.
#             Tissue               Cell Type  Cell Count Tissue Composition  \
# 6   adipose tissue                  T cell       31314              0.01%
# 7   adipose tissue                  T cell       31314              0.01%
# 16  adipose tissue  connective tissue cell      188588              0.04%
# 17  adipose tissue  connective tissue cell      188588              0.11%
# 18  adipose tissue        contractile cell       16234              0.01%
#
#    Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 6        AIPL1    1.842176            0.095082                       30.0
# 7       PLSCR3    1.934062            0.114250                       63.0
# 16       AIPL1    1.768123            0.079635                      171.0
# 17      PLSCR3    1.798154            0.085899                      502.0
# 18       AIPL1    1.931372            0.113689                       26.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 6                 0.095804           0.439654    0.095804
# 7                 0.201188           1.060851    0.201188
# 16                0.090674          -0.060984    0.090674
# 17                0.266189           0.142039    0.266189
# 18                0.160158           1.042670    0.160158
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 6                 0.586239           0.319444     0.336706           0.079448
# 7                 0.707314           0.319444     0.427290           0.079448
# 16                0.488662           0.319444     0.295623           0.079448
# 17                0.528233           0.319444     0.381658           0.079448
# 18                0.703771           0.319444     0.409460           0.079448
#
#     POI_Expression_%  POI_Above_Median
# 6           0.095804              True
# 7           0.095804              True
# 16          0.090674              True
# 17          0.090674              True
# 18          0.160158              True
#
# ✅STEP-3: Found 0 interactors with ≥20% expression.
# Empty DataFrame
# Columns: [Tissue, Cell Type, Cell Count, Tissue Composition, Gene Symbol, Expression, Expression, Scaled, Num_Cells_Expressing_Gene, %Cells Expressing Gene, Expression_Zscore, Robustness, Expression_Specificity, Cluster_Diversity, scRNA_score, Tissue_Median_Exp, POI_Expression_%, POI_Above_Median]
# Index: []
#
# ⚠️WARNING: No interactors reach ≥20% expression. Skipping file.
# ⚠️ WARNING: No valid data after processing AIPL1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing file: ALAS2_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ALAS2
# ✅ Loaded ALAS2_PPI_filtered_S0_17042025.csv | Shape: (3238, 14)
#
# 🔍STEP-1: Computing tissue median expression for ALAS2...
# 📊Tissue-specific median expression for ALAS2:
# Tissue
# adipose tissue     0.153665
# adrenal gland      0.381078
# bladder organ      0.049140
# blood              0.046972
# bone marrow        0.977392
# brain              0.015764
# breast             0.010009
# colon              0.026610
# cortex             0.004423
# embryo             0.350145
# endocrine gland    0.049669
# esophagus          0.043605
# exocrine gland     0.008080
# eye                0.022402
# fallopian tube     0.031631
# forelimb           0.059559
# heart              0.080726
# hindlimb           0.131062
# intestine          0.018474
# kidney             0.019867
# large intestine    0.033885
# liver              0.414051
# lung               0.043405
# lymph node         0.026548
# ovary              0.020903
# pancreas           0.046331
# placenta           0.176566
# prostate gland     0.027070
# small intestine    0.061200
# spinal cord        0.135336
# spleen             0.046865
# stomach            0.020965
# testis             0.795229
# uterus             0.006415
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 1636 clusters where ALAS2 is expressed above median.
#             Tissue         Cell Type  Cell Count Tissue Composition  \
# 14  adipose tissue        blood cell        3586              0.03%
# 15  adipose tissue        blood cell        3586              0.05%
# 18  adipose tissue  contractile cell       16234              0.01%
# 19  adipose tissue  contractile cell       16234              0.22%
# 20  adipose tissue    dendritic cell        2534              0.00%
#
#    Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 14       ALAS2    2.824116            0.299917                      125.0
# 15        BANP    1.741642            0.074111                      208.0
# 18       ALAS2    2.131422            0.155420                       28.0
# 19        BANP    1.954930            0.118603                     1005.0
# 20       ALAS2    1.761098            0.078169                        7.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 14                3.485778           5.095645    3.485778
# 15                5.800335          -0.674683    5.800335
# 18                0.172478           1.403111    0.172478
# 19                6.190711           0.462289    6.190711
# 20                0.276243          -0.570968    0.276243
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 14                1.000000           0.326531     1.859617           0.153665
# 15                0.235756           0.326531     2.479742           0.153665
# 18                0.510947           0.326531     0.338676           0.153665
# 19                0.386341           0.326531     2.696127           0.153665
# 20                0.249493           0.326531     0.275600           0.153665
#
#     POI_Expression_%  POI_Above_Median
# 14          3.485778              True
# 15          3.485778              True
# 18          0.172478              True
# 19          0.172478              True
# 20          0.276243              True
#
# ✅STEP-3: Found 1 interactors with ≥20% expression.
#         Tissue                 Cell Type  Cell Count Tissue Composition  \
# 2749  placenta  syncytiotrophoblast cell       28110              1.49%
#
#      Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 2749        BANP    1.802497            0.086805                     7804.0
#
#       %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 2749               27.762362          -0.276514   27.762362
#
#       Expression_Specificity  Cluster_Diversity  scRNA_score  \
# ...
# 338            0.070395                      431.0               40.318054
# 362            0.207020                      490.0               39.200000
#
#      Expression_Zscore  Robustness  Expression_Specificity  Cluster_Diversity  \
# 296          -1.343590   41.671918                0.111244           0.147727
# 302          -1.141474   40.462963                0.172190           0.147727
# 314          -0.003956   36.970475                0.515197           0.147727
# 338          -1.305733   40.318054                0.122660           0.147727
# 362           0.169313   39.200000                0.567444           0.147727
#
#      scRNA_score  Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 296    16.742810           0.112986          0.126024              True
# 302    16.283607           0.112986          0.113169              True
# 314    15.023814           0.112986          0.192555              True
# 338    16.205831           0.112986          0.280636              True
# 362    15.936523           0.112986          0.240000              True
#
# ✅STEP-4: Found 298 valid POI-interactor pairs.
#            Tissue                                        Cell Type
# 0   adrenal gland                  CD8-positive, alpha-beta T cell
# 6   adrenal gland                                           T cell
# 12  adrenal gland                         ciliated epithelial cell
# 18  adrenal gland  effector memory CD8-positive, alpha-beta T cell
# 24  adrenal gland                                       enterocyte
#
# ✅STEP-5: Filtered dataset now contains 1788 rows.
#           Tissue                        Cell Type  Cell Count  \
# 0  adrenal gland  CD8-positive, alpha-beta T cell        4761
# 1  adrenal gland  CD8-positive, alpha-beta T cell        4761
# 2  adrenal gland  CD8-positive, alpha-beta T cell        4761
# 3  adrenal gland  CD8-positive, alpha-beta T cell        4761
# 4  adrenal gland  CD8-positive, alpha-beta T cell        4761
#
#   Tissue Composition Gene Symbol  Expression  Expression, Scaled  \
# 0              0.00%     ZMYND10    1.608949            0.064774
# 1                NaN        CDR1         NaN                 NaN
# 2              1.43%       EIF3M    1.616213            0.066888
# 3              0.17%       IFT43    1.515206            0.037494
# 4                NaN       NUTM1         NaN                 NaN
#
#    Num_Cells_Expressing_Gene  %Cells Expressing Gene  Expression_Zscore  \
# 0                        6.0                0.126024          -1.366414
# 1                        NaN                     NaN                NaN
# 2                     1984.0               41.671918          -1.343590
# 3                      237.0                4.977946          -1.660944
# 4                        NaN                     NaN                NaN
#
#    Robustness  Expression_Specificity  Cluster_Diversity  scRNA_score  \
# 0    0.126024                0.104362           0.147727     0.121700
# 1         NaN                     NaN           0.147727          NaN
# 2   41.671918                0.111244           0.147727    16.742810
# 3    4.977946                0.015550           0.147727     2.026944
# 4         NaN                     NaN           0.147727          NaN
#
#    Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 0           0.112986          0.126024              True
# 1           0.112986          0.126024              True
# 2           0.112986          0.126024              True
# 3           0.112986          0.126024              True
# 4           0.112986          0.126024              True
#
# ✅STEP-7: Final dataset contains 309 rows after removing non-compensating interactors.
# ✅ Successfully saved H2 output: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/ZMYND10_PPI_filtered_S2_H2_24042025.xlsx
#
# 📂 Processing file: ZNF24_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ZNF24
# ✅ Loaded ZNF24_PPI_filtered_S0_17042025.csv | Shape: (4226, 14)
#
# 🔍STEP-1: Computing tissue median expression for ZNF24...
# 📊Tissue-specific median expression for ZNF24:
# Tissue
# adipose tissue     4.330418
# adrenal gland      6.725631
# bladder organ      1.355810
# blood              6.438561
# bone marrow        6.525855
# brain              4.148007
# breast             5.247956
# colon              4.662283
# cortex             3.213701
# embryo             4.290553
# endocrine gland    6.169319
# esophagus          3.918001
# exocrine gland     5.240488
# eye                3.040520
# fallopian tube     4.285519
# forelimb           0.992384
# gallbladder        7.768323
# heart              5.067623
# intestine          3.971014
# kidney             5.102062
# large intestine    2.806607
# liver              4.278523
# lung               5.527409
# lymph node         7.250443
# ovary              3.887733
# pancreas           2.594331
# placenta           2.250929
# prostate gland     4.477644
# small intestine    4.851749
# spinal cord        7.602257
# spleen             5.122021
# stomach            3.794649
# testis             6.498131
# uterus             2.853069
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 2132 clusters where ZNF24 is expressed above median.
#             Tissue          Cell Type  Cell Count Tissue Composition  \
# 0   adipose tissue             B cell       16003              0.21%
# 1   adipose tissue             B cell       16003              0.02%
# 6   adipose tissue             T cell       31314              0.38%
# 7   adipose tissue             T cell       31314              0.09%
# 12  adipose tissue  alpha-beta T cell       20182              0.22%
#
#    Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 0        ZNF24    1.630503            0.071047                      939.0
# 1      ZSCAN32    1.570385            0.030965                       71.0
# 6        ZNF24    1.806974            0.122403                     1715.0
# 7      ZSCAN32    1.815269            0.072173                      397.0
# 12       ZNF24    1.681006            0.085744                      975.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 0                 5.867650          -1.085507    5.867650
# 1                 0.443667          -1.609109    0.443667
# 6                 5.476784           0.451491    5.476784
# 7                 1.267804           0.523735    1.267804
# 12                4.831038          -0.645643    4.831038
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 0                 0.247243           0.270718     2.500101           4.330418
# 1                 0.143813           0.270718     0.289135           4.330418
# 6                 0.550856           0.270718     2.465199           4.330418
# 7                 0.565127           0.270718     0.787316           4.330418
# 12                0.334132           0.270718     2.120212           4.330418
#
#     POI_Expression_%  POI_Above_Median
# 0           5.867650              True
# 1           5.867650              True
# 6           5.476784              True
# 7           5.476784              True
# 12          4.831038              True
#
# ✅STEP-3: Found 0 interactors with ≥20% expression.
# Empty DataFrame
# Columns: [Tissue, Cell Type, Cell Count, Tissue Composition, Gene Symbol, Expression, Expression, Scaled, Num_Cells_Expressing_Gene, %Cells Expressing Gene, Expression_Zscore, Robustness, Expression_Specificity, Cluster_Diversity, scRNA_score, Tissue_Median_Exp, POI_Expression_%, POI_Above_Median]
# Index: []
#
# ⚠️WARNING: No interactors reach ≥20% expression. Skipping file.
# ⚠️ WARNING: No valid data after processing ZNF24_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing file: ZNF624_PPI_filtered_S0_17042025.csv
# 🧬 Identified POI: ZNF624
# ✅ Loaded ZNF624_PPI_filtered_S0_17042025.csv | Shape: (6060, 14)
#
# 🔍STEP-1: Computing tissue median expression for ZNF624...
# 📊Tissue-specific median expression for ZNF624:
# Tissue
# adipose tissue     1.076537
# adrenal gland      0.478807
# bladder organ      0.067148
# blood              0.305543
# bone marrow        0.274489
# brain              0.525784
# breast             0.147465
# colon              0.231099
# cortex             0.306344
# embryo             0.564122
# endocrine gland    0.377778
# esophagus          0.211256
# exocrine gland     0.290557
# eye                0.464725
# fallopian tube     0.216293
# forelimb           0.043745
# gallbladder        0.054900
# heart              0.810413
# intestine          0.112326
# kidney             0.527241
# large intestine    0.175413
# liver              0.335570
# lung               0.355707
# lymph node         0.272199
# ovary              0.172791
# pancreas           0.159453
# placenta           0.309643
# prostate gland     0.179776
# small intestine    0.225156
# spinal cord        1.368588
# spleen             0.178039
# stomach            0.152942
# testis             1.075979
# uterus             0.113021
# Name: %Cells Expressing Gene, dtype: float64
#
# ✅STEP-2: Found 3054 clusters where ZNF624 is expressed above median.
#             Tissue         Cell Type  Cell Count Tissue Composition  \
# 27  adipose tissue  contractile cell       16234              0.05%
# 28  adipose tissue  contractile cell       16234              0.02%
# 29  adipose tissue  contractile cell       16234              0.03%
# 30  adipose tissue    dendritic cell        2534              0.01%
# 31  adipose tissue    dendritic cell        2534              0.00%
#
#    Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 27      ZNF624    1.883180            0.144580                      222.0
# 28    GOLGA6L9    1.812845            0.088964                       68.0
# 29       MTUS2    1.993625            0.130882                      132.0
# 30      ZNF624    1.860634            0.138019                       30.0
# 31    GOLGA6L9    1.784260            0.083001                        4.0
#
#     %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 27                1.367500           0.812943    1.367500
# 28                0.418874           0.272178    0.418874
# 29                0.813108           1.662092    0.813108
# 30                1.183899           0.639602    1.183899
# 31                0.157853           0.052410    0.157853
#
#     Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 27                0.670567           0.271186     0.869464           1.076537
# 28                0.562090           0.271186     0.446623           1.076537
# 29                0.840906           0.271186     0.715843           1.076537
# 30                0.635795           0.271186     0.782115           1.076537
# 31                0.518005           0.271186     0.324580           1.076537
#
#     POI_Expression_%  POI_Above_Median
# 27          1.367500              True
# 28          1.367500              True
# 29          1.367500              True
# 30          1.183899              True
# 31          1.183899              True
#
# ✅STEP-3: Found 100 interactors with ≥20% expression.
#              Tissue                                          Cell Type  \
# 116  adipose tissue                             neuron associated cell
# 986           brain                                    CNS interneuron
# 992           brain                              GABAergic interneuron
# 995           brain                                   GABAergic neuron
# 998           brain  L2/3 intratelencephalic projecting glutamaterg...
#
#      Cell Count Tissue Composition Gene Symbol  Expression  \
# 116        1900              0.09%       MTUS2    2.096780
# 986     1167505              4.35%       MTUS2    2.452852
# 992     1127440              4.26%       MTUS2    2.452156
# 995     1592020              5.54%       MTUS2    2.454788
# 998       41340              0.15%       MTUS2    1.939993
#
#      Expression, Scaled  Num_Cells_Expressing_Gene  %Cells Expressing Gene  \
# 116            0.153114                      388.0               20.421053
# 986            0.229855                   811649.0               69.519959
# 992            0.229705                   795629.0               70.569520
# 995            0.230272                  1033784.0               64.935365
# 998            0.119323                    28791.0               69.644412
#
#      Expression_Zscore  Robustness  Expression_Specificity  Cluster_Diversity  \
# 116           2.455188   20.421053                1.000000           0.271186
# 986           2.686689   69.519959                0.727019           0.774011
# 992           2.683616   70.569520                0.726539           0.774011
# 995           2.695234   64.935365                0.728354           0.774011
# 998           0.422917   69.644412                0.373461           0.774011
#
#      scRNA_score  Tissue_Median_Exp  POI_Expression_%  POI_Above_Median
# 116     8.622658           1.076537          1.947368              True
# 986    28.253594           0.525784          0.325309             False
# 992    28.673226           0.525784          0.290126             False
# 995    26.420290           0.525784          0.682655              True
# 998    28.161952           0.525784          0.106434             False
#
# ✅STEP-4: Found 39 valid POI-interactor pairs.
#             Tissue                Cell Type
# 0   adipose tissue   neuron associated cell
# 3            brain         GABAergic neuron
# 6            brain            Purkinje cell
# 9            brain  cerebellar granule cell
# 12           brain        cerebellar neuron
#
# ✅STEP-5: Filtered dataset now contains 117 rows.
#            Tissue               Cell Type  Cell Count Tissue Composition  \
# 0  adipose tissue  neuron associated cell        1900              0.01%
# 1  adipose tissue  neuron associated cell        1900              0.00%
# 2  adipose tissue  neuron associated cell        1900              0.09%
# 3           brain        GABAergic neuron     1592020              0.06%
# 4           brain        GABAergic neuron     1592020              0.02%
#
#   Gene Symbol  Expression  Expression, Scaled  Num_Cells_Expressing_Gene  \
# 0      ZNF624    1.856652            0.136860                       37.0
# 1    GOLGA6L9    2.028998            0.134054                       18.0
# 2       MTUS2    2.096780            0.153114                      388.0
# 3      ZNF624    2.022556            0.185141                    10868.0
# 4    GOLGA6L9    1.708350            0.067166                     2832.0
#
#    %Cells Expressing Gene  Expression_Zscore  Robustness  \
# 0                1.947368           0.608990    1.947368
# 1                0.947368           1.934053    0.947368
# 2               20.421053           2.455188   20.421053
# 3                0.682655           0.787350    0.682655
# 4                0.177887          -0.599561    0.177887
#
#    Expression_Specificity  Cluster_Diversity  scRNA_score  Tissue_Median_Exp  \
# 0                0.629654           0.271186     1.085046           1.076537
# 1                0.895461           0.271186     0.791369           1.076537
# 2                1.000000           0.271186     8.622658           1.076537
# 3                0.430379           0.774011     0.600016           0.525784
# 4                0.213770           0.774011     0.311465           0.525784
#
#    POI_Expression_%  POI_Above_Median
# 0          1.947368              True
# 1          1.947368              True
# 2          1.947368              True
# 3          0.682655              True
# 4          0.682655              True
#
# ✅STEP-7: Final dataset contains 39 rows after removing non-compensating interactors.
# ✅ Successfully saved H2 output: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/ZNF624_PPI_filtered_S2_H2_24042025.xlsx

# %% [markdown]
# Key confirmations:
#
# 1. All POI rows are first filtered for POI_Above_Median.
#
# df["POI_Above_Median"] = df["POI_Expression_%"] >= df["Tissue_Median_Exp"]
# Only True rows move to the next step (Step 2).
#
#
# 2. Only interactors with ≥20% expression are considered.
#
# interactors_present = df[(df["Gene Symbol"] != protein_of_interest) & (df["%Cells Expressing Gene"] >= WEAK_COMPENSATION)]
# If no interactors qualify, the file is skipped (Step 3).
#
#
# 3. Final filtering merges valid POI & interactors, ensuring that both conditions are met.
#
# df = df.merge(valid_interactions, on=["Tissue", "Cell Type"], how="inner")
# Only valid POI-interactor pairs are retained (Step 5).
#
#
# 4. The output will only contain PPIs where both conditions hold (Steps 6-7).
#
# POI expression is shown in the final file for reference (POI_Expression_%).
# Rows failing either condition are removed before saving.

# %%
#Just print the moderate & robust compensations in the notebook:

#Find all processed H2 files
h2_files = [f for f in os.listdir(output_dir) if f.endswith("_S2_H2_24042025.xlsx")]
len(h2_files)
# Out:
# 174

# %% [markdown]
# - We need to ensure that while filtering for Moderate & Robust Compensation, we retain weakly expressed interactors within the same cluster for context.
#
# - Also, instead of completely removing POI as an interactor, let's explicitly flag self-interactions so that they can be reviewed manually.
#
# - Updates for handling self-interactions:
#     - If POI is present as an interactor, mark it as "Self-Interaction" in a new column.
#     - Keep all cases in the output but differentiate them so you can review them later.
#     - Sorting remains unchanged, but self-interactions will be labeled clearly.
#     - Filters out H3 redundant cases at the end (Step-9) without affecting H2
#     - Renames %Cells Expressing Gene → %Cells Expressing Interactor
#     - Renames POI_Expression_% → %Cells Expressing POI
#     - Ensures sorting remains correct (R → M → W)

# %%
#let's retain all relevant columns, including Cell Count, so you have full flexibility
#Self_Interaction == "Yes" rows should be removed just before saving the Excel file.
#Refer to line-16 of PPI_CellxGene_H2_corr_27022025.ipynb 

#Process each file
for file in h2_files:
    file_path = os.path.join(output_dir, file)
    
    #Load the processed file
    df = pd.read_excel(file_path, engine="openpyxl")
    
    print(f"\n📂 Processing file: {file}")
    print(f"✅ Loaded {file} | Shape: {df.shape}")

    #Extract POI from filename
    protein_of_interest = file.split("_")[0]

    #Step 1: Identify clusters where at least one interactor is Moderate or Robust
    valid_clusters = df[df["Compensation Category"].isin(["Robust Compensation (≥50%)", "Moderate Compensation (30-49%)"])][["Tissue", "Cell Type"]].drop_duplicates()

    if valid_clusters.empty:
        print(f"⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in {file}. Skipping...\n")
        continue

    #Step 2: Retain all interactors (including weak ones) in these clusters
    filtered_df = df.merge(valid_clusters, on=["Tissue", "Cell Type"], how="inner")

    print(f"✅ Found {len(filtered_df)} total interactors in clusters with at least one Moderate/Robust Compensation.")

    #Step 3: Construct the PPI column (POI-Interactor Pair)
    filtered_df["PPI"] = protein_of_interest + "-" + filtered_df["Gene Symbol"]  #Format: POI-Interactor (e.g., STXBP1-STX5)

    #Step 4: Assign W, M, R for Compensation Category (Fixing Mapping Issue)
    category_mapping = {
        "Robust Compensation (≥50%)": "R",
        "Moderate Compensation (30-49%)": "M",
        "Weak Compensation (20-29%)": "W"
    }

    #Standardize category column before mapping
    filtered_df["Compensation Category"] = filtered_df["Compensation Category"].astype(str).str.strip()

    #Map category names
    filtered_df["Comp_Category"] = filtered_df["Compensation Category"].map(category_mapping)

    #Handle missing values (should not happen, but just in case)
    filtered_df["Comp_Category"] = filtered_df["Comp_Category"].fillna("Unknown")

    #Step 5: Flag Self-Interactions
    filtered_df["Self_Interaction"] = filtered_df["Gene Symbol"].apply(lambda x: "Yes" if x == protein_of_interest else "No")

    #Step 6: Rename columns for consistency
    filtered_df.rename(columns={
        "%Cells Expressing Gene": "%Cells Expressing Interactor",
        "POI_Expression_%": "%Cells Expressing POI"
    }, inplace=True)

    #Step 7: Select only required columns (PPI-related & Cell Count)
    output_cols = ["Tissue", "Cell Type", "Cell Count", "PPI", "%Cells Expressing POI", "%Cells Expressing Interactor", "Comp_Category", "Self_Interaction"]
    final_df = filtered_df[output_cols]  #Retain only relevant columns

    #Step 8: Sort by Tissue → Cell Type → Compensation (R → M → W)
    comp_rank = {"R": 1, "M": 2, "W": 3}
    final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)

    sorted_df = final_df.sort_values(by=["Tissue", "Cell Type", "Comp_Rank"],
                                     ascending=[True, True, True]).drop(columns=["Comp_Rank"])

    #Step 9: **Exclude H3 redundant cases (where both POI & Interactor are ≥30%)** => very important to avoid redundancy 
    sorted_df = sorted_df[~((sorted_df["%Cells Expressing POI"] >= 30) & 
                            (sorted_df["%Cells Expressing Interactor"] >= 30))]

    print(f"✅ Removed H3 redundant cases. Final dataset contains {len(sorted_df)} rows.")

    #Step 10: Print first 10 rows for quick verification
    print(sorted_df.head(10)) 

    #Step 11: Remove Self-Interactions before saving the files
    sorted_df = sorted_df[sorted_df["Self_Interaction"] != "Yes"]

    #Step 12: Save the sorted version
    sorted_file_path = os.path.join(output_dir, file.replace("_S2_H2_24042025.xlsx", "_Sorted_S2_H2_24042025.xlsx"))
    sorted_df.to_excel(sorted_file_path, index=False, engine="openpyxl")

    print(f"✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): {sorted_file_path}\n")
# Out:
# 📂 Processing file: EIF2B1_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded EIF2B1_PPI_filtered_S2_H2_24042025.xlsx | Shape: (12, 18)
# ✅ Found 1 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 1 rows.
#     Tissue       Cell Type  Cell Count          PPI  %Cells Expressing POI  \
# 0  stomach  malignant cell        1040  EIF2B1-ATF5              11.634615
#
#    %Cells Expressing Interactor Comp_Category Self_Interaction
# 0                     56.153846             R               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/EIF2B1_PPI_filtered_Sorted_S2_H2_24042025.xlsx
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# 📂 Processing file: EFHC1_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded EFHC1_PPI_filtered_S2_H2_24042025.xlsx | Shape: (2189, 18)
# ✅ Found 1980 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 1940 rows.
#            Tissue                             Cell Type  Cell Count  \
# 0  adipose tissue                connective tissue cell      188588
# 1  adipose tissue                connective tissue cell      188588
# 2  adipose tissue                      contractile cell       16234
# 3  adipose tissue                      contractile cell       16234
# 5  adipose tissue                      endothelial cell       45303
# 4  adipose tissue                      endothelial cell       45303
# 7  adipose tissue  endothelial cell of lymphatic vessel        6146
# 6  adipose tissue  endothelial cell of lymphatic vessel        6146
# 8  adipose tissue                       epithelial cell      109540
# 9  adipose tissue                       epithelial cell      109540
#
#           PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0  EFHC1-PBX1               8.174433                     66.802766
# 1  EFHC1-TCF4               8.174433                     45.168834
# 2  EFHC1-PBX1               5.771837                     51.287421
# 3  EFHC1-TCF4               5.771837                     48.546261
# 5  EFHC1-TCF4               7.059135                     83.813434
# 4  EFHC1-PBX1               7.059135                     39.023906
# 7  EFHC1-TCF4               9.729906                     73.299707
# 6  EFHC1-PBX1               9.729906                     34.184836
# 8  EFHC1-PBX1              13.659850                     65.575132
# 9  EFHC1-TCF4              13.659850                     55.215446
#
#   Comp_Category Self_Interaction
# 0             R               No
# 1             M               No
# 2             R               No
# 3             M               No
# 5             R               No
# 4             M               No
# 7             R               No
# 6             M               No
# 8             R               No
# 9             R               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/EFHC1_PPI_filtered_Sorted_S2_H2_24042025.xlsx
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# 📂 Processing file: PUF60_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded PUF60_PPI_filtered_S2_H2_24042025.xlsx | Shape: (1715, 18)
# ✅ Found 1331 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 1304 rows.
#            Tissue                        Cell Type  Cell Count           PPI  \
# 0  adipose tissue                           B cell       16003     PUF60-SF1
# 1  adipose tissue                           B cell       16003  PUF60-SRSF11
# 2  adipose tissue  CD4-positive, alpha-beta T cell       11653     PUF60-SF1
# 3  adipose tissue  CD4-positive, alpha-beta T cell       11653  PUF60-SRSF11
# 4  adipose tissue  CD8-positive, alpha-beta T cell        5441     PUF60-SF1
# 5  adipose tissue  CD8-positive, alpha-beta T cell        5441  PUF60-SRSF11
# 6  adipose tissue                           T cell       31314     PUF60-SF1
# 7  adipose tissue                           T cell       31314  PUF60-SRSF11
# 8  adipose tissue                alpha-beta T cell       20182     PUF60-SF1
# 9  adipose tissue                alpha-beta T cell       20182  PUF60-SRSF11
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               1.612198                     48.809598             M
# 1               1.612198                     28.319690             W
# 2               2.351326                     50.931091             R
# 3               2.351326                     30.309791             M
# 4               3.528763                     39.606690             M
# 5               3.528763                     32.824848             M
# 6               2.573929                     36.817398             M
# 7               2.573929                     36.862106             M
# 8               2.893668                     43.538797             M
# 9               2.893668                     32.742047             M
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/PUF60_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: ASNS_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded ASNS_PPI_filtered_S2_H2_24042025.xlsx | Shape: (2, 18)
# ⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in ASNS_PPI_filtered_S2_H2_24042025.xlsx. Skipping...
#
#
# 📂 Processing file: PITX1_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded PITX1_PPI_filtered_S2_H2_24042025.xlsx | Shape: (844, 18)
# ✅ Found 794 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 750 rows.
#            Tissue                                        Cell Type  \
# 0  adipose tissue                                   dendritic cell
# 1   adrenal gland                         ciliated epithelial cell
# 2   adrenal gland                                 endothelial cell
# 3   adrenal gland                                       enterocyte
# 4           blood                                           B cell
# 5           blood                           CD14-positive monocyte
# 6           blood  CD14-positive, CD16-negative classical monocyte
# 7           blood                  CD8-positive, alpha-beta T cell
# 8           blood               CD8-positive, alpha-beta thymocyte
# 9           blood               CD8-positive, alpha-beta thymocyte
#
#    Cell Count          PPI  %Cells Expressing POI  \
# 0        2534  PITX1-PFDN5               0.118390
# 1        1558  PITX1-PFDN5               0.385109
# 2        4262  PITX1-PFDN5               0.070389
# 3        1250  PITX1-PFDN5               0.480000
# 4     1418907  PITX1-PFDN5               0.077947
# 5      980345  PITX1-PFDN5               0.061917
# 6      257951  PITX1-PFDN5               0.220585
# 7     1712602  PITX1-PFDN5               0.072404
# 8        2618  PITX1-PFDN5               0.152788
# 9        2618  PITX1-YPEL3               0.152788
#
#    %Cells Expressing Interactor Comp_Category Self_Interaction
# 0                     32.280979             M               No
# 1                     76.829268             R               No
# 2                     32.167996             M               No
# 3                     72.960000             R               No
# 4                     82.899513             R               No
# 5                     81.691955             R               No
# 6                     95.063791             R               No
# 7                     86.322158             R               No
# 8                     95.874714             R               No
# 9                     28.838808             W               No
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/PITX1_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: FOXP3_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded FOXP3_PPI_filtered_S2_H2_24042025.xlsx | Shape: (520, 18)
# ✅ Found 369 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 366 rows.
#            Tissue                        Cell Type  Cell Count         PPI  \
# 0  adipose tissue  CD4-positive, alpha-beta T cell       11653  FOXP3-FOSB
# 1  adipose tissue                           T cell       31314  FOXP3-FOSB
# 2  adipose tissue                alpha-beta T cell       20182  FOXP3-FOSB
# 3  adipose tissue                   dendritic cell        2534  FOXP3-FOSB
# 4  adipose tissue               hematopoietic cell      121993  FOXP3-FOSB
# 5  adipose tissue                        leukocyte      118505  FOXP3-FOSB
# 6  adipose tissue                       lymphocyte       50559  FOXP3-FOSB
# 7  adipose tissue                       macrophage       55294  FOXP3-FOSB
# 8  adipose tissue                        mast cell        2725  FOXP3-FOSB
# 9  adipose tissue         mature alpha-beta T cell       17631  FOXP3-FOSB
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               0.858148                     51.042650             R
# 1               0.558855                     35.821039             M
# 2               0.520266                     45.907244             M
# 3               0.197316                     36.621942             M
# 4               0.200831                     38.998139             M
# 5               0.206742                     39.309734             M
# 6               0.361953                     38.798236             M
# 7               0.083192                     40.989981             M
# 8               0.146789                     40.000000             M
# 9               0.584198                     50.762861             R
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/FOXP3_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: THAP1_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded THAP1_PPI_filtered_S2_H2_24042025.xlsx | Shape: (42, 18)
# ✅ Found 29 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 29 rows.
#   Tissue                                       Cell Type  Cell Count  \
# 0  brain               L6b glutamatergic cortical neuron       74181
# 1  brain  caudal ganglionic eminence derived interneuron       39708
# 2  brain                         cerebellar granule cell       68864
# 3  brain               cerebellar granule cell precursor        4957
# 4  brain                               cerebellar neuron      361299
# 5  brain                 cerebellum glutamatergic neuron       69787
# 6  brain                             dopaminergic neuron       15507
# 7  brain                                    granule cell      144972
# 8  brain                                     interneuron     1375242
# 9  brain                                     neural cell    16427319
#
#            PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0  THAP1-RALYL               1.322441                     80.613634
# 1  THAP1-RALYL               0.982170                     59.771331
# 2  THAP1-RALYL               1.333062                     90.617739
# 3  THAP1-RALYL               0.726246                     84.083115
# 4  THAP1-RALYL               0.712153                     89.348711
# 5  THAP1-RALYL               1.349822                     89.614112
# 6  THAP1-RALYL               1.618624                     43.167602
# 7  THAP1-RALYL               0.753249                     86.680876
# 8  THAP1-RALYL               0.763647                     35.659469
# 9  THAP1-RALYL               0.759613                     48.781928
#
#   Comp_Category Self_Interaction
# 0             R               No
# 1             R               No
# 2             R               No
# 3             R               No
# 4             R               No
# 5             R               No
# 6             M               No
# 7             R               No
# 8             M               No
# 9             M               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/THAP1_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: SFTPB_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded SFTPB_PPI_filtered_S2_H2_24042025.xlsx | Shape: (13, 18)
# ✅ Found 5 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 5 rows.
#            Tissue         Cell Type  Cell Count          PPI  \
# 0  adipose tissue  endothelial cell       45303  SFTPB-MEOX2
# 1  adipose tissue   epithelial cell      109540  SFTPB-MEOX2
# 2  adipose tissue        mural cell       10411  SFTPB-MEOX2
# 3  adipose tissue          pericyte        7345  SFTPB-MEOX2
# 4            lung      stromal cell       15361  SFTPB-MEOX2
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               0.103746                     38.425711             M
# 1               0.084900                     30.937557             M
# 2               0.076842                     31.188166             M
# 3               0.068074                     30.728387             M
# 4              10.747998                     34.476922             M
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/SFTPB_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: ANKRD1_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded ANKRD1_PPI_filtered_S2_H2_24042025.xlsx | Shape: (6, 18)
# ⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in ANKRD1_PPI_filtered_S2_H2_24042025.xlsx. Skipping...
#
#
# 📂 Processing file: NCF2_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded NCF2_PPI_filtered_S2_H2_24042025.xlsx | Shape: (13, 18)
# ⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in NCF2_PPI_filtered_S2_H2_24042025.xlsx. Skipping...
#
#
# 📂 Processing file: KRT8_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded KRT8_PPI_filtered_S2_H2_24042025.xlsx | Shape: (98, 18)
# ✅ Found 97 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 25 rows.
#              Tissue                                          Cell Type  \
# 1            breast                                    epithelial cell
# 6            breast  luminal adaptive secretory precursor cell of m...
# 8            breast           luminal epithelial cell of mammary gland
# 10           breast                      mammary gland epithelial cell
# 13           breast                                     precursor cell
# 16           breast                                    progenitor cell
# 20  endocrine gland                               endo-epithelial cell
# 22  endocrine gland                          epithelial cell of thymus
# 30        esophagus                               endo-epithelial cell
# 29        esophagus                               endo-epithelial cell
#
#     Cell Count         PPI  %Cells Expressing POI  \
# 1      1243928  KRT8-KRT15              45.198999
# 6       308347  KRT8-KRT16              58.774692
# 8       676178  KRT8-KRT15              67.446442
# 10      889158  KRT8-KRT15              61.354450
# 13      462068  KRT8-KRT16              55.092540
# 16      329489  KRT8-KRT16              58.977993
# 20       43159  KRT8-KRT15              61.294284
# 22       39108  KRT8-KRT15              61.125601
# 30       24068  KRT8-KRT15              28.764334
# 29       24068   KRT8-KRT8              28.764334
#
#     %Cells Expressing Interactor Comp_Category Self_Interaction
# 1                      20.363478             W               No
# 6                      27.855306             W               No
# 8                      29.990772             W               No
# 10                     27.686643             W               No
# 13                     20.480102             W               No
# 16                     26.181754             W               No
# 20                     25.568248             W               No
# 22                     28.203948             W               No
# 30                     31.078611             M               No
# 29                     28.764334             W              Yes
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/KRT8_PPI_filtered_Sorted_S2_H2_24042025.xlsx
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# 📂 Processing file: GLYCTK_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded GLYCTK_PPI_filtered_S2_H2_24042025.xlsx | Shape: (1524, 18)
# ✅ Found 1389 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 1389 rows.
#            Tissue                         Cell Type  Cell Count  \
# 0  adipose tissue                         adipocyte       72587
# 1  adipose tissue       adipocyte of omentum tissue       15436
# 3  adipose tissue                    dendritic cell        2534
# 2  adipose tissue                    dendritic cell        2534
# 4  adipose tissue  fibro/adipogenic progenitor cell       15985
# 5  adipose tissue                hematopoietic cell      121993
# 6  adipose tissue              innate lymphoid cell        1031
# 7  adipose tissue                         leukocyte      118505
# 8  adipose tissue                        lymphocyte       50559
# 9  adipose tissue                        macrophage       55294
#
#               PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0  GLYCTK-METTL15               0.877568                     30.888451
# 1  GLYCTK-METTL15               0.978233                     30.104949
# 3      GLYCTK-REL               0.868193                     55.327545
# 2    GLYCTK-PFDN5               0.868193                     32.280979
# 4  GLYCTK-METTL15               0.675633                     30.503597
# 5      GLYCTK-REL               0.823818                     36.139779
# 6      GLYCTK-REL               0.969932                     50.436469
# 7      GLYCTK-REL               0.835408                     36.870174
# 8      GLYCTK-REL               0.739730                     40.226270
# 9      GLYCTK-REL               0.938619                     32.743155
#
#   Comp_Category Self_Interaction
# 0             M               No
# 1             M               No
# 3             R               No
# 2             M               No
# 4             M               No
# 5             M               No
# 6             R               No
# 7             M               No
# 8             M               No
# 9             M               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/GLYCTK_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: LHFPL5_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded LHFPL5_PPI_filtered_S2_H2_24042025.xlsx | Shape: (188, 18)
# ✅ Found 132 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 132 rows.
#            Tissue                             Cell Type  Cell Count  \
# 0  adipose tissue                            blood cell        3586
# 1  adipose tissue                neuron associated cell        1900
# 2  adipose tissue                            neutrophil        3456
# 3           blood                                B cell     1418907
# 4           blood                           granulocyte       38067
# 5           blood               lymphocyte of B lineage     1447936
# 6           blood                         mature B cell      505431
# 7           blood                          naive B cell      332595
# 8           blood                            neutrophil       36783
# 9           blood  professional antigen presenting cell      649672
#
#              PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0  LHFPL5-ADGRG3               2.481874                     69.408812
# 1  LHFPL5-LRRC4C               2.263158                     40.421053
# 2  LHFPL5-ADGRG3               2.575231                     71.961806
# 3   LHFPL5-CD79A               0.218196                     84.546133
# 4  LHFPL5-ADGRG3               3.443928                     52.447001
# 5   LHFPL5-CD79A               0.215894                     83.893349
# 6   LHFPL5-CD79A               0.163425                     78.856461
# 7   LHFPL5-CD79A               0.227303                     77.687578
# 8  LHFPL5-ADGRG3               3.561428                     54.130984
# 9   LHFPL5-CD79A               0.132528                     61.678662
#
#   Comp_Category Self_Interaction
# 0             R               No
# 1             M               No
# 2             R               No
# 3             R               No
# 4             R               No
# 5             R               No
# 6             R               No
# 7             R               No
# 8             R               No
# 9             R               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/LHFPL5_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: HMBS_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded HMBS_PPI_filtered_S2_H2_24042025.xlsx | Shape: (1, 18)
# ⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in HMBS_PPI_filtered_S2_H2_24042025.xlsx. Skipping...
#
#
# 📂 Processing file: FAM187A_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded FAM187A_PPI_filtered_S2_H2_24042025.xlsx | Shape: (2, 18)
# ✅ Found 2 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 2 rows.
#   Tissue                          Cell Type  Cell Count            PPI  \
# 0   lung    alveolar type 1 fibroblast cell       44503  FAM187A-MEOX2
# 1   lung  pulmonary interstitial fibroblast       73054  FAM187A-MEOX2
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               0.002247                     31.454059             M
# 1               0.001369                     30.577381             M
#
#   Self_Interaction
# 0               No
# 1               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/FAM187A_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: SYNGR1_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded SYNGR1_PPI_filtered_S2_H2_24042025.xlsx | Shape: (198, 18)
# ✅ Found 94 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 64 rows.
#             Tissue                                  Cell Type  Cell Count  \
# 0   adipose tissue           fibro/adipogenic progenitor cell       15985
# 1    adrenal gland            CD8-positive, alpha-beta T cell        4761
# 3      bone marrow              basophil mast progenitor cell        2217
# 2      bone marrow              basophil mast progenitor cell        2217
# 9      bone marrow                 common lymphoid progenitor        3531
# 8      bone marrow                 common lymphoid progenitor        3531
# 11     bone marrow                  common myeloid progenitor       12587
# 10     bone marrow                  common myeloid progenitor       12587
# 12     bone marrow                             dendritic cell       20095
# 21     bone marrow  hematopoietic multipotent progenitor cell       18406
#
#                PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0   SYNGR1-TMEM14B               2.327182                     32.724429
# 1   SYNGR1-TMEM14B               7.246377                     30.896870
# 3   SYNGR1-TMEM14B              22.011728                     43.572395
# 2    SYNGR1-SYNGR1              22.011728                     22.011728
# 9   SYNGR1-TMEM14B              23.449448                     43.557066
# 8    SYNGR1-SYNGR1              23.449448                     23.449448
# 11  SYNGR1-TMEM14B              24.310797                     52.689283
# 10   SYNGR1-SYNGR1              24.310797                     24.310797
# 12  SYNGR1-TMEM14B               8.310525                     34.735009
# 21  SYNGR1-TMEM14B              16.668478                     32.315549
#
#    Comp_Category Self_Interaction
# 0              M               No
# 1              M               No
# 3              M               No
# 2              W              Yes
# 9              M               No
# 8              W              Yes
# 11             R               No
# 10             W              Yes
# 12             M               No
# 21             M               No
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/SYNGR1_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: RP2_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded RP2_PPI_filtered_S2_H2_24042025.xlsx | Shape: (222, 18)
# ✅ Found 65 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 65 rows.
#            Tissue                                        Cell Type  \
# 1  adipose tissue                                       blood cell
# 0  adipose tissue                                       blood cell
# 2  adipose tissue                             innate lymphoid cell
# 3  adipose tissue                              natural killer cell
# 5  adipose tissue                                       neutrophil
# 4  adipose tissue                                       neutrophil
# 6   adrenal gland                  CD4-positive, alpha-beta T cell
# 7   adrenal gland                  CD8-positive, alpha-beta T cell
# 8   adrenal gland  effector memory CD8-positive, alpha-beta T cell
# 9   adrenal gland                               hematopoietic cell
#
#    Cell Count        PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 1        3586  RP2-OSTF1              23.340770                     35.582822
# 0        3586    RP2-RP2              23.340770                     23.340770
# 2        1031  RP2-OSTF1               2.424830                     31.813773
# 3        1022  RP2-OSTF1               2.446184                     31.898239
# 5        3456  RP2-OSTF1              24.218750                     36.921296
# 4        3456    RP2-RP2              24.218750                     24.218750
# 6        1418  RP2-OSTF1               3.314528                     33.568406
# 7        4761  RP2-OSTF1               3.297627                     43.541273
# 8        1069  RP2-OSTF1               4.864359                     52.572498
# 9       16124  RP2-OSTF1               3.262218                     30.550732
#
#   Comp_Category Self_Interaction
# 1             M               No
# 0             W              Yes
# 2             M               No
# 3             M               No
# 5             M               No
# 4             W              Yes
# 6             M               No
# 7             M               No
# 8             R               No
# 9             M               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/RP2_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: GCK_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded GCK_PPI_filtered_S2_H2_24042025.xlsx | Shape: (2, 18)
# ⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in GCK_PPI_filtered_S2_H2_24042025.xlsx. Skipping...
#
#
# 📂 Processing file: CTNNA3_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded CTNNA3_PPI_filtered_S2_H2_24042025.xlsx | Shape: (393, 18)
# ✅ Found 263 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 217 rows.
#             Tissue                        Cell Type  Cell Count           PPI  \
# 1   adipose tissue                   dendritic cell        2534    CTNNA3-REL
# 0   adipose tissue                   dendritic cell        2534  CTNNA3-DISC1
# 4   adipose tissue                        mast cell        2725  CTNNA3-DISC1
# 5   adipose tissue                         monocyte        3769  CTNNA3-DISC1
# 6   adipose tissue                         monocyte        3769    CTNNA3-REL
# 10  adipose tissue           neuron associated cell        1900  CTNNA3-DISC1
# 11  adipose tissue                   secretory cell        2726  CTNNA3-DISC1
# 12   bladder organ  CD8-positive, alpha-beta T cell        4432    CTNNA3-REL
# 13   bladder organ                           T cell        7530    CTNNA3-REL
# 14   bladder organ          bladder urothelial cell       27240    CTNNA3-JUP
#
#     %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 1                6.866614                     55.327545             R
# 0                6.866614                     36.621942             M
# 4                8.660550                     32.660550             M
# 5                4.430884                     33.616344             M
# 6                4.430884                     45.608915             M
# 10              52.684211                     21.421053             W
# 11               8.657373                     32.648569             M
# 12               0.180505                     43.907942             M
# 13               0.185923                     38.605578             M
# 14               0.187225                     43.384728             M
#
#    Self_Interaction
# 1                No
# 0                No
# 4                No
# 5                No
# 6                No
# 10               No
# 11               No
# 12               No
# 13               No
# 14               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/CTNNA3_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: PLN_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded PLN_PPI_filtered_S2_H2_24042025.xlsx | Shape: (333, 18)
# ✅ Found 175 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 166 rows.
#            Tissue                        Cell Type  Cell Count         PPI  \
# 0  adipose tissue                           T cell       31314  PLN-CLEC2D
# 1  adipose tissue               immature NK T cell        2551  PLN-CLEC2D
# 2  adipose tissue                       lymphocyte       50559  PLN-CLEC2D
# 3   adrenal gland   cortical cell of adrenal gland       91988     PLN-EDA
# 4   adrenal gland        glandular epithelial cell       92005     PLN-EDA
# 5   adrenal gland                   secretory cell       97999     PLN-EDA
# 6   bladder organ  CD8-positive, alpha-beta T cell        4432  PLN-CLEC2D
# 7   bladder organ                           T cell        7530  PLN-CLEC2D
# 8   bladder organ                       lymphocyte        9386  PLN-CLEC2D
# 9   bladder organ                    mature T cell        6739  PLN-CLEC2D
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               0.875008                     43.437440             M
# 1               0.901607                     49.470796             M
# 2               0.642813                     33.465852             M
# 3               0.594643                     32.043310             M
# 4               0.594533                     32.037389             M
# 5               0.573475                     30.254390             M
# 6               0.383574                     45.758123             M
# 7               0.265604                     45.152722             M
# 8               0.223737                     37.715747             M
# 9               0.281941                     45.689271             M
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/PLN_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: GCM2_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded GCM2_PPI_filtered_S2_H2_24042025.xlsx | Shape: (37, 18)
# ✅ Found 19 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 19 rows.
#    Tissue                         Cell Type  Cell Count         PPI  \
# 0   brain  cerebral cortex endothelial cell        6010  GCM2-USP54
# 1   brain                  endothelial cell       77438  GCM2-USP54
# 2   brain                        glial cell     5378077  GCM2-USP54
# 3   brain                   macroglial cell     4076209  GCM2-USP54
# 4   brain            neuron associated cell     5408654  GCM2-USP54
# 5   brain                   oligodendrocyte     2889040  GCM2-USP54
# 6   brain    oligodendrocyte precursor cell      481160  GCM2-USP54
# 7   brain                   progenitor cell      575959  GCM2-USP54
# 8  embryo              cortical interneuron        4067   GCM2-TOX3
# 9  embryo              forebrain neuroblast        4039   GCM2-TOX3
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               0.016639                     45.607321             M
# 1               0.024536                     31.878406             M
# 2               0.034455                     45.558273             M
# 3               0.042417                     59.211046             R
# 4               0.034297                     45.343389             M
# 5               0.041052                     75.957065             R
# 6               0.059855                     49.671211             M
# 7               0.050872                     41.605392             M
# 8               0.270470                     44.676666             M
# 9               0.272345                     44.788314             M
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/GCM2_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: IRAK4_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded IRAK4_PPI_filtered_S2_H2_24042025.xlsx | Shape: (6, 18)
# ✅ Found 1 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 1 rows.
#    Tissue   Cell Type  Cell Count          PPI  %Cells Expressing POI  \
# 0  embryo  glial cell        2770  IRAK4-TRIM7               6.137184
#
#    %Cells Expressing Interactor Comp_Category Self_Interaction
# 0                     32.924188             M               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/IRAK4_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: CDKN2C_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded CDKN2C_PPI_filtered_S2_H2_24042025.xlsx | Shape: (124, 18)
# ✅ Found 47 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 47 rows.
#            Tissue                          Cell Type  Cell Count          PPI  \
# 0  adipose tissue                    epithelial cell      109540  CDKN2C-CDK6
# 1  adipose tissue                   mesothelial cell       64233  CDKN2C-CDK6
# 2   adrenal gland                    chromaffin cell        5943  CDKN2C-CDK6
# 3   adrenal gland  columnar/cuboidal epithelial cell        7501  CDKN2C-CDK6
# 4   adrenal gland                     endocrine cell        5974  CDKN2C-CDK6
# 5   adrenal gland                        neural cell        7610  CDKN2C-CDK6
# 6   adrenal gland                             neuron        7498  CDKN2C-CDK6
# 7           blood                    IgG plasmablast        1030  CDKN2C-CDK6
# 8           blood         common lymphoid progenitor        7972  CDKN2C-CDK6
# 9           blood                   early pro-B cell       32221  CDKN2C-CDK6
#
#    %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               0.985941                     32.512324             M
# 1               0.882724                     39.450127             M
# 2               2.658590                     50.950698             R
# 3               2.439675                     40.874550             M
# 4               2.644794                     50.719786             R
# 5               2.378449                     42.509855             M
# 6               2.333956                     42.704721             M
# 7               4.174757                     30.582524             M
# 8               0.940793                     66.093828             R
# 9               0.744856                     75.186990             R
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/CDKN2C_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: DOLK_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded DOLK_PPI_filtered_S2_H2_24042025.xlsx | Shape: (108, 18)
# ✅ Found 65 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 65 rows.
#            Tissue                             Cell Type  Cell Count  \
# 0  adipose tissue  professional antigen presenting cell       57968
# 1   adrenal gland        cortical cell of adrenal gland       91988
# 2   adrenal gland             glandular epithelial cell       92005
# 3   adrenal gland                        secretory cell       97999
# 4           blood                                B cell     1418907
# 5           blood                         abnormal cell        2628
# 6           blood          class switched memory B cell       18834
# 7           blood               lymphocyte of B lineage     1447936
# 8           blood                        malignant cell        2291
# 9           blood                         mature B cell      505431
#
#           PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0    DOLK-EDA               0.220811                     42.152567
# 1    DOLK-EDA               0.737053                     32.043310
# 2    DOLK-EDA               0.738003                     32.037389
# 3    DOLK-EDA               0.734701                     30.254390
# 4  DOLK-CD79A               0.280709                     84.546133
# 5  DOLK-CD79A               0.342466                     81.963470
# ...
# 8               0.062138                     73.728620             R
# 9               0.009159                     48.543689             M
#
#   Self_Interaction
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/NR0B1_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: SFTPA2_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded SFTPA2_PPI_filtered_S2_H2_24042025.xlsx | Shape: (1, 18)
# ⚠️ No valid interactor-driven Robust or Moderate Compensation cases found in SFTPA2_PPI_filtered_S2_H2_24042025.xlsx. Skipping...
#
#
# 📂 Processing file: ANXA11_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded ANXA11_PPI_filtered_S2_H2_24042025.xlsx | Shape: (49, 18)
# ✅ Found 24 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 12 rows.
#              Tissue                   Cell Type  Cell Count            PPI  \
# 0    exocrine gland              malignant cell        3974   ANXA11-FUBP1
# 2            kidney        endo-epithelial cell        4731   ANXA11-FUBP1
# 4            kidney         taste receptor cell        4728   ANXA11-FUBP1
# 8              lung            cytotoxic T cell        2512   ANXA11-FUBP1
# 7              lung            cytotoxic T cell        2512  ANXA11-ANXA11
# 14       lymph node                  fibroblast        2271   ANXA11-FUBP1
# 16       lymph node           muscle fibroblast        1991   ANXA11-FUBP1
# 18  small intestine  epithelial cell of stomach        1432   ANXA11-FUBP1
# 20  small intestine              malignant cell        1814   ANXA11-FUBP1
# 19  small intestine              malignant cell        1814  ANXA11-ANXA11
#
#     %Cells Expressing POI  %Cells Expressing Interactor Comp_Category  \
# 0               17.991948                     34.650226             M
# 2               32.065103                     20.418516             W
# 4               32.064298                     20.431472             W
# 8               28.343949                     33.957006             M
# 7               28.343949                     28.343949             W
# 14              30.339058                     25.891678             W
# 16              32.044199                     28.628830             W
# 18              41.201117                     25.139665             W
# 20              22.105843                     35.722161             M
# 19              22.105843                     22.105843             W
#
#    Self_Interaction
# 0                No
# 2                No
# 4                No
# 8                No
# 7               Yes
# 14               No
# 16               No
# 18               No
# 20               No
# 19              Yes
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/ANXA11_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: KRT4_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded KRT4_PPI_filtered_S2_H2_24042025.xlsx | Shape: (71, 18)
# ✅ Found 59 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 32 rows.
#              Tissue                                  Cell Type  Cell Count  \
# 0            breast                             precursor cell      462068
# 1            breast                             precursor cell      462068
# 2   endocrine gland           medullary thymic epithelial cell       14983
# 3   endocrine gland    medullary thymic epithelial cell type 1        3535
# 7         esophagus                                     T cell        2394
# 12        esophagus                       endo-epithelial cell       24068
# 30   exocrine gland                                 basal cell       11143
# 31   exocrine gland  basal-myoepithelial cell of mammary gland        3884
# 32   exocrine gland                       duct epithelial cell       22206
# 33   exocrine gland              mammary gland epithelial cell       19589
#
#            PPI  %Cells Expressing POI  %Cells Expressing Interactor  \
# 0   KRT4-KRT15               0.012769                     35.792567
# 1   KRT4-KRT16               0.012769                     20.480102
# 2   KRT4-KRT15               1.541747                     50.951078
# 3   KRT4-KRT15               0.028289                     74.314003
# 7   KRT4-KRT16              34.419382                     28.529657
# 12  KRT4-KRT16              69.906099                     26.105202
# 30  KRT4-KRT15               1.256394                     69.963206
# 31  KRT4-KRT15               0.463440                     32.826982
# 32  KRT4-KRT15               0.054039                     35.828155
# 33  KRT4-KRT15               0.091888                     39.358824
#
#    Comp_Category Self_Interaction
# 0              M               No
# 1              W               No
# 2              R               No
# 3              R               No
# 7              W               No
# 12             W               No
# 30             R               No
# 31             M               No
# 32             M               No
# 33             M               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/KRT4_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: DIABLO_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded DIABLO_PPI_filtered_S2_H2_24042025.xlsx | Shape: (466, 18)
# ✅ Found 162 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 162 rows.
#           Tissue                                          Cell Type  \
# 2  adrenal gland                    CD4-positive, alpha-beta T cell
# 0  adrenal gland                    CD4-positive, alpha-beta T cell
# 1  adrenal gland                    CD4-positive, alpha-beta T cell
# 4          blood  CD16-positive, CD56-dim natural killer cell, h...
# 3          blood  CD16-positive, CD56-dim natural killer cell, h...
# 6          blood           effector CD8-positive, alpha-beta T cell
# 5          blood           effector CD8-positive, alpha-beta T cell
# 7          blood  effector memory CD8-positive, alpha-beta T cel...
# 8    bone marrow                             CD14-positive monocyte
# 9    bone marrow              CD14-positive, CD16-positive monocyte
#
#    Cell Count             PPI  %Cells Expressing POI  \
# 2        1418   DIABLO-RHBDD2              11.001410
# 0        1418  DIABLO-ARL6IP1              11.001410
# 1        1418     DIABLO-MPC2              11.001410
# 4      300326  DIABLO-ARL6IP1               2.076410
# 3      300326   DIABLO-AGTRAP               2.076410
# 6       62479  DIABLO-ARL6IP1               2.200739
# 5       62479   DIABLO-AGTRAP               2.200739
# 7        7775  DIABLO-ARL6IP1               1.311897
# 8       39362   DIABLO-AGTRAP               1.006046
# 9        4996   DIABLO-AGTRAP               1.321057
#
#    %Cells Expressing Interactor Comp_Category Self_Interaction
# 2                     33.921016             M               No
# 0                     21.791255             W               No
# 1                     29.055007             W               No
# 4                     30.155564             M               No
# 3                     21.061447             W               No
# 6                     34.560412             M               No
# 5                     20.157173             W               No
# 7                     33.054662             M               No
# 8                     39.378080             M               No
# 9                     30.664532             M               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/DIABLO_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: TRIM32_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded TRIM32_PPI_filtered_S2_H2_24042025.xlsx | Shape: (638, 18)
# ✅ Found 275 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 275 rows.
#           Tissue                                          Cell Type  \
# 0  adrenal gland                    CD8-positive, alpha-beta T cell
# 1  adrenal gland                                             T cell
# 2  adrenal gland    effector memory CD8-positive, alpha-beta T cell
# 3  adrenal gland                                      mature T cell
# 4  adrenal gland                           mature alpha-beta T cell
# 5  adrenal gland                                      memory T cell
# 6          blood  CD16-positive, CD56-dim natural killer cell, h...
# 7          blood          CD8-positive, alpha-beta cytotoxic T cell
# 8          blood                 CD8-positive, alpha-beta thymocyte
# 9          blood                                    IgG plasmablast
#
#    Cell Count            PPI  %Cells Expressing POI  \
# 0        4761  TRIM32-RABAC1               1.197227
# 1        9720  TRIM32-RABAC1               1.008230
# 2        1069  TRIM32-RABAC1               1.590271
# 3        7110  TRIM32-RABAC1               1.139241
# 4        7092  TRIM32-RABAC1               1.142132
# 5        1101  TRIM32-RABAC1               1.544051
# 6      300326  TRIM32-RABAC1               0.469490
# 7       74804  TRIM32-RABAC1               0.378322
# 8        2618  TRIM32-RABAC1               0.343774
# 9        1030  TRIM32-RABAC1               0.970874
#
#    %Cells Expressing Interactor Comp_Category Self_Interaction
# 0                     54.274312             R               No
# 1                     48.580247             M               No
# 2                     53.882133             R               No
# 3                     51.097046             R               No
# 4                     51.170333             R               No
# 5                     53.769301             R               No
# 6                     31.454486             M               No
# 7                     32.754933             M               No
# 8                     30.443086             M               No
# 9                     37.669903             M               No
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/TRIM32_PPI_filtered_Sorted_S2_H2_24042025.xlsx
#
#
# 📂 Processing file: TPM3_PPI_filtered_S2_H2_24042025.xlsx
# ✅ Loaded TPM3_PPI_filtered_S2_H2_24042025.xlsx | Shape: (195, 18)
# ✅ Found 176 total interactors in clusters with at least one Moderate/Robust Compensation.
# ✅ Removed H3 redundant cases. Final dataset contains 71 rows.
#            Tissue                                        Cell Type  \
# 1   adrenal gland                  CD4-positive, alpha-beta T cell
# 3   adrenal gland                  CD8-positive, alpha-beta T cell
# 4   adrenal gland                  CD8-positive, alpha-beta T cell
# 6   adrenal gland                                           T cell
# 8   adrenal gland  effector memory CD8-positive, alpha-beta T cell
# 9   adrenal gland  effector memory CD8-positive, alpha-beta T cell
# 10  adrenal gland  effector memory CD8-positive, alpha-beta T cell
# 12  adrenal gland                               hematopoietic cell
# 14  adrenal gland                                        leukocyte
# 16  adrenal gland                                       lymphocyte
#
#     Cell Count          PPI  %Cells Expressing POI  \
# 1         1418   TPM3-PSMC5              56.135402
# 3         4761  TPM3-MAD1L1              63.978156
# 4         4761   TPM3-PSMC5              63.978156
# 6         9720   TPM3-PSMC5              60.915638
# 8         1069    TPM3-KXD1              67.446211
# 9         1069  TPM3-MAD1L1              67.446211
# 10        1069   TPM3-PSMC5              67.446211
# 12       16124   TPM3-PSMC5              50.924088
# 14       14622   TPM3-PSMC5              54.055533
# 16       11091   TPM3-PSMC5              58.308538
#
#     %Cells Expressing Interactor Comp_Category Self_Interaction
# 1                      28.420310             W               No
# 3                      20.877967             W               No
# 4                      28.691451             W               No
# 6                      28.323045             W               No
# 8                      21.141254             W               No
# 9                      20.767072             W               No
# 10                     28.999065             W               No
# 12                     22.438601             W               No
# 14                     23.656135             W               No
# 16                     26.462898             W               No
# ✅ Saved sorted file (Only PPI + Cell Count, Self-Interactions Removed): ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step2_H2/TPM3_PPI_filtered_Sorted_S2_H2_24042025.xlsx
# /tmp/ipykernel_1136/2816450650.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Comp_Rank"] = final_df["Comp_Category"].map(comp_rank)
