# %% [markdown]
# <p style="font-size:18px; font-weight:bold;"> 2025 Olivia Debnath</p>
# <p style="font-size:14px;">Dana-Farber Cancer Institute & Harvard Medical School</p>

# %% [markdown]
# In this notebook, we will analyze the raw Cell*Gene output files where we tabulated the expression of our protein of interest i.e, POI (e.g., ACSF3) & other metadata across cell types/states of different tissues.
#
# As an input, Level-2 files (genenerated in Cell*Gene_geneExp_data_Level1_16042025_Step2.ipynb) are used for QC+filtering.
#
# This script is named "S0" (PPI_contextualization_CellxGene_S0_Final_17042025.ipynb) as it represents QC.
#
# For convenience, we restricted to the major tissues (e.g, brain, lungs, liver, heart, kidney) for which it will be possible to do orthogonal validations.
#
# Our main pipeline for Step-0 (basic QC):
#
# 1. Load data files (CSV) per gene
#
# 2. Filter data
#
# - Remove bulk-level data (Cell Type = "aggregated" or "cell")
# - Remove small clusters (No of cells < 1000)
# = Remove low-expression clusters (%Cells Expressing Gene < 10% OR below 25th percentile per tissue) => moved this to _S1 (Hypothesis 1 test)
# - Remove genes with extremely low absolute expression (Expression < 0.1 in >90% of clusters)
# - Compute the Z-score per tissue (Saved as a new column). However, normalized expression is the most useful for us.
#
# 3. Compute scRNA-score = 𝑊1×robustness + 𝑊2×expression specificity+ 𝑊3×cluster diversity
#
# - W1 (Robustness) = 0.4 (slightly increased, as it indicates how widely a gene is expressed)
# - W2 (Expression Specificity) = 0.4 (remains high, as specificity is important for biological function)
# - W3 (Cluster Diversity) = 0.2 (reduced weight, as broad cluster distribution, might not always be informative)
# scRNA-score=0.4×Robustness + 0.4× Expression Specificity + 0.2×Cluster Diversity
# where, Robustness = %Cells Expressing Gene Expression specificity = Variance-normalized expression level per tissue Cluster diversity = Number of unique Cell Types (cell types/states) per gene per tissue (normalized by max across dataset)
#
# Here, we reproduced all the findings from /PPI_contextualization_CellxGene_downstream_S0S1_26022025.ipynb (but earlier we just looked into POIs for which we had tested one benign & 1 pathogenic allele) - now it's run on all genes.
#
# Please note that POIs (e.g., AC012254.2) which are not expressed in the single-cell datasets of Cell*Gene & hence excluded from this pipeline.

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
import os

# %% [markdown]
# The script will automatically detect all input files matching [POI]CELLxGENE_gene_expression (CSV file per POI enlisting PPIs)
#
# - Ensures proper handling of missing columns with an explicit check.
# - Fixes the z-score transformation function for correct scaling
# - Add print statements for clarity.

# %%
print(os.path.exists("./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/"))
# Out:
# True

# %%
#Define input directory
input_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/"

#**Dynamically find all Excel files that match the *_PPI.xlsx pattern**
input_files = sorted([f for f in os.listdir(input_dir) if f.endswith("_PPI.xlsx")])

#**Full paths for each file**
input_paths = {file: os.path.join(input_dir, file) for file in input_files}

#**Print summary**
print("\n📂 Detected Gene-wise PPI Excel Files (Alphabetically sorted):")
for file in input_files:
    print(file)

print(f"\n✅ Total Gene-specific PPI files found: {len(input_files)}")
# Out:
# 📂 Detected Gene-wise PPI Excel Files (Alphabetically sorted):
# ACSF3_PPI.xlsx
# ACTB_PPI.xlsx
# ACY1_PPI.xlsx
# ADIPOQ_PPI.xlsx
# AGXT_PPI.xlsx
# AHCY_PPI.xlsx
# AIPL1_PPI.xlsx
# ALAS2_PPI.xlsx
# ALDOA_PPI.xlsx
# ALOX5_PPI.xlsx
# AMPD2_PPI.xlsx
# ANKRD1_PPI.xlsx
# ANXA11_PPI.xlsx
# AP2S1_PPI.xlsx
# APOA1_PPI.xlsx
# APOD_PPI.xlsx
# ASNS_PPI.xlsx
# ATPAF2_PPI.xlsx
# BAG3_PPI.xlsx
# BANF1_PPI.xlsx
# BCL10_PPI.xlsx
# BFSP2_PPI.xlsx
# BLK_PPI.xlsx
# C1QA_PPI.xlsx
# C1QB_PPI.xlsx
# C1QC_PPI.xlsx
# CA8_PPI.xlsx
# CACNB4_PPI.xlsx
# CCBE1_PPI.xlsx
# CCDC103_PPI.xlsx
# CD151_PPI.xlsx
# CDA_PPI.xlsx
# CDC73_PPI.xlsx
# CDK4_PPI.xlsx
# CDKN1A_PPI.xlsx
# CDKN2C_PPI.xlsx
# CFP_PPI.xlsx
# CHN1_PPI.xlsx
# CHRNG_PPI.xlsx
# CLCNKA_PPI.xlsx
# CLDN19_PPI.xlsx
# CLN6_PPI.xlsx
# COL10A1_PPI.xlsx
# COL2A1_PPI.xlsx
# COMP_PPI.xlsx
# COQ8A_PPI.xlsx
# CRADD_PPI.xlsx
# CREB1_PPI.xlsx
# CRYAA_PPI.xlsx
# CRYAB_PPI.xlsx
# CRYBB1_PPI.xlsx
# CSNK1D_PPI.xlsx
# CSNK1E_PPI.xlsx
# CTH_PPI.xlsx
# CTNNA3_PPI.xlsx
# CUL3_PPI.xlsx
# CXCL16_PPI.xlsx
# CYP4F12_PPI.xlsx
# DCX_PPI.xlsx
# DDX20_PPI.xlsx
# DIABLO_PPI.xlsx
# DMC1_PPI.xlsx
# DOLK_PPI.xlsx
# DUSP23_PPI.xlsx
# EFEMP1_PPI.xlsx
# EFHC1_PPI.xlsx
# EIF2B1_PPI.xlsx
# EIF2B4_PPI.xlsx
# EMD_PPI.xlsx
# ESR2_PPI.xlsx
# EXOC8_PPI.xlsx
# EZH2_PPI.xlsx
# FA2H_PPI.xlsx
# FADD_PPI.xlsx
# FAM161A_PPI.xlsx
# FAM187A_PPI.xlsx
# FASLG_PPI.xlsx
# FBP1_PPI.xlsx
# FGD4_PPI.xlsx
# FKBP6_PPI.xlsx
# FOXD4_PPI.xlsx
# FOXP3_PPI.xlsx
# FTH1_PPI.xlsx
# FUCA1_PPI.xlsx
# GAD1_PPI.xlsx
# GALE_PPI.xlsx
# GALT_PPI.xlsx
# GATA2_PPI.xlsx
# GCK_PPI.xlsx
# GCM2_PPI.xlsx
# GFAP_PPI.xlsx
# GLYCTK_PPI.xlsx
# GMPPB_PPI.xlsx
# GNAI3_PPI.xlsx
# GNE_PPI.xlsx
# GOSR2_PPI.xlsx
# GRN_PPI.xlsx
# GSS_PPI.xlsx
# GSTA2_PPI.xlsx
# GSTZ1_PPI.xlsx
# GYG1_PPI.xlsx
# GYPA_PPI.xlsx
# HBD_PPI.xlsx
# HCFC1_PPI.xlsx
# HGD_PPI.xlsx
# HMBS_PPI.xlsx
# HPRT1_PPI.xlsx
# ICAM1_PPI.xlsx
# IER3IP1_PPI.xlsx
# IGFBP5_PPI.xlsx
# IL10_PPI.xlsx
# IL2RG_PPI.xlsx
# IL36RN_PPI.xlsx
# ILK_PPI.xlsx
# IMPDH1_PPI.xlsx
# IRAK4_PPI.xlsx
# ITGB2_PPI.xlsx
# KCNJ2_PPI.xlsx
# KCTD1_PPI.xlsx
# KCTD7_PPI.xlsx
# KLHL3_PPI.xlsx
# KRT2_PPI.xlsx
# KRT4_PPI.xlsx
# KRT5_PPI.xlsx
# KRT6A_PPI.xlsx
# KRT86_PPI.xlsx
# KRT8_PPI.xlsx
# LDHB_PPI.xlsx
# LHFPL5_PPI.xlsx
# LIG4_PPI.xlsx
# LITAF_PPI.xlsx
# MAX_PPI.xlsx
# MCEE_PPI.xlsx
# MCOLN1_PPI.xlsx
# MID1_PPI.xlsx
# MIP_PPI.xlsx
# MLH1_PPI.xlsx
# MSRB3_PPI.xlsx
# MVK_PPI.xlsx
# MYD88_PPI.xlsx
# MYOZ2_PPI.xlsx
# NAA10_PPI.xlsx
# NCF2_PPI.xlsx
# NELL1_PPI.xlsx
# NEUROD1_PPI.xlsx
# NEUROG3_PPI.xlsx
# NEXN_PPI.xlsx
# NF2_PPI.xlsx
# NFU1_PPI.xlsx
# NME1_PPI.xlsx
# NMNAT1_PPI.xlsx
# NPPA_PPI.xlsx
# NR0B1_PPI.xlsx
# NT5C3A_PPI.xlsx
# OAS1_PPI.xlsx
# OPTN_PPI.xlsx
# ORC6_PPI.xlsx
# PCCA_PPI.xlsx
# PGBD1_PPI.xlsx
# PHKG2_PPI.xlsx
# PHYKPL_PPI.xlsx
# PIK3CD_PPI.xlsx
# PITX1_PPI.xlsx
# PITX2_PPI.xlsx
# PKP2_PPI.xlsx
# PLA2G6_PPI.xlsx
# PLN_PPI.xlsx
# PLOD3_PPI.xlsx
# PLP1_PPI.xlsx
# PMP22_PPI.xlsx
# PNKP_PPI.xlsx
# PNPO_PPI.xlsx
# POLR1C_PPI.xlsx
# POMT1_PPI.xlsx
# PRKAR1A_PPI.xlsx
# PRKRA_PPI.xlsx
# PRPF31_PPI.xlsx
# PRPF3_PPI.xlsx
# PRPS1_PPI.xlsx
# PTS_PPI.xlsx
# PUF60_PPI.xlsx
# PYGL_PPI.xlsx
# RAB33B_PPI.xlsx
# RAD51D_PPI.xlsx
# RNF135_PPI.xlsx
# RP2_PPI.xlsx
# RPIA_PPI.xlsx
# RXRG_PPI.xlsx
# SDC3_PPI.xlsx
# SERPINE1_PPI.xlsx
# SERPINF1_PPI.xlsx
# SFTPA2_PPI.xlsx
# SFTPB_PPI.xlsx
# SFTPC_PPI.xlsx
# SH3BP2_PPI.xlsx
# SHMT1_PPI.xlsx
# SIX1_PPI.xlsx
# SLC30A2_PPI.xlsx
# SMAD1_PPI.xlsx
# SMAD3_PPI.xlsx
# SMARCB1_PPI.xlsx
# SMN1_PPI.xlsx
# SMN2_PPI.xlsx
# SOX10_PPI.xlsx
# SQSTM1_PPI.xlsx
# SS18L1_PPI.xlsx
# STAC3_PPI.xlsx
# STAR_PPI.xlsx
# STOX1_PPI.xlsx
# STXBP1_PPI.xlsx
# SUOX_PPI.xlsx
# SYNGR1_PPI.xlsx
# TAT_PPI.xlsx
# TFG_PPI.xlsx
# THAP1_PPI.xlsx
# TH_PPI.xlsx
# TIMM8A_PPI.xlsx
# TMEM43_PPI.xlsx
# TPK1_PPI.xlsx
# TPM1_PPI.xlsx
# TPM2_PPI.xlsx
# TPM3_PPI.xlsx
# TREX1_PPI.xlsx
# TRIB3_PPI.xlsx
# TRIM32_PPI.xlsx
# TSFM_PPI.xlsx
# TTPA_PPI.xlsx
# TTR_PPI.xlsx
# TUFM_PPI.xlsx
# UBE3A_PPI.xlsx
# UBQLN2_PPI.xlsx
# UROD_PPI.xlsx
# VAPB_PPI.xlsx
# VHL_PPI.xlsx
# VPS33B_PPI.xlsx
# WRAP53_PPI.xlsx
# XRCC2_PPI.xlsx
# XRCC4_PPI.xlsx
# ZCCHC12_PPI.xlsx
# ZMYND10_PPI.xlsx
# ZNF24_PPI.xlsx
# ZNF624_PPI.xlsx
#
# ✅ Total Gene-specific PPI files found: 242

# %%
#**Create output directory inside input_dir**
output_dir = os.path.join(input_dir, "filtered_S0")  #QC step-specific
os.makedirs(output_dir, exist_ok=True)

#**Define new naming format: replace full filename with new suffix**
output_paths = {
    file: os.path.join(output_dir, file.replace(".xlsx", "_filtered_S0_17042025.csv"))
    for file in input_files
}

# %%
#**Define Weights for scRNA-score computation**

W1 = 0.4  #Robustness (How widely a gene is expressed)
W2 = 0.4  #Expression Specificity (Tissue-level variation)
W3 = 0.2  #Cluster Diversity (Spread across cell types)

# %% [markdown]
# Understand scRNA score calculation:
#
# 1. Robustness (W1= 0.4):
#
# - Definition: Measures how widely a gene is expressed across cells within a tissue.
# - Computation: The fraction of cells expressing the gene (%Cells Expressing Gene).
# - Why it matters: A gene that is expressed in many cells within a tissue is more biologically relevant than one expressed in just a few scattered cells.
#             - Helps identify widely expressed genes with functional roles.
#             - Genes with low robustness but high Expression Intensity may play specialized roles.
#
#
# 2. Expression Specificity (Cell type bias; W2 = 0.4)
#
# - Definition: Measures how uniquely a gene is expressed across different cell types within a tissue.
# - Computation: Normalized variation in expression across cell types within a tissue.
#     - High Specificity = A gene is highly restricted to a single cell type.
#     - Low Specificity = A gene is broadly expressed across multiple cell types.
#
# - Why it matters: Genes uniquely expressed in specific cell types are more functionally specialized. Also, genes with low Robustness but high specificity may be critical for rare cell states.
#
#
# 3. Cluster Diversity (Spread across cell types/states; W3 = 0.2)
#
# - Definition: Measures the number of different cell types a gene is expressed in within a tissue.
# - Computation: The number of unique cell types a gene is expressed in, normalized across all tissues.
# - Why it matters: A gene expressed in diverse cell types may have broader functional significance. Helps in identifying broadly expressed functional genes vs cell-type-restricted markers.
#
#
# Another important consideration could be Tissue Breadth (Multi-tissue expression)
#
# 🔹 Is this gene expressed in just one tissue or multiple tissues?
#
# 🔹 Formula: Number of distinct tissues in which this gene is expressed, normalized across all genes.
#     - High Tissue Breadth = A gene is expressed in many tissues.
#     - Low Tissue Breadth = A gene is restricted to just one tissue.
#
# 🔹 Why it matters?
#
# - High Tissue Breadth suggests a fundamental biological role across multiple systems.
# - Low Tissue Breadth suggests a tissue-specific function.
#
#
#
# Final scRNA score Calculation
#
# To integrate all these features into a single metric:
#
# scRNA-score = (0.4 × Robustness) + (0.4 × Expression Specificity) + (0.2 × Cluster Diversity)
#
# 🔹 Why are these assigned weights?
#
# - Robustness, and Specificity are equally important.
# - Cluster Diversity is weighted lower (since broad expression isn’t always functionally meaningful).

# %%
def process_file(df, protein_of_interest):
    """ Cleans, filters, normalizes, and computes scRNA-score for scRNA-seq data. """

    #**Fix column names: Strip spaces & rename correctly**
    df.columns = df.columns.str.strip()
    df.rename(columns={
        "Number of Cells Expressing Genes": "Num_Cells_Expressing_Gene",
        "%Cells Expressing Gene ": "%Cells Expressing Gene"  # optional, legacy case
    }, inplace=True)

    #**Print number of unique cell types before filtering**
    print(f"\n🔍 Before filtering: Unique Cell Types = {df['Cell Type'].nunique()}")

    #**Ensure necessary columns exist**
    required_columns = {"Tissue", "Cell Type", "Cell Count", "Gene Symbol", "Expression", "Num_Cells_Expressing_Gene"}
    if not required_columns.issubset(df.columns):
        print(f"❌ ERROR: Missing required columns in {protein_of_interest} data! Skipping...")
        print(f"Missing: {required_columns - set(df.columns)}")
        return None

    #**Check if the protein of interest is present**
    if protein_of_interest not in df["Gene Symbol"].astype(str).unique():
        print(f"⚠️ WARNING: {protein_of_interest} not found in Gene Symbol column! Skipping...")
        return None

    #**Recalculate %Cells Expressing Gene**
    df["%Cells Expressing Gene"] = (df["Num_Cells_Expressing_Gene"] / df["Cell Count"]) * 100

    #**Remove bulk-level data (aggregate, cell)**
    df = df[~df["Cell Type"].isin(["aggregated", "cell"])]

    #**Remove small clusters (#Cells < 1000)**
    df = df[df["Cell Count"] >= 1000]

    #**Ensure the POI is expressed above threshold in at least some cells**
    main_protein_present = df[(df["Gene Symbol"] == protein_of_interest) & (df["Expression"] > 0.1)]
    if main_protein_present.empty:
        print(f"⚠️ WARNING: {protein_of_interest} not detected above 0.1 in any valid cluster! Skipping file.")
        return None

    #**Keep only valid tissue-cell type pairs where POI is expressed >0.1**
    valid_tissue_cell_types = main_protein_present[["Tissue", "Cell Type"]].drop_duplicates()

    #**Merge to keep only relevant tissue-cell type pairs where POI is expressed >0.1**
    df = df.merge(valid_tissue_cell_types, on=["Tissue", "Cell Type"], how="inner")

    #**Remove genes with Expression < 0.1 in >90% of clusters**
    gene_low_expr = df.groupby("Gene Symbol")["Expression"].apply(lambda x: (x < 0.1).mean() > 0.9)
    low_expr_genes = gene_low_expr[gene_low_expr].index
    df = df[~df["Gene Symbol"].isin(low_expr_genes)]

    #**Compute Z-score per Tissue**
    df["Expression_Zscore"] = df.groupby("Tissue")["Expression"].transform(lambda x: zscore(x, nan_policy="omit"))

    #**Compute scRNA-score components**
    df["Robustness"] = df["%Cells Expressing Gene"]
    df["Expression_Specificity"] = df.groupby("Tissue")["Expression"].transform(
        lambda x: (x - x.min()) / (x.max() - x.min()) if x.max() > x.min() else 0
    )
    df["Cluster_Diversity"] = df.groupby(["Tissue", "Gene Symbol"])["Cell Type"].transform("nunique")
    df["Cluster_Diversity"] /= df["Cluster_Diversity"].max()

    #**Compute scRNA-score**
    df["scRNA_score"] = (
        W1 * df["Robustness"] +
        W2 * df["Expression_Specificity"] +
        W3 * df["Cluster_Diversity"]
    )

    #**Print number of unique cell types after filtering**
    print(f"🔍 After filtering: Unique Cell Types = {df['Cell Type'].nunique()}")

    return df

# %%
# for file in input_paths:
#     print(f"Found file: {file}") #can identify all files

# %%
#Pick one file to test: 
file = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ACSF3_PPI.xlsx"
df = pd.read_excel(file)

# Check if POI exists
poi = "ACSF3"
print("Gene Symbol values:", df["Gene Symbol"].unique())
print("Looking for POI:", poi in df["Gene Symbol"].unique())

# Call your function
processed = process_file(df, poi)

if processed is not None:
    print("✅ QC passed:", processed.shape)
else:
    print("⚠️ QC failed or POI missing.")
# Out:
# Gene Symbol values: ['ACSF3' 'KRT40' 'RAB28' 'TRIM27']
# Looking for POI: True
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 613
# ✅ QC passed: (8536, 14)

# %%
#Check another file to test: 
file = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/STXBP1_PPI.xlsx"
df = pd.read_excel(file)

# Check if POI exists
poi = "STXBP1"
print("Gene Symbol values:", df["Gene Symbol"].unique())
print("Looking for POI:", poi in df["Gene Symbol"].unique())

# Call your function
processed = process_file(df, poi)

if processed is not None:
    print("✅ QC passed:", processed.shape)
else:
    print("⚠️ QC failed or POI missing.")
# Out:
# Gene Symbol values: ['STXBP1' 'CENPP' 'MAPK1' 'STX19' 'STX5' 'SYTL4' 'TRIM38']
# Looking for POI: True
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 597
# ✅ QC passed: (14245, 14)

# %%
#Now that it works on individual files, test it on all files: 

def process_all_files():
    """Processes all input Excel files and saves filtered results with proper logging."""

    #**STEP 1: Locate all input Excel files**
    input_files = sorted([
        f for f in os.listdir(input_dir)
        if f.endswith(".xlsx") and "_PPI" in f
    ])

    print("\n📋 Input Excel files found:")
    for f in input_files:
        print(" -", f)
    if not input_files:
        print("❌ No Excel files found in directory!")
        return

    #**STEP 2: Prepare file paths**
    input_paths = {f: os.path.join(input_dir, f) for f in input_files}
    output_dir = os.path.join(input_dir, "filtered_S0")
    os.makedirs(output_dir, exist_ok=True)
    output_paths = {
        f: os.path.join(output_dir, f.replace(".xlsx", "_filtered_S0_17042025.csv"))
        for f in input_files
    }

    #**STEP 3: Process each file**
    for file, input_path in input_paths.items():
        print(f"\n📂 Processing: {input_path}...")

        if not os.path.isfile(input_path):
            print(f"❌ File not found: {input_path}")
            continue

        protein_of_interest = file.split("_")[0]
        print(f"🧬 Protein of Interest: {protein_of_interest}")

        try:
            df = pd.read_excel(input_path)
            print(f"📊 Loaded: {df.shape}")
        except Exception as e:
            print(f"❌ Failed to read file: {e}")
            continue

        if "Gene Symbol" not in df.columns:
            print("❌ Missing 'Gene Symbol' column!")
            continue

        gene_list = df["Gene Symbol"].astype(str).unique()
        print(f"🧬 Found genes: {gene_list}")

        if protein_of_interest not in gene_list:
            print(f"⚠️ Skipping {file}: POI '{protein_of_interest}' not found in file.")
            continue

        processed_df = process_file(df, protein_of_interest)

        if processed_df is not None:
            output_path = output_paths[file]
            processed_df.to_csv(output_path, index=False)
            print(f"✅ Saved: {output_path} ({processed_df.shape[0]} rows)")
        else:
            print(f"⚠️ Skipped {file}: QC failed.")

# %%
#**Run all 242 files in the input directory** 
process_all_files()
# Out:
# 📋 Input Excel files found:
#  - ACSF3_PPI.xlsx
#  - ACTB_PPI.xlsx
#  - ACY1_PPI.xlsx
#  - ADIPOQ_PPI.xlsx
#  - AGXT_PPI.xlsx
#  - AHCY_PPI.xlsx
#  - AIPL1_PPI.xlsx
#  - ALAS2_PPI.xlsx
#  - ALDOA_PPI.xlsx
#  - ALOX5_PPI.xlsx
#  - AMPD2_PPI.xlsx
#  - ANKRD1_PPI.xlsx
#  - ANXA11_PPI.xlsx
#  - AP2S1_PPI.xlsx
#  - APOA1_PPI.xlsx
#  - APOD_PPI.xlsx
#  - ASNS_PPI.xlsx
#  - ATPAF2_PPI.xlsx
#  - BAG3_PPI.xlsx
#  - BANF1_PPI.xlsx
#  - BCL10_PPI.xlsx
#  - BFSP2_PPI.xlsx
#  - BLK_PPI.xlsx
#  - C1QA_PPI.xlsx
#  - C1QB_PPI.xlsx
#  - C1QC_PPI.xlsx
#  - CA8_PPI.xlsx
#  - CACNB4_PPI.xlsx
#  - CCBE1_PPI.xlsx
#  - CCDC103_PPI.xlsx
#  - CD151_PPI.xlsx
#  - CDA_PPI.xlsx
#  - CDC73_PPI.xlsx
#  - CDK4_PPI.xlsx
#  - CDKN1A_PPI.xlsx
#  - CDKN2C_PPI.xlsx
#  - CFP_PPI.xlsx
#  - CHN1_PPI.xlsx
#  - CHRNG_PPI.xlsx
#  - CLCNKA_PPI.xlsx
#  - CLDN19_PPI.xlsx
#  - CLN6_PPI.xlsx
#  - COL10A1_PPI.xlsx
#  - COL2A1_PPI.xlsx
#  - COMP_PPI.xlsx
#  - COQ8A_PPI.xlsx
#  - CRADD_PPI.xlsx
#  - CREB1_PPI.xlsx
#  - CRYAA_PPI.xlsx
#  - CRYAB_PPI.xlsx
#  - CRYBB1_PPI.xlsx
#  - CSNK1D_PPI.xlsx
#  - CSNK1E_PPI.xlsx
#  - CTH_PPI.xlsx
#  - CTNNA3_PPI.xlsx
#  - CUL3_PPI.xlsx
#  - CXCL16_PPI.xlsx
#  - CYP4F12_PPI.xlsx
#  - DCX_PPI.xlsx
#  - DDX20_PPI.xlsx
#  - DIABLO_PPI.xlsx
#  - DMC1_PPI.xlsx
#  - DOLK_PPI.xlsx
#  - DUSP23_PPI.xlsx
#  - EFEMP1_PPI.xlsx
#  - EFHC1_PPI.xlsx
#  - EIF2B1_PPI.xlsx
#  - EIF2B4_PPI.xlsx
#  - EMD_PPI.xlsx
#  - ESR2_PPI.xlsx
#  - EXOC8_PPI.xlsx
#  - EZH2_PPI.xlsx
#  - FA2H_PPI.xlsx
#  - FADD_PPI.xlsx
#  - FAM161A_PPI.xlsx
#  - FAM187A_PPI.xlsx
#  - FASLG_PPI.xlsx
#  - FBP1_PPI.xlsx
#  - FGD4_PPI.xlsx
#  - FKBP6_PPI.xlsx
#  - FOXD4_PPI.xlsx
#  - FOXP3_PPI.xlsx
#  - FTH1_PPI.xlsx
#  - FUCA1_PPI.xlsx
#  - GAD1_PPI.xlsx
#  - GALE_PPI.xlsx
#  - GALT_PPI.xlsx
#  - GATA2_PPI.xlsx
#  - GCK_PPI.xlsx
#  - GCM2_PPI.xlsx
#  - GFAP_PPI.xlsx
#  - GLYCTK_PPI.xlsx
#  - GMPPB_PPI.xlsx
#  - GNAI3_PPI.xlsx
#  - GNE_PPI.xlsx
#  - GOSR2_PPI.xlsx
#  - GRN_PPI.xlsx
#  - GSS_PPI.xlsx
#  - GSTA2_PPI.xlsx
#  - GSTZ1_PPI.xlsx
#  - GYG1_PPI.xlsx
#  - GYPA_PPI.xlsx
#  - HBD_PPI.xlsx
#  - HCFC1_PPI.xlsx
#  - HGD_PPI.xlsx
#  - HMBS_PPI.xlsx
#  - HPRT1_PPI.xlsx
#  - ICAM1_PPI.xlsx
#  - IER3IP1_PPI.xlsx
#  - IGFBP5_PPI.xlsx
#  - IL10_PPI.xlsx
#  - IL2RG_PPI.xlsx
#  - IL36RN_PPI.xlsx
#  - ILK_PPI.xlsx
#  - IMPDH1_PPI.xlsx
#  - IRAK4_PPI.xlsx
#  - ITGB2_PPI.xlsx
#  - KCNJ2_PPI.xlsx
#  - KCTD1_PPI.xlsx
#  - KCTD7_PPI.xlsx
#  - KLHL3_PPI.xlsx
#  - KRT2_PPI.xlsx
#  - KRT4_PPI.xlsx
#  - KRT5_PPI.xlsx
#  - KRT6A_PPI.xlsx
#  - KRT86_PPI.xlsx
#  - KRT8_PPI.xlsx
#  - LDHB_PPI.xlsx
#  - LHFPL5_PPI.xlsx
#  - LIG4_PPI.xlsx
#  - LITAF_PPI.xlsx
#  - MAX_PPI.xlsx
#  - MCEE_PPI.xlsx
#  - MCOLN1_PPI.xlsx
#  - MID1_PPI.xlsx
#  - MIP_PPI.xlsx
#  - MLH1_PPI.xlsx
#  - MSRB3_PPI.xlsx
#  - MVK_PPI.xlsx
#  - MYD88_PPI.xlsx
#  - MYOZ2_PPI.xlsx
#  - NAA10_PPI.xlsx
#  - NCF2_PPI.xlsx
#  - NELL1_PPI.xlsx
#  - NEUROD1_PPI.xlsx
#  - NEUROG3_PPI.xlsx
#  - NEXN_PPI.xlsx
#  - NF2_PPI.xlsx
#  - NFU1_PPI.xlsx
#  - NME1_PPI.xlsx
#  - NMNAT1_PPI.xlsx
#  - NPPA_PPI.xlsx
#  - NR0B1_PPI.xlsx
#  - NT5C3A_PPI.xlsx
#  - OAS1_PPI.xlsx
#  - OPTN_PPI.xlsx
#  - ORC6_PPI.xlsx
#  - PCCA_PPI.xlsx
#  - PGBD1_PPI.xlsx
#  - PHKG2_PPI.xlsx
#  - PHYKPL_PPI.xlsx
#  - PIK3CD_PPI.xlsx
#  - PITX1_PPI.xlsx
#  - PITX2_PPI.xlsx
#  - PKP2_PPI.xlsx
#  - PLA2G6_PPI.xlsx
#  - PLN_PPI.xlsx
#  - PLOD3_PPI.xlsx
#  - PLP1_PPI.xlsx
#  - PMP22_PPI.xlsx
#  - PNKP_PPI.xlsx
#  - PNPO_PPI.xlsx
#  - POLR1C_PPI.xlsx
#  - POMT1_PPI.xlsx
#  - PRKAR1A_PPI.xlsx
#  - PRKRA_PPI.xlsx
#  - PRPF31_PPI.xlsx
#  - PRPF3_PPI.xlsx
#  - PRPS1_PPI.xlsx
#  - PTS_PPI.xlsx
#  - PUF60_PPI.xlsx
#  - PYGL_PPI.xlsx
#  - RAB33B_PPI.xlsx
#  - RAD51D_PPI.xlsx
#  - RNF135_PPI.xlsx
#  - RP2_PPI.xlsx
#  - RPIA_PPI.xlsx
#  - RXRG_PPI.xlsx
#  - SDC3_PPI.xlsx
#  - SERPINE1_PPI.xlsx
#  - SERPINF1_PPI.xlsx
#  - SFTPA2_PPI.xlsx
#  - SFTPB_PPI.xlsx
#  - SFTPC_PPI.xlsx
#  - SH3BP2_PPI.xlsx
#  - SHMT1_PPI.xlsx
#  - SIX1_PPI.xlsx
#  - SLC30A2_PPI.xlsx
#  - SMAD1_PPI.xlsx
#  - SMAD3_PPI.xlsx
#  - SMARCB1_PPI.xlsx
#  - SMN1_PPI.xlsx
#  - SMN2_PPI.xlsx
#  - SOX10_PPI.xlsx
#  - SQSTM1_PPI.xlsx
#  - SS18L1_PPI.xlsx
#  - STAC3_PPI.xlsx
#  - STAR_PPI.xlsx
#  - STOX1_PPI.xlsx
#  - STXBP1_PPI.xlsx
#  - SUOX_PPI.xlsx
#  - SYNGR1_PPI.xlsx
#  - TAT_PPI.xlsx
#  - TFG_PPI.xlsx
#  - THAP1_PPI.xlsx
#  - TH_PPI.xlsx
#  - TIMM8A_PPI.xlsx
#  - TMEM43_PPI.xlsx
#  - TPK1_PPI.xlsx
#  - TPM1_PPI.xlsx
#  - TPM2_PPI.xlsx
#  - TPM3_PPI.xlsx
#  - TREX1_PPI.xlsx
#  - TRIB3_PPI.xlsx
#  - TRIM32_PPI.xlsx
#  - TSFM_PPI.xlsx
#  - TTPA_PPI.xlsx
#  - TTR_PPI.xlsx
#  - TUFM_PPI.xlsx
#  - UBE3A_PPI.xlsx
#  - UBQLN2_PPI.xlsx
#  - UROD_PPI.xlsx
#  - VAPB_PPI.xlsx
#  - VHL_PPI.xlsx
#  - VPS33B_PPI.xlsx
#  - WRAP53_PPI.xlsx
#  - XRCC2_PPI.xlsx
#  - XRCC4_PPI.xlsx
#  - ZCCHC12_PPI.xlsx
#  - ZMYND10_PPI.xlsx
#  - ZNF24_PPI.xlsx
#  - ZNF624_PPI.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ACSF3_PPI.xlsx...
# 🧬 Protein of Interest: ACSF3
# 📊 Loaded: (13484, 8)
# 🧬 Found genes: ['ACSF3' 'KRT40' 'RAB28' 'TRIM27']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 613
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ACSF3_PPI_filtered_S0_17042025.csv (8536 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ACTB_PPI.xlsx...
# 🧬 Protein of Interest: ACTB
# 📊 Loaded: (10113, 8)
# 🧬 Found genes: ['ACTB' 'ACTG1' 'CFL2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ACTB_PPI_filtered_S0_17042025.csv (6423 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ACY1_PPI.xlsx...
# 🧬 Protein of Interest: ACY1
# 📊 Loaded: (3371, 8)
# 🧬 Found genes: ['ACY1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 562
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ACY1_PPI_filtered_S0_17042025.csv (1933 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ADIPOQ_PPI.xlsx...
# 🧬 Protein of Interest: ADIPOQ
# 📊 Loaded: (70791, 8)
# 🧬 Found genes: ['ADIPOQ' 'AMIGO1' 'BCL2L13' 'BIK' 'BTNL9' 'CLDN9' 'CPLX4' 'CREB3L1'
#  'FAM209A' 'FCGR1A' 'FNDC9' 'GPR152' 'GPR42' 'MFF' 'MRM1' 'NEMP1' 'PVR'
#  'SLC35C2' 'SLC35E3' 'SYNE4' 'TMEM237']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 348
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ADIPOQ_PPI_filtered_S0_17042025.csv (19236 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/AGXT_PPI.xlsx...
# 🧬 Protein of Interest: AGXT
# 📊 Loaded: (30339, 8)
# 🧬 Found genes: ['AGXT' 'CYSRT1' 'FOSB' 'KRT31' 'KRT34' 'KRT40' 'KRTAP1-1' 'NBPF19' 'RFX6']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 359
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AGXT_PPI_filtered_S0_17042025.csv (8703 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/AHCY_PPI.xlsx...
# 🧬 Protein of Interest: AHCY
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['AHCY' 'C1orf50']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 611
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AHCY_PPI_filtered_S0_17042025.csv (4266 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/AIPL1_PPI.xlsx...
# 🧬 Protein of Interest: AIPL1
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['AIPL1' 'PLSCR3']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 469
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AIPL1_PPI_filtered_S0_17042025.csv (2664 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ALAS2_PPI.xlsx...
# 🧬 Protein of Interest: ALAS2
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['ALAS2' 'BANP']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 494
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ALAS2_PPI_filtered_S0_17042025.csv (3238 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ALDOA_PPI.xlsx...
# 🧬 Protein of Interest: ALDOA
# 📊 Loaded: (3371, 8)
# 🧬 Found genes: ['ALDOA']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 600
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ALDOA_PPI_filtered_S0_17042025.csv (2112 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ALOX5_PPI.xlsx...
# 🧬 Protein of Interest: ALOX5
# 📊 Loaded: (13484, 8)
# 🧬 Found genes: ['ALOX5' 'CEP63' 'MAD1L1' 'NUTM1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 568
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ALOX5_PPI_filtered_S0_17042025.csv (7944 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/AMPD2_PPI.xlsx...
# 🧬 Protein of Interest: AMPD2
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['AMPD2' 'AMPD1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 611
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AMPD2_PPI_filtered_S0_17042025.csv (4248 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ANKRD1_PPI.xlsx...
# 🧬 Protein of Interest: ANKRD1
# 📊 Loaded: (10113, 8)
# 🧬 Found genes: ['ANKRD1' 'NAGK' 'ZNF446']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 432
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ANKRD1_PPI_filtered_S0_17042025.csv (3699 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ANXA11_PPI.xlsx...
# 🧬 Protein of Interest: ANXA11
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['ANXA11' 'FUBP1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 609
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ANXA11_PPI_filtered_S0_17042025.csv (4266 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/AP2S1_PPI.xlsx...
# 🧬 Protein of Interest: AP2S1
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['AP2S1' 'AAGAB']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 614
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AP2S1_PPI_filtered_S0_17042025.csv (4278 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/APOA1_PPI.xlsx...
# 🧬 Protein of Interest: APOA1
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['APOA1' 'CMTM5']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 574
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/APOA1_PPI_filtered_S0_17042025.csv (3950 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/APOD_PPI.xlsx...
# 🧬 Protein of Interest: APOD
# 📊 Loaded: (53936, 8)
# 🧬 Found genes: ['APOD' 'AQP9' 'BIK' 'CD53' 'CPLX4' 'CREB3L1' 'ERGIC3' 'FAM209A' 'GDAP1'
#  'GJA8' 'KCNJ6' 'MFF' 'MTERF2' 'MTIF3' 'TMEM237' 'VAPA']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 550
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/APOD_PPI_filtered_S0_17042025.csv (30624 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ASNS_PPI.xlsx...
# 🧬 Protein of Interest: ASNS
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['ASNS' 'TRIM69']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 587
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ASNS_PPI_filtered_S0_17042025.csv (4122 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ATPAF2_PPI.xlsx...
# 🧬 Protein of Interest: ATPAF2
# 📊 Loaded: (30339, 8)
# 🧬 Found genes: ['ATPAF2' 'GOLGA6L9' 'IKZF3' 'LNX1' 'MAGEA6' 'PRDM6' 'RPIA' 'SPG21'
#  'TFIP11']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 615
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ATPAF2_PPI_filtered_S0_17042025.csv (19215 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/BAG3_PPI.xlsx...
# 🧬 Protein of Interest: BAG3
# 📊 Loaded: (70791, 8)
# 🧬 Found genes: ['BAG3' 'ARRDC3' 'BAIAP2L1' 'CYSRT1' 'DAZAP2' 'EYA2' 'FOXD4L1' 'HSPB7'
#  'HSPB8' 'MAGED1' 'MDFI' 'PDLIM7' 'PLA2G10' 'PRDM6' 'SHISA6' 'SPRY2'
#  'TBC1D3G' 'TP53BP2' 'TRIM27' 'UNKL' 'VPS37B']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 606
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BAG3_PPI_filtered_S0_17042025.csv (44709 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/BANF1_PPI.xlsx...
# 🧬 Protein of Interest: BANF1
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['BANF1' 'BANF2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 612
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BANF1_PPI_filtered_S0_17042025.csv (4274 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/BCL10_PPI.xlsx...
# 🧬 Protein of Interest: BCL10
# 📊 Loaded: (10113, 8)
# 🧬 Found genes: ['BCL10' 'COG6' 'TRAF2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 610
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BCL10_PPI_filtered_S0_17042025.csv (6399 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/BFSP2_PPI.xlsx...
# 🧬 Protein of Interest: BFSP2
# 📊 Loaded: (74162, 8)
# 🧬 Found genes: ['BFSP2' 'AMOTL2' 'ATF4' 'BEX3' 'BEX5' 'BFSP1' 'BICRAL' 'BLOC1S2' 'CAGE1'
#  'CDR2L' 'CEP63' 'DISC1' 'DMAP1' 'HAUS1' 'HGS' 'KRT27' 'SCOC' 'SNAPIN'
#  'SYCE1' 'SYCE1L' 'USP54' 'WASHC3']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 510
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BFSP2_PPI_filtered_S0_17042025.csv (36168 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/BLK_PPI.xlsx...
# 🧬 Protein of Interest: BLK
# 📊 Loaded: (60678, 8)
# 🧬 Found genes: ['BLK' 'BIRC2' 'CCDC33' 'EFS' 'FXR1' 'FXR2' 'GRB10' 'HSF2BP' 'IKZF3'
#  'MID2' 'PIK3R1' 'PXN' 'SH2D1B' 'SLA' 'SSBP3' 'STAT3' 'TDP2' 'ZBTB8A']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 489
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BLK_PPI_filtered_S0_17042025.csv (30924 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/C1QA_PPI.xlsx...
# 🧬 Protein of Interest: C1QA
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['C1QA' 'UBQLN2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 566
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/C1QA_PPI_filtered_S0_17042025.csv (3988 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/C1QB_PPI.xlsx...
# 🧬 Protein of Interest: C1QB
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['C1QB' 'UBQLN2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 562
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/C1QB_PPI_filtered_S0_17042025.csv (3990 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/C1QC_PPI.xlsx...
# 🧬 Protein of Interest: C1QC
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['C1QC' 'UBQLN2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 552
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/C1QC_PPI_filtered_S0_17042025.csv (3932 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CA8_PPI.xlsx...
# 🧬 Protein of Interest: CA8
# 📊 Loaded: (13432, 8)
# 🧬 Found genes: ['CA8' 'HSD17B14' 'KLHL8' 'MAGED1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 592
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CA8_PPI_filtered_S0_17042025.csv (7920 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CACNB4_PPI.xlsx...
# 🧬 Protein of Interest: CACNB4
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['CACNB4' 'CTBP2' 'EFHC2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 592
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CACNB4_PPI_filtered_S0_17042025.csv (5973 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CCBE1_PPI.xlsx...
# 🧬 Protein of Interest: CCBE1
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['CCBE1' 'KLHL12' 'KRT27']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 572
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CCBE1_PPI_filtered_S0_17042025.csv (5598 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CCDC103_PPI.xlsx...
# 🧬 Protein of Interest: CCDC103
# 📊 Loaded: (16842, 8)
# 🧬 Found genes: ['CCDC103' 'GRIPAP1' 'MEOX2' 'PICK1' 'VAC14']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 306
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CCDC103_PPI_filtered_S0_17042025.csv (4020 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CD151_PPI.xlsx...
# 🧬 Protein of Interest: CD151
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CD151' 'GRAMD1C']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 610
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CD151_PPI_filtered_S0_17042025.csv (4256 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CDA_PPI.xlsx...
# 🧬 Protein of Interest: CDA
# 📊 Loaded: (3358, 8)
# 🧬 Found genes: ['CDA']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 566
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDA_PPI_filtered_S0_17042025.csv (1946 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CDC73_PPI.xlsx...
# 🧬 Protein of Interest: CDC73
# 📊 Loaded: (20148, 8)
# 🧬 Found genes: ['CDC73' 'GOLGA6L9' 'HSF2BP' 'MTUS2' 'PICK1' 'TRIM23']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDC73_PPI_filtered_S0_17042025.csv (12828 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CDK4_PPI.xlsx...
# 🧬 Protein of Interest: CDK4
# 📊 Loaded: (20148, 8)
# 🧬 Found genes: ['CDK4' 'CCND2' 'CCND3' 'CDKN2D' 'HOOK1' 'IKZF3']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 613
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDK4_PPI_filtered_S0_17042025.csv (12786 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CDKN1A_PPI.xlsx...
# 🧬 Protein of Interest: CDKN1A
# 📊 Loaded: (30222, 8)
# 🧬 Found genes: ['CDKN1A' 'CCND2' 'CCND3' 'INCA1' 'KRT31' 'LZTS2' 'PCNA' 'REL' 'TRIM54']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 600
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDKN1A_PPI_filtered_S0_17042025.csv (19080 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CDKN2C_PPI.xlsx...
# 🧬 Protein of Interest: CDKN2C
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['CDKN2C' 'AHCYL1' 'CDK6']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 592
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDKN2C_PPI_filtered_S0_17042025.csv (6273 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CFP_PPI.xlsx...
# 🧬 Protein of Interest: CFP
# 📊 Loaded: (16790, 8)
# 🧬 Found genes: ['CFP' 'CYSRT1' 'GEMIN4' 'HOXA1' 'KRTAP6-2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 542
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CFP_PPI_filtered_S0_17042025.csv (9460 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CHN1_PPI.xlsx...
# 🧬 Protein of Interest: CHN1
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CHN1' 'NCK2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 588
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CHN1_PPI_filtered_S0_17042025.csv (4004 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CHRNG_PPI.xlsx...
# 🧬 Protein of Interest: CHRNG
# 📊 Loaded: (26864, 8)
# 🧬 Found genes: ['CHRNG' 'CYSRT1' 'KRT31' 'KRTAP1-1' 'KRTAP10-8' 'KRTAP12-3' 'KRTAP5-9'
#  'KRTAP9-3']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 413
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CHRNG_PPI_filtered_S0_17042025.csv (8904 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CLCNKA_PPI.xlsx...
# 🧬 Protein of Interest: CLCNKA
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CLCNKA' 'CYSRT1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 423
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CLCNKA_PPI_filtered_S0_17042025.csv (2226 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CLDN19_PPI.xlsx...
# 🧬 Protein of Interest: CLDN19
# 📊 Loaded: (63802, 8)
# 🧬 Found genes: ['CLDN19' 'AQP9' 'BTN2A1' 'CD200R1' 'CLRN1' 'FCGR1A' 'GJA8' 'GPR161'
#  'KIR2DL3' 'LRRC4C' 'MFF' 'MS4A4A' 'MUC1' 'PVR' 'SGPL1' 'STOM' 'TM4SF18'
#  'TMEM248' 'TNFSF14']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 450
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CLDN19_PPI_filtered_S0_17042025.csv (25175 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CLN6_PPI.xlsx...
# 🧬 Protein of Interest: CLN6
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['CLN6' 'CREB3L1' 'STX1A']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 604
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CLN6_PPI_filtered_S0_17042025.csv (6288 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/COL10A1_PPI.xlsx...
# 🧬 Protein of Interest: COL10A1
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['COL10A1' 'BANP' 'UBQLN2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 511
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COL10A1_PPI_filtered_S0_17042025.csv (4683 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/COL2A1_PPI.xlsx...
# 🧬 Protein of Interest: COL2A1
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['COL2A1' 'KEAP1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 479
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COL2A1_PPI_filtered_S0_17042025.csv (2952 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/COMP_PPI.xlsx...
# 🧬 Protein of Interest: COMP
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['COMP' 'MEOX2' 'OTX1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 503
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COMP_PPI_filtered_S0_17042025.csv (4755 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/COQ8A_PPI.xlsx...
# 🧬 Protein of Interest: COQ8A
# 📊 Loaded: (23506, 8)
# 🧬 Found genes: ['COQ8A' 'AGTRAP' 'CMTM5' 'RABAC1' 'REEP6' 'SH3GLB1' 'TFIP11']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 582
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COQ8A_PPI_filtered_S0_17042025.csv (14434 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CRADD_PPI.xlsx...
# 🧬 Protein of Interest: CRADD
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CRADD' 'CASP2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 612
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRADD_PPI_filtered_S0_17042025.csv (4250 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CREB1_PPI.xlsx...
# 🧬 Protein of Interest: CREB1
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CREB1' 'CRTC2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CREB1_PPI_filtered_S0_17042025.csv (4276 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CRYAA_PPI.xlsx...
# 🧬 Protein of Interest: CRYAA
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CRYAA' 'CRYAB']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 183
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRYAA_PPI_filtered_S0_17042025.csv (754 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CRYAB_PPI.xlsx...
# 🧬 Protein of Interest: CRYAB
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CRYAB' 'CRYAA']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 567
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRYAB_PPI_filtered_S0_17042025.csv (3936 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CRYBB1_PPI.xlsx...
# 🧬 Protein of Interest: CRYBB1
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CRYBB1' 'GAS8']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 461
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRYBB1_PPI_filtered_S0_17042025.csv (2956 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CSNK1D_PPI.xlsx...
# 🧬 Protein of Interest: CSNK1D
# 📊 Loaded: (10074, 8)
# 🧬 Found genes: ['CSNK1D' 'CCDC14' 'ZNF618']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CSNK1D_PPI_filtered_S0_17042025.csv (6414 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CSNK1E_PPI.xlsx...
# 🧬 Protein of Interest: CSNK1E
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CSNK1E' 'ZNF618']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 615
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CSNK1E_PPI_filtered_S0_17042025.csv (4270 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CTH_PPI.xlsx...
# 🧬 Protein of Interest: CTH
# 📊 Loaded: (3358, 8)
# 🧬 Found genes: ['CTH']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 602
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CTH_PPI_filtered_S0_17042025.csv (2102 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CTNNA3_PPI.xlsx...
# 🧬 Protein of Interest: CTNNA3
# 📊 Loaded: (83950, 8)
# 🧬 Found genes: ['CTNNA3' 'ATP23' 'BLOC1S2' 'CCDC33' 'CKMT1A' 'CKMT1B' 'COG4' 'DISC1'
#  'FAM161A' 'FAM161B' 'FAM9A' 'JUP' 'KATNAL1' 'MBD3L1' 'MYOG' 'ORC2'
#  'PLAGL2' 'PNMA5' 'REL' 'TNNI1' 'TNNI2' 'TRIM54' 'USHBP1' 'ZG16' 'ZNF474']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 532
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CTNNA3_PPI_filtered_S0_17042025.csv (42725 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CUL3_PPI.xlsx...
# 🧬 Protein of Interest: CUL3
# 📊 Loaded: (43654, 8)
# 🧬 Found genes: ['CUL3' 'BTBD3' 'BTBD6' 'GMCL1' 'KCTD10' 'KCTD13' 'KCTD7' 'KCTD9' 'KEAP1'
#  'KLHL12' 'KLHL3' 'SHKBP1' 'ZMAT4']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 615
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CUL3_PPI_filtered_S0_17042025.csv (27781 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CXCL16_PPI.xlsx...
# 🧬 Protein of Interest: CXCL16
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CXCL16' 'FKBP7']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 585
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CXCL16_PPI_filtered_S0_17042025.csv (4096 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/CYP4F12_PPI.xlsx...
# 🧬 Protein of Interest: CYP4F12
# 📊 Loaded: (6716, 8)
# 🧬 Found genes: ['CYP4F12' 'MEOX2']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 493
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CYP4F12_PPI_filtered_S0_17042025.csv (3300 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/DCX_PPI.xlsx...
# 🧬 Protein of Interest: DCX
# 📊 Loaded: (16855, 8)
# 🧬 Found genes: ['DCX' 'IKZF1' 'MEOX1' 'MTUS2' 'ZRANB1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 465
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DCX_PPI_filtered_S0_17042025.csv (6585 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/DDX20_PPI.xlsx...
# 🧬 Protein of Interest: DDX20
# 📊 Loaded: (6742, 8)
# 🧬 Found genes: ['DDX20' 'GEMIN4']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 603
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DDX20_PPI_filtered_S0_17042025.csv (4226 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/DIABLO_PPI.xlsx...
# 🧬 Protein of Interest: DIABLO
# 📊 Loaded: (23597, 8)
# 🧬 Found genes: ['DIABLO' 'AGTRAP' 'ARL6IP1' 'FADS6' 'MPC2' 'RHBDD2' 'SYP']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 548
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DIABLO_PPI_filtered_S0_17042025.csv (13622 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/DMC1_PPI.xlsx...
# 🧬 Protein of Interest: DMC1
# 📊 Loaded: (10113, 8)
# 🧬 Found genes: ['DMC1' 'NIF3L1' 'PICK1']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 563
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DMC1_PPI_filtered_S0_17042025.csv (5640 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/DOLK_PPI.xlsx...
# 🧬 Protein of Interest: DOLK
# 📊 Loaded: (26968, 8)
# 🧬 Found genes: ['DOLK' 'CD79A' 'CREB3L1' 'EDA' 'GALNT8' 'KCNA1' 'KCNA10' 'SLC7A6']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 586
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DOLK_PPI_filtered_S0_17042025.csv (16496 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/DUSP23_PPI.xlsx...
# 🧬 Protein of Interest: DUSP23
# 📊 Loaded: (10113, 8)
# 🧬 Found genes: ['DUSP23' 'EXOSC8' 'UBA3']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 610
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DUSP23_PPI_filtered_S0_17042025.csv (6393 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EFEMP1_PPI.xlsx...
# 🧬 Protein of Interest: EFEMP1
# 📊 Loaded: (19866, 8)
# 🧬 Found genes: ['EFEMP1' 'BAG4' 'CYSRT1' 'KRTAP21-2' 'LCE2C' 'TRAF2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 544
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EFEMP1_PPI_filtered_S0_17042025.csv (10986 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EFHC1_PPI.xlsx...
# 🧬 Protein of Interest: EFHC1
# 📊 Loaded: (69531, 8)
# 🧬 Found genes: ['EFHC1' 'C20orf85' 'CCDC130' 'CFAP161' 'EFHC2' 'GADD45B' 'IKZF3' 'KCTD4'
#  'KRT18' 'LMO2' 'MIIP' 'NQO2' 'NUP54' 'PAX6' 'PBX1' 'PBX2' 'REL' 'RNF125'
#  'TCF4' 'TEX11' 'ZBED1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 614
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EFHC1_PPI_filtered_S0_17042025.csv (44163 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EIF2B1_PPI.xlsx...
# 🧬 Protein of Interest: EIF2B1
# 📊 Loaded: (13244, 8)
# 🧬 Found genes: ['EIF2B1' 'ATF5' 'C1orf50' 'RD3']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 615
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EIF2B1_PPI_filtered_S0_17042025.csv (8440 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EIF2B4_PPI.xlsx...
# 🧬 Protein of Interest: EIF2B4
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['EIF2B4' 'EIF2B2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 610
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EIF2B4_PPI_filtered_S0_17042025.csv (4214 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EMD_PPI.xlsx...
# 🧬 Protein of Interest: EMD
# 📊 Loaded: (135751, 8)
# 🧬 Found genes: ['EMD' 'ANK1' 'ANKS6' 'AVPI1' 'BANF1' 'BEND7' 'CATSPER1' 'CERS4' 'CPLX4'
#  'CXorf66' 'ERMAP' 'FAM209A' 'FATE1' 'GORAB' 'GPR152' 'GRAMD2A' 'HSF2BP'
#  'INCA1' 'KCNJ8' 'KCNN3' 'LIME1' 'LUZP4' 'MEOX1' 'MEOX2' 'MTERF4' 'PIMREG'
#  'REL' 'SOWAHB' 'SSMEM1' 'STX1A' 'TCF23' 'TMEM174' 'TMEM200A' 'TMEM52B'
#  'TRAF3IP3' 'ZFP57' 'ZNF329' 'ZNF341' 'ZNF398' 'ZNF549' 'ZNF774']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 607
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EMD_PPI_filtered_S0_17042025.csv (86141 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ESR2_PPI.xlsx...
# 🧬 Protein of Interest: ESR2
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['ESR2' 'CYSRT1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 571
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ESR2_PPI_filtered_S0_17042025.csv (3798 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EXOC8_PPI.xlsx...
# 🧬 Protein of Interest: EXOC8
# 📊 Loaded: (148995, 8)
# 🧬 Found genes: ['EXOC8' 'ATP23' 'BICRAL' 'BLOC1S6' 'BLZF1' 'CAPN3' 'CCDC33' 'CCHCR1'
#  'CDSN' 'DMAP1' 'FAM217B' 'GTF2E2' 'IKZF3' 'KIAA1217' 'KIFC3' 'KRT34'
#  'KRT36' 'KRT76' 'MBD3L1' 'MIPOL1' 'MTUS2' 'NAB2' 'NDC80' 'NUP54' 'PBX4'
#  'PCM1' 'PRR35' 'RINT1' 'TCF12' 'TCF4' 'TFIP11' 'TRIM21' 'TRIM27' 'TRIM54'
#  'UQCC2' 'USHBP1' 'USP54' 'VPS16' 'VPS37B' 'WASHC1' 'ZC2HC1A' 'ZNF177'
#  'ZNF559-ZNF177' 'ZNF566' 'ZNF628']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 595
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EXOC8_PPI_filtered_S0_17042025.csv (92700 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/EZH2_PPI.xlsx...
# 🧬 Protein of Interest: EZH2
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['EZH2' 'EED']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 612
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EZH2_PPI_filtered_S0_17042025.csv (4214 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FA2H_PPI.xlsx...
# 🧬 Protein of Interest: FA2H
# 📊 Loaded: (16490, 8)
# 🧬 Found genes: ['FA2H' 'ARMC12' 'CREB3L1' 'ERLIN1' 'TMEM14B']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 542
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FA2H_PPI_filtered_S0_17042025.csv (8595 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FADD_PPI.xlsx...
# 🧬 Protein of Interest: FADD
# 📊 Loaded: (19788, 8)
# 🧬 Found genes: ['FADD' 'BTG1' 'NUTM2F' 'RNF4' 'TRADD' 'UBE2I']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 594
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FADD_PPI_filtered_S0_17042025.csv (12408 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FAM161A_PPI.xlsx...
# 🧬 Protein of Interest: FAM161A
# 📊 Loaded: (199140, 8)
# 🧬 Found genes: ['FAM161A' 'AXIN2' 'BACH2' 'BHLHB9' 'CADPS' 'CALCOCO2' 'CARD9' 'CCDC136'
#  'CCDC57' 'CCNC' 'CCNDBP1' 'CDR2' 'CDR2L' 'CEP63' 'CEP70' 'DHX32' 'FXR1'
#  'GAS8' 'GOLGA6L9' 'GRIPAP1' 'HMBOX1' 'HOOK1' 'HOOK2' 'INO80E' 'JRK'
#  'KANK2' 'KIAA1328' 'KIFC3' 'KRTAP10-8' 'KRTAP2-3' 'KRTAP2-4' 'KRTAP5-7'
#  'KRTAP5-9' 'LDOC1' 'LURAP1L' 'LZTS2' 'MCC' 'MDFI' 'MID2' 'MIPOL1' 'MTUS2'
#  'PIBF1' 'PICK1' 'POC5' 'PRKAR1B' 'ROPN1' 'TAX1BP1' 'TBC1D1' 'TFIP11'
#  'TNIP1' 'TRAF2' 'TRIM27' 'TRIM54' 'VPS52' 'ZBTB1' 'ZBTB8A' 'ZIM2'
#  'ZNF526' 'ZRANB1' 'ZSCAN12']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 606
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FAM161A_PPI_filtered_S0_17042025.csv (124527 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FAM187A_PPI.xlsx...
# 🧬 Protein of Interest: FAM187A
# 📊 Loaded: (16542, 8)
# 🧬 Found genes: ['FAM187A' 'GRIPAP1' 'MEOX2' 'PICK1' 'VAC14']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 67
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FAM187A_PPI_filtered_S0_17042025.csv (405 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FASLG_PPI.xlsx...
# 🧬 Protein of Interest: FASLG
# 📊 Loaded: (6596, 8)
# 🧬 Found genes: ['FASLG' 'CYSRT1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 369
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FASLG_PPI_filtered_S0_17042025.csv (2780 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FBP1_PPI.xlsx...
# 🧬 Protein of Interest: FBP1
# 📊 Loaded: (3298, 8)
# 🧬 Found genes: ['FBP1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 577
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FBP1_PPI_filtered_S0_17042025.csv (2013 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FGD4_PPI.xlsx...
# 🧬 Protein of Interest: FGD4
# 📊 Loaded: (6596, 8)
# 🧬 Found genes: ['FGD4' 'C9orf16']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 608
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FGD4_PPI_filtered_S0_17042025.csv (4166 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FKBP6_PPI.xlsx...
# 🧬 Protein of Interest: FKBP6
# 📊 Loaded: (26384, 8)
# 🧬 Found genes: ['FKBP6' 'CDK5RAP3' 'KRT75' 'MEOX2' 'PIAS2' 'PICK1' 'PPP1R32' 'RNF4']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 462
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FKBP6_PPI_filtered_S0_17042025.csv (11408 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FOXD4_PPI.xlsx...
# 🧬 Protein of Interest: FOXD4
# 📊 Loaded: (6596, 8)
# 🧬 Found genes: ['FOXD4' 'MDFI']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 384
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FOXD4_PPI_filtered_S0_17042025.csv (2012 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FOXP3_PPI.xlsx...
# 🧬 Protein of Interest: FOXP3
# 📊 Loaded: (6596, 8)
# 🧬 Found genes: ['FOXP3' 'FOSB']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 460
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FOXP3_PPI_filtered_S0_17042025.csv (2984 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FTH1_PPI.xlsx...
# 🧬 Protein of Interest: FTH1
# 📊 Loaded: (6596, 8)
# 🧬 Found genes: ['FTH1' 'BAG4']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FTH1_PPI_filtered_S0_17042025.csv (4218 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/FUCA1_PPI.xlsx...
# 🧬 Protein of Interest: FUCA1
# 📊 Loaded: (6596, 8)
# 🧬 Found genes: ['FUCA1' 'UBQLN2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 612
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FUCA1_PPI_filtered_S0_17042025.csv (4204 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GAD1_PPI.xlsx...
# 🧬 Protein of Interest: GAD1
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['GAD1' 'AGTRAP' 'CMTM5']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 519
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GAD1_PPI_filtered_S0_17042025.csv (4752 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GALE_PPI.xlsx...
# 🧬 Protein of Interest: GALE
# 📊 Loaded: (3311, 8)
# 🧬 Found genes: ['GALE']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 608
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GALE_PPI_filtered_S0_17042025.csv (2093 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GALT_PPI.xlsx...
# 🧬 Protein of Interest: GALT
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['GALT' 'UBTD2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 604
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GALT_PPI_filtered_S0_17042025.csv (4168 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GATA2_PPI.xlsx...
# 🧬 Protein of Interest: GATA2
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['GATA2' 'CYSRT1' 'KRTAP6-3']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 541
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GATA2_PPI_filtered_S0_17042025.csv (5721 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GCK_PPI.xlsx...
# 🧬 Protein of Interest: GCK
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['GCK' 'GCKR' 'SPDYE4']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 515
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GCK_PPI_filtered_S0_17042025.csv (4575 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GCM2_PPI.xlsx...
# 🧬 Protein of Interest: GCM2
# 📊 Loaded: (26488, 8)
# 🧬 Found genes: ['GCM2' 'CRX' 'FHL3' 'HSF2BP' 'TOX3' 'TRAF1' 'USP54' 'ZMIZ2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 358
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GCM2_PPI_filtered_S0_17042025.csv (5800 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GFAP_PPI.xlsx...
# 🧬 Protein of Interest: GFAP
# 📊 Loaded: (23177, 8)
# 🧬 Found genes: ['GFAP' 'KRT15' 'PIAS2' 'TBC1D21' 'TFIP11' 'TP53BP2' 'ZNF774']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 444
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GFAP_PPI_filtered_S0_17042025.csv (8274 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GLYCTK_PPI.xlsx...
# 🧬 Protein of Interest: GLYCTK
# 📊 Loaded: (62909, 8)
# 🧬 Found genes: ['GLYCTK' 'BAIAP2L2' 'DTX2' 'EFHC2' 'GMPPB' 'KRT34' 'KRT75' 'KRTAP6-2'
#  'KRTAP6-3' 'LZTS2' 'MAGED1' 'METTL15' 'PFDN5' 'PICK1' 'PLAGL2' 'RBCK1'
#  'REL' 'SMUG1' 'ZNF620']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 586
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GLYCTK_PPI_filtered_S0_17042025.csv (39064 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GMPPB_PPI.xlsx...
# 🧬 Protein of Interest: GMPPB
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['GMPPB' 'GMPPA']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 601
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GMPPB_PPI_filtered_S0_17042025.csv (4178 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GNAI3_PPI.xlsx...
# 🧬 Protein of Interest: GNAI3
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['GNAI3' 'GPSM2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GNAI3_PPI_filtered_S0_17042025.csv (4228 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GNE_PPI.xlsx...
# 🧬 Protein of Interest: GNE
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['GNE' 'PLA2G10']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 609
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GNE_PPI_filtered_S0_17042025.csv (4196 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GOSR2_PPI.xlsx...
# 🧬 Protein of Interest: GOSR2
# 📊 Loaded: (33110, 8)
# 🧬 Found genes: ['GOSR2' 'CYB561' 'EBP' 'FATE1' 'HSD17B13' 'JAGN1' 'STX1A' 'STX4' 'TMCO5A'
#  'TMEM205']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 597
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/GOSR2_PPI_filtered_S0_17042025.csv (20850 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/GRN_PPI.xlsx...
# 🧬 Protein of Interest: GRN
# 📊 Loaded: (52976, 8)
# 🧬 Found genes: ['GRN' 'CCDC33' 'CXCL5' 'CYSRT1' 'HOXA1' 'KRTAP11-1' 'LCE1D' 'LCE2B'
#  'LCE2D' 'LCE3E' 'LCE4A' 'MEOX2' 'NUFIP2' 'OTX1' 'SMCP' 'TSPAN4']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 613
# ...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/STAC3_PPI.xlsx...
# 🧬 Protein of Interest: STAC3
# 📊 Loaded: (3311, 8)
# 🧬 Found genes: ['STAC3']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 579
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/STAC3_PPI_filtered_S0_17042025.csv (1954 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/STAR_PPI.xlsx...
# 🧬 Protein of Interest: STAR
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['STAR' 'AGTRAP' 'MAGEA11']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 496
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/STAR_PPI_filtered_S0_17042025.csv (4578 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/STOX1_PPI.xlsx...
# 🧬 Protein of Interest: STOX1
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['STOX1' 'ADARB1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 576
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/STOX1_PPI_filtered_S0_17042025.csv (3804 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/STXBP1_PPI.xlsx...
# 🧬 Protein of Interest: STXBP1
# 📊 Loaded: (23177, 8)
# 🧬 Found genes: ['STXBP1' 'CENPP' 'MAPK1' 'STX19' 'STX5' 'SYTL4' 'TRIM38']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 597
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/STXBP1_PPI_filtered_S0_17042025.csv (14245 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/SUOX_PPI.xlsx...
# 🧬 Protein of Interest: SUOX
# 📊 Loaded: (99330, 8)
# 🧬 Found genes: ['SUOX' 'BAG4' 'C1D' 'CAMK2A' 'CCDC103' 'CDCA4' 'CEP76' 'EIF3F' 'EYA2'
#  'FAM187A' 'FNDC3B' 'HMG20A' 'INCA1' 'ITGB3BP' 'KIAA0753' 'KRT27' 'LMO4'
#  'MAGEA11' 'MAGEB10' 'MEIS3' 'MORN3' 'NUP62' 'PTTG2' 'REL' 'RUSC1'
#  'SERTAD3' 'SNF8' 'SOHLH1' 'UBQLN2' 'UBR2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 595
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/SUOX_PPI_filtered_S0_17042025.csv (61440 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/SYNGR1_PPI.xlsx...
# 🧬 Protein of Interest: SYNGR1
# 📊 Loaded: (13244, 8)
# 🧬 Found genes: ['SYNGR1' 'FATE1' 'TMEM14B' 'TMEM80']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 602
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/SYNGR1_PPI_filtered_S0_17042025.csv (8292 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TAT_PPI.xlsx...
# 🧬 Protein of Interest: TAT
# 📊 Loaded: (3311, 8)
# 🧬 Found genes: ['TAT']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 382
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TAT_PPI_filtered_S0_17042025.csv (997 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TFG_PPI.xlsx...
# 🧬 Protein of Interest: TFG
# 📊 Loaded: (46354, 8)
# 🧬 Found genes: ['TFG' 'BOLL' 'CEP55' 'DAZAP2' 'EYA2' 'FAM168A' 'MAGED1' 'MAPK1IP1L'
#  'PLA2G10' 'POU2AF1' 'RNF4' 'SF3B4' 'SMUG1' 'ZNF34']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TFG_PPI_filtered_S0_17042025.csv (29596 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/THAP1_PPI.xlsx...
# 🧬 Protein of Interest: THAP1
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['THAP1' 'RALYL' 'ZNF408']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 600
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/THAP1_PPI_filtered_S0_17042025.csv (6264 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TH_PPI.xlsx...
# 🧬 Protein of Interest: TH
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['TH' 'PUF60']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 374
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TH_PPI_filtered_S0_17042025.csv (2174 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TIMM8A_PPI.xlsx...
# 🧬 Protein of Interest: TIMM8A
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['TIMM8A' 'ARID3A']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 592
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TIMM8A_PPI_filtered_S0_17042025.csv (4134 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TMEM43_PPI.xlsx...
# 🧬 Protein of Interest: TMEM43
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['TMEM43' 'FAM209A' 'GRAMD2B']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 614
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TMEM43_PPI_filtered_S0_17042025.csv (6321 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TPK1_PPI.xlsx...
# 🧬 Protein of Interest: TPK1
# 📊 Loaded: (3311, 8)
# 🧬 Found genes: ['TPK1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 607
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TPK1_PPI_filtered_S0_17042025.csv (2084 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TPM1_PPI.xlsx...
# 🧬 Protein of Interest: TPM1
# 📊 Loaded: (19866, 8)
# 🧬 Found genes: ['TPM1' 'FAM9C' 'KXD1' 'MAD1L1' 'PSMC5' 'WASHC1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 613
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TPM1_PPI_filtered_S0_17042025.csv (12654 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TPM2_PPI.xlsx...
# 🧬 Protein of Interest: TPM2
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['TPM2' 'SNAPIN' 'TFPT']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 604
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TPM2_PPI_filtered_S0_17042025.csv (6282 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TPM3_PPI.xlsx...
# 🧬 Protein of Interest: TPM3
# 📊 Loaded: (43043, 8)
# 🧬 Found genes: ['TPM3' 'CCHCR1' 'FAM9C' 'HSF2' 'KXD1' 'MAD1L1' 'NUP54' 'OIP5' 'PHLDB3'
#  'PSMC5' 'SNAPIN' 'TFPT' 'WASHC1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 615
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TPM3_PPI_filtered_S0_17042025.csv (27378 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TREX1_PPI.xlsx...
# 🧬 Protein of Interest: TREX1
# 📊 Loaded: (26488, 8)
# 🧬 Found genes: ['TREX1' 'CYB561' 'CYSRT1' 'EBP' 'ELOVL4' 'HSD17B13' 'TMEM205' 'TMX2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 370
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TREX1_PPI_filtered_S0_17042025.csv (10792 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TRIB3_PPI.xlsx...
# 🧬 Protein of Interest: TRIB3
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['TRIB3' 'ATF4']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 593
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TRIB3_PPI_filtered_S0_17042025.csv (4094 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TRIM32_PPI.xlsx...
# 🧬 Protein of Interest: TRIM32
# 📊 Loaded: (16555, 8)
# 🧬 Found genes: ['TRIM32' 'ABI2' 'RABAC1' 'UBQLN1' 'UBQLN2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 589
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TRIM32_PPI_filtered_S0_17042025.csv (10155 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TSFM_PPI.xlsx...
# 🧬 Protein of Interest: TSFM
# 📊 Loaded: (13244, 8)
# 🧬 Found genes: ['TSFM' 'GAS8' 'GOLGA6L9' 'RALBP1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 611
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TSFM_PPI_filtered_S0_17042025.csv (8344 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TTPA_PPI.xlsx...
# 🧬 Protein of Interest: TTPA
# 📊 Loaded: (33110, 8)
# 🧬 Found genes: ['TTPA' 'AGTRAP' 'BIRC7' 'CMTM5' 'COQ3' 'FAM25A' 'FAM25C' 'FAM25G' 'RPRM'
#  'SCAMP1']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 458
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TTPA_PPI_filtered_S0_17042025.csv (12870 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TTR_PPI.xlsx...
# 🧬 Protein of Interest: TTR
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['TTR' 'ATF5']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 476
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TTR_PPI_filtered_S0_17042025.csv (2826 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/TUFM_PPI.xlsx...
# 🧬 Protein of Interest: TUFM
# 📊 Loaded: (19866, 8)
# 🧬 Found genes: ['TUFM' 'ARL6IP1' 'CMTM5' 'DGAT2L6' 'HMBOX1' 'MTIF3']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 615
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TUFM_PPI_filtered_S0_17042025.csv (12678 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/UBE3A_PPI.xlsx...
# 🧬 Protein of Interest: UBE3A
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['UBE3A' 'TAT']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/UBE3A_PPI_filtered_S0_17042025.csv (4228 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/UBQLN2_PPI.xlsx...
# 🧬 Protein of Interest: UBQLN2
# 📊 Loaded: (126058, 8)
# 🧬 Found genes: ['UBQLN2' 'AGR2' 'AGR3' 'BCL2L11' 'CCDC158' 'CLPSL2' 'CSN2' 'DAZAP2'
#  'DEFA6' 'ECM1' 'EFEMP1' 'ERP27' 'GALP' 'GPX7' 'HGS' 'HSPA13' 'JPH4'
#  'KRTAP13-1' 'KRTAP19-5' 'LASP1' 'LATS1' 'LY6G6D' 'MAGED1' 'MDK' 'NPY'
#  'NRN1L' 'PRR4' 'PSMD2' 'RBFOX2' 'RNF208' 'RNF4' 'RTL8C' 'SFTPA2' 'SMIM19'
#  'STAM2' 'TRIM32' 'WFDC12' 'ZG16B']
#
# 🔍 Before filtering: Unique Cell Types = 757
# 🔍 After filtering: Unique Cell Types = 609
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/UBQLN2_PPI_filtered_S0_17042025.csv (80098 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/UROD_PPI.xlsx...
# 🧬 Protein of Interest: UROD
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['UROD' 'PHKA2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 614
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/UROD_PPI_filtered_S0_17042025.csv (4220 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/VAPB_PPI.xlsx...
# 🧬 Protein of Interest: VAPB
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['VAPB' 'RETREG3' 'ZBTB22']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 614
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/VAPB_PPI_filtered_S0_17042025.csv (6330 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/VHL_PPI.xlsx...
# 🧬 Protein of Interest: VHL
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['VHL' 'HSF2BP']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 613
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/VHL_PPI_filtered_S0_17042025.csv (4218 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/VPS33B_PPI.xlsx...
# 🧬 Protein of Interest: VPS33B
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['VPS33B' 'VIPAS39']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 580
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/VPS33B_PPI_filtered_S0_17042025.csv (4014 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/WRAP53_PPI.xlsx...
# 🧬 Protein of Interest: WRAP53
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['WRAP53' 'UBAP2' 'VAC14']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 597
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/WRAP53_PPI_filtered_S0_17042025.csv (6198 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/XRCC2_PPI.xlsx...
# 🧬 Protein of Interest: XRCC2
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['XRCC2' 'RAD51D']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 578
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/XRCC2_PPI_filtered_S0_17042025.csv (3898 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/XRCC4_PPI.xlsx...
# 🧬 Protein of Interest: XRCC4
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['XRCC4' 'KRT27' 'MAGEA6']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/XRCC4_PPI_filtered_S0_17042025.csv (6327 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ZCCHC12_PPI.xlsx...
# 🧬 Protein of Interest: ZCCHC12
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['ZCCHC12' 'KPNA3']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 466
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZCCHC12_PPI_filtered_S0_17042025.csv (3090 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ZMYND10_PPI.xlsx...
# 🧬 Protein of Interest: ZMYND10
# 📊 Loaded: (19866, 8)
# 🧬 Found genes: ['ZMYND10' 'CDR1' 'EIF3M' 'IFT43' 'NUTM1' 'NUTM2F']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 541
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZMYND10_PPI_filtered_S0_17042025.csv (10890 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ZNF24_PPI.xlsx...
# 🧬 Protein of Interest: ZNF24
# 📊 Loaded: (6622, 8)
# 🧬 Found genes: ['ZNF24' 'ZSCAN32']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 616
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZNF24_PPI_filtered_S0_17042025.csv (4226 rows)
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/ZNF624_PPI.xlsx...
# 🧬 Protein of Interest: ZNF624
# 📊 Loaded: (9933, 8)
# 🧬 Found genes: ['ZNF624' 'GOLGA6L9' 'MTUS2']
#
# 🔍 Before filtering: Unique Cell Types = 755
# 🔍 After filtering: Unique Cell Types = 590
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZNF624_PPI_filtered_S0_17042025.csv (6060 rows)

# %% [markdown]
# **Quick summary of what we did:**
#
# 🔹 **Step 1: Data cleaning & pre-processing**
# - Fix column names (strip spaces, standardize names)
# - Ensure all necessary columns exist (Tissue, Cell Type, Gene Symbol, Expression, etc.)
# - Recalculate %Cells Expressing Gene (Num_Cells_Expressing_Gene / Cell Count * 100)
#
# 🔹 **Step 2: Filtering based on POI (Protein of Interest)**
# - Remove bulk-level data (Cell Type = "aggregated" or "cell")
# - Remove small clusters (Cell Count < 1000)
# - Ensure POI is expressed at a minimum threshold level (Expression > 0.1 in at least some cells)
# - Drop cell types where POI is missing or has Expression ≤ 0.1 → ensures we don’t process interactions in irrelevant clusters
# - Retain only tissue-cell type pairs where POI meets this threshold
#
# 🔹 **Step 3: Additional Gene-level filtering**
# - Remove genes with extremely low absolute expression (Expression < 0.1 in >90% of clusters)
# (We moved percentile-based filtering max(10%, 25th percentile) to Step 3 for hypothesis testing instead of prematurely removing weak signals.)
#
# 🔹 **Step 4: Compute Normalization & scores**
# - Compute Expression Z-score (per tissue)
# - Compute scRNA-score using:
#
# W1 (Robustness) = % of cells expressing the gene
# W2 (Expression Specificity) = How uniquely a gene is expressed per tissue
# W3 (Cluster Diversity) = Spread of gene expression across different cell types
#
# **Weights Adjusted**:
#
# W1 = 0.4 → Slightly higher to prioritize robust expression
# W2 = 0.4 → Maintained high importance for specificity
# W3 = 0.2 → Lowered, as broad cluster distribution isn't always informative
#
# Key fixes as compared to previous codes:
#
# ✅ More accurate removal of weak/noisy POI signals (Expression > 0.1)
# ✅ Ensures POI must be present in a cell type/state before interactions are processed
# ✅ Retains interactions that are functionally relevant but may have low POI expression
# ✅ Avoids premature exclusion of weakly expressed yet functionally important genes (like MLH1)

# %%
#Define the output directory
filtered_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0"

#Get all filtered files
filtered_files = [f for f in os.listdir(filtered_dir) if f.endswith("_filtered_S0_17042025.csv")]

#Print total number of output files
print(f"\n Total filtered output files: {len(filtered_files)}")
# Out:
#  Total filtered output files: 242

# %% [markdown]
# 1. Structure Checks:
# - Tissue + Cell Type structure present.
# - Within a tissue+cluster combination, POI (e.g., ACSF3, LITAF) is present & ordered first.
#
#
# 2. All values for:
# - %Cells Expressing Gene
# - Robustness, Expression_Specificity, Cluster_Diversity & scRNA_score
#
# 3. Filtering/QC criteria:
# - No cell type has <1000 cells
# - No bulk-level aggregate/cell entries.
# - No genes with expression <0.1 across 90% of cell types.
