# %% [markdown]
# <p style="font-size:18px; font-weight:bold;"> 2025 Olivia Debnath</p>
# <p style="font-size:14px;">Dana-Farber Cancer Institute & Harvard Medical School</p>

# %% [markdown]
# Moving forward from PPI_CellxGene_downstream_S0_12032025.ipynb (basic filtering & QC for genes & cell types)
#
# **Step 1 (Hypothesis Testing) evaluating strong co-expression of P.O.I & its partners in a cell type/state**
#
#
# **Hypothesis 1 (H₁): Strong co-Expression & functional disruption**
#
# If a gene & at least one of its interactors are moderately to highly co-expressed (cut-off: ≥30%) in a specific cell type/state, then perturbation of the PPI (due to mutations, knockdown, or inhibition) is likely to disrupt a specific cellular function.
#
# 🔹 Why this hypothesis?
#
# 1. Cell type specificity matters:
#    - Many biological processes depend on tightly regulated co-expression of genes in specific cell types or functional states. E.g.,  Synaptic vesicle trafficking in neurons requires co-expression of essential interactors like STXBP1 & SYTL4/MAPK1 in neuronal subpopulations.
#
# 2. Pathogenicity & functional impact:
#     - Disrupting PPIs in highly co-expressed modules can lead to disease phenotypes. E.g., STXBP1 mutations impair synaptic function, contributing to neurodevelopmental disorders (e.g., epilepsy, intellectual disability).
#
#     - Similar disruptions in cardiomyocytes, hepatocytes, or immune cells can drive distinct disease mechanisms.
#
#
# 🔹 Applications:
#     - Prioritizing functionally relevant PPIs for therapeutic targeting.
#     - Identifying tissue/cell-type-specific vulnerabilities to genetic mutations.

# %%
import os
print(os.path.exists("./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/"))
# Out:
# True

# %%
#Define input directory: 
input_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/"  

#Dynamically find all relevant input files
input_files = sorted([f for f in os.listdir(input_dir) if f.endswith("_filtered_S0_17042025.csv")]) 
print(input_files) 

#Print total count of files
print(f"\n✅ Total Input Files Found: {len(input_files)}")
# Out:
# ['ACSF3_PPI_filtered_S0_17042025.csv', 'ACTB_PPI_filtered_S0_17042025.csv', 'ACY1_PPI_filtered_S0_17042025.csv', 'ADIPOQ_PPI_filtered_S0_17042025.csv', 'AGXT_PPI_filtered_S0_17042025.csv', 'AHCY_PPI_filtered_S0_17042025.csv', 'AIPL1_PPI_filtered_S0_17042025.csv', 'ALAS2_PPI_filtered_S0_17042025.csv', 'ALDOA_PPI_filtered_S0_17042025.csv', 'ALOX5_PPI_filtered_S0_17042025.csv', 'AMPD2_PPI_filtered_S0_17042025.csv', 'ANKRD1_PPI_filtered_S0_17042025.csv', 'ANXA11_PPI_filtered_S0_17042025.csv', 'AP2S1_PPI_filtered_S0_17042025.csv', 'APOA1_PPI_filtered_S0_17042025.csv', 'APOD_PPI_filtered_S0_17042025.csv', 'ASNS_PPI_filtered_S0_17042025.csv', 'ATPAF2_PPI_filtered_S0_17042025.csv', 'BAG3_PPI_filtered_S0_17042025.csv', 'BANF1_PPI_filtered_S0_17042025.csv', 'BCL10_PPI_filtered_S0_17042025.csv', 'BFSP2_PPI_filtered_S0_17042025.csv', 'BLK_PPI_filtered_S0_17042025.csv', 'C1QA_PPI_filtered_S0_17042025.csv', 'C1QB_PPI_filtered_S0_17042025.csv', 'C1QC_PPI_filtered_S0_17042025.csv', 'CA8_PPI_filtered_S0_17042025.csv', 'CACNB4_PPI_filtered_S0_17042025.csv', 'CCBE1_PPI_filtered_S0_17042025.csv', 'CCDC103_PPI_filtered_S0_17042025.csv', 'CD151_PPI_filtered_S0_17042025.csv', 'CDA_PPI_filtered_S0_17042025.csv', 'CDC73_PPI_filtered_S0_17042025.csv', 'CDK4_PPI_filtered_S0_17042025.csv', 'CDKN1A_PPI_filtered_S0_17042025.csv', 'CDKN2C_PPI_filtered_S0_17042025.csv', 'CFP_PPI_filtered_S0_17042025.csv', 'CHN1_PPI_filtered_S0_17042025.csv', 'CHRNG_PPI_filtered_S0_17042025.csv', 'CLCNKA_PPI_filtered_S0_17042025.csv', 'CLDN19_PPI_filtered_S0_17042025.csv', 'CLN6_PPI_filtered_S0_17042025.csv', 'COL10A1_PPI_filtered_S0_17042025.csv', 'COL2A1_PPI_filtered_S0_17042025.csv', 'COMP_PPI_filtered_S0_17042025.csv', 'COQ8A_PPI_filtered_S0_17042025.csv', 'CRADD_PPI_filtered_S0_17042025.csv', 'CREB1_PPI_filtered_S0_17042025.csv', 'CRYAA_PPI_filtered_S0_17042025.csv', 'CRYAB_PPI_filtered_S0_17042025.csv', 'CRYBB1_PPI_filtered_S0_17042025.csv', 'CSNK1D_PPI_filtered_S0_17042025.csv', 'CSNK1E_PPI_filtered_S0_17042025.csv', 'CTH_PPI_filtered_S0_17042025.csv', 'CTNNA3_PPI_filtered_S0_17042025.csv', 'CUL3_PPI_filtered_S0_17042025.csv', 'CXCL16_PPI_filtered_S0_17042025.csv', 'CYP4F12_PPI_filtered_S0_17042025.csv', 'DCX_PPI_filtered_S0_17042025.csv', 'DDX20_PPI_filtered_S0_17042025.csv', 'DIABLO_PPI_filtered_S0_17042025.csv', 'DMC1_PPI_filtered_S0_17042025.csv', 'DOLK_PPI_filtered_S0_17042025.csv', 'DUSP23_PPI_filtered_S0_17042025.csv', 'EFEMP1_PPI_filtered_S0_17042025.csv', 'EFHC1_PPI_filtered_S0_17042025.csv', 'EIF2B1_PPI_filtered_S0_17042025.csv', 'EIF2B4_PPI_filtered_S0_17042025.csv', 'EMD_PPI_filtered_S0_17042025.csv', 'ESR2_PPI_filtered_S0_17042025.csv', 'EXOC8_PPI_filtered_S0_17042025.csv', 'EZH2_PPI_filtered_S0_17042025.csv', 'FA2H_PPI_filtered_S0_17042025.csv', 'FADD_PPI_filtered_S0_17042025.csv', 'FAM161A_PPI_filtered_S0_17042025.csv', 'FAM187A_PPI_filtered_S0_17042025.csv', 'FASLG_PPI_filtered_S0_17042025.csv', 'FBP1_PPI_filtered_S0_17042025.csv', 'FGD4_PPI_filtered_S0_17042025.csv', 'FKBP6_PPI_filtered_S0_17042025.csv', 'FOXD4_PPI_filtered_S0_17042025.csv', 'FOXP3_PPI_filtered_S0_17042025.csv', 'FTH1_PPI_filtered_S0_17042025.csv', 'FUCA1_PPI_filtered_S0_17042025.csv', 'GAD1_PPI_filtered_S0_17042025.csv', 'GALE_PPI_filtered_S0_17042025.csv', 'GALT_PPI_filtered_S0_17042025.csv', 'GATA2_PPI_filtered_S0_17042025.csv', 'GCK_PPI_filtered_S0_17042025.csv', 'GCM2_PPI_filtered_S0_17042025.csv', 'GFAP_PPI_filtered_S0_17042025.csv', 'GLYCTK_PPI_filtered_S0_17042025.csv', 'GMPPB_PPI_filtered_S0_17042025.csv', 'GNAI3_PPI_filtered_S0_17042025.csv', 'GNE_PPI_filtered_S0_17042025.csv', 'GOSR2_PPI_filtered_S0_17042025.csv', 'GRN_PPI_filtered_S0_17042025.csv', 'GSS_PPI_filtered_S0_17042025.csv', 'GSTA2_PPI_filtered_S0_17042025.csv', 'GSTZ1_PPI_filtered_S0_17042025.csv', 'GYG1_PPI_filtered_S0_17042025.csv', 'GYPA_PPI_filtered_S0_17042025.csv', 'HBD_PPI_filtered_S0_17042025.csv', 'HCFC1_PPI_filtered_S0_17042025.csv', 'HGD_PPI_filtered_S0_17042025.csv', 'HMBS_PPI_filtered_S0_17042025.csv' ...
#
# ✅ Total Input Files Found: 242

# %%
#Specify output directory: 
output_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/"
os.makedirs(output_dir, exist_ok=True)  #Ensure output directory exists

# %%
import pandas as pd
import numpy as np

# %%
#Define expression cutoffs - can be adjusted later. 
HIGH_EXP = 50  #Highly co-expressed threshold
MODERATE_EXP = 30  #Moderately co-expressed (H1 lower bound)


#We will test the previously generated *_gene_expression_S0_13032025 files as input & test for co-expression (Hypothesis 1): 
def process_H1_file(df, protein_of_interest):
    """ 
    Filters for strong co-expression (H1) and computes scRNA-score.
    Keeps only tissue/cell type pairs where:
    - POI ≥30% expression & at least one interactor ≥30% (moderate co-expression)
    - POI ≥50% expression & at least one interactor ≥50% (strong co-expression)
    """

    #**Ensure POI is moderately expressed (≥30%) in at least some cells**
    main_protein_present = df[(df["Gene Symbol"] == protein_of_interest) & (df["%Cells Expressing Gene"] >= MODERATE_EXP)]
    
    if main_protein_present.empty:
        print(f"⚠️ WARNING: {protein_of_interest} does not meet ≥30% expression in any valid cluster. Skipping file.")
        return None

    #**Identify valid interaction cases**
    interactors_present_30 = df[(df["Gene Symbol"] != protein_of_interest) & (df["%Cells Expressing Gene"] >= MODERATE_EXP)]

    #**Scenario 1: POI ≥30%, Interactor ≥30%**
    valid_case_1 = pd.merge(
        main_protein_present[["Tissue", "Cell Type"]],
        interactors_present_30[["Tissue", "Cell Type"]],
        on=["Tissue", "Cell Type"], how="inner"
    ).drop_duplicates()

    #**Scenario 2: Both POI & at least one interactor are highly expressed (≥50%)**
    main_protein_present_50 = df[(df["Gene Symbol"] == protein_of_interest) & (df["%Cells Expressing Gene"] >= HIGH_EXP)]
    interactors_present_50 = df[(df["Gene Symbol"] != protein_of_interest) & (df["%Cells Expressing Gene"] >= HIGH_EXP)]
    valid_case_2 = pd.merge(
        main_protein_present_50[["Tissue", "Cell Type"]],
        interactors_present_50[["Tissue", "Cell Type"]],
        on=["Tissue", "Cell Type"], how="inner"
    ).drop_duplicates()

    #**Print filtered results per scenario**
    print(f"\n📊 Scenario 1: {protein_of_interest} ≥30%, Interactor ≥30% (Moderate Co-Expression)")
    print(valid_case_1)

    print(f"\n📊 Scenario 2: Both {protein_of_interest} and at least one interactor ≥50% (Highly Co-Expressed)")
    print(valid_case_2)

    #**Combine all valid cases & filter data**
    valid_tissue_cell_types = pd.concat([valid_case_1, valid_case_2]).drop_duplicates()
    df = df.merge(valid_tissue_cell_types, on=["Tissue", "Cell Type"], how="inner")

    #**Define Co-Expression Category**
    conditions = [
        df["%Cells Expressing Gene"] >= HIGH_EXP,   #Highly Co-Expressed
        df["%Cells Expressing Gene"] >= MODERATE_EXP  #Moderately Co-Expressed
    ]
    categories = ["Highly Co-Expressed (≥50%)", "Moderately Co-Expressed (30-50%)"]

    df["Co-Expression Category"] = np.select(conditions, categories, default="Low Co-Expression (<30%)")

    #**Remove Lowly Expressed Genes (<30%) since they are not part of H1**
    df = df[df["Co-Expression Category"] != "Low Co-Expression (<30%)"]

    return df

# %%
#Exporting results as .xlsx to avoid character encoding issues. 

def process_all_H1_files():
    """ Processes all Step-2 filtered files and saves H1 filtered output as Excel (.xlsx). """
    for file in input_files:
        input_path = os.path.join(input_dir, file)
        print(f"\n📂 Processing: {input_path}...")

        #Extract POI dynamically from filename
        protein_of_interest = file.split("_")[0]  
        print(f"🧬 Identified Protein of Interest: {protein_of_interest}")

        #Read file
        df = pd.read_csv(input_path)

        #Process file
        processed_df = process_H1_file(df, protein_of_interest)  # Ensure this function is implemented correctly!

        if processed_df is not None and not processed_df.empty:
            #**Modify output filename for Step 3 H1 (Now Excel)**
            output_file = os.path.join(output_dir, file.replace("_S0_17042025", "_S1_H1_17042025").replace(".csv", ".xlsx"))
            
            #**Save as Excel (without encoding argument)**
            processed_df.to_excel(output_file, index=False)

            print(f"✅ Saved: {output_file}")
        else:
            print(f"⚠️ WARNING: No valid data after processing {file}. Skipping...")

#Run the function to process all files
process_all_H1_files()
# Out:
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ACSF3_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ACSF3
# ⚠️ WARNING: ACSF3 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing ACSF3_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ACTB_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ACTB
#
# 📊 Scenario 1: ACTB ≥30%, Interactor ≥30% (Moderate Co-Expression)
#               Tissue                               Cell Type
# 0     adipose tissue                                  B cell
# 1     adipose tissue         CD4-positive, alpha-beta T cell
# 2     adipose tissue         CD8-positive, alpha-beta T cell
# 3     adipose tissue                                  T cell
# 4     adipose tissue                       alpha-beta T cell
# ...              ...                                     ...
# 1819          uterus                            stromal cell
# 1820          uterus                   stromal cell of ovary
# 1821          uterus                         supporting cell
# 1822          uterus              uterine smooth muscle cell
# 1824          uterus  vascular associated smooth muscle cell
#
# [1819 rows x 2 columns]
#
# 📊 Scenario 2: Both ACTB and at least one interactor ≥50% (Highly Co-Expressed)
#               Tissue                               Cell Type
# 0     adipose tissue         CD4-positive, alpha-beta T cell
# 1     adipose tissue         CD8-positive, alpha-beta T cell
# 2     adipose tissue                       alpha-beta T cell
# 3     adipose tissue                              blood cell
# 4     adipose tissue                    innate lymphoid cell
# ...              ...                                     ...
# 1604          uterus                            stromal cell
# 1605          uterus                   stromal cell of ovary
# 1606          uterus                         supporting cell
# 1607          uterus              uterine smooth muscle cell
# 1608          uterus  vascular associated smooth muscle cell
#
# [1609 rows x 2 columns]
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/ACTB_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ACY1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ACY1
# ⚠️ WARNING: ACY1 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing ACY1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ADIPOQ_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ADIPOQ
#
# 📊 Scenario 1: ADIPOQ ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ADIPOQ and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ADIPOQ_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AGXT_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: AGXT
#
# 📊 Scenario 1: AGXT ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both AGXT and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing AGXT_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AHCY_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: AHCY
#
# 📊 Scenario 1: AHCY ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both AHCY and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing AHCY_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AIPL1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: AIPL1
#
# 📊 Scenario 1: AIPL1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both AIPL1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing AIPL1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ALAS2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ALAS2
#
# 📊 Scenario 1: ALAS2 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ALAS2 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ALAS2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ALDOA_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ALDOA
#
# 📊 Scenario 1: ALDOA ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ALDOA and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ALDOA_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ALOX5_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ALOX5
#
# 📊 Scenario 1: ALOX5 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ALOX5 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ALOX5_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AMPD2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: AMPD2
# ⚠️ WARNING: AMPD2 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing AMPD2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ANKRD1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ANKRD1
#
# 📊 Scenario 1: ANKRD1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ANKRD1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ANKRD1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ANXA11_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ANXA11
#
# 📊 Scenario 1: ANXA11 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#        Tissue                                  Cell Type
# 0        lung  activated CD8-positive, alpha-beta T cell
# 1        lung                  natural T-regulatory cell
# 2  lymph node  activated CD8-positive, alpha-beta T cell
#
# 📊 Scenario 2: Both ANXA11 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/ANXA11_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/AP2S1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: AP2S1
#
# 📊 Scenario 1: AP2S1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both AP2S1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing AP2S1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/APOA1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: APOA1
#
# 📊 Scenario 1: APOA1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both APOA1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing APOA1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/APOD_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: APOD
#
# 📊 Scenario 1: APOD ≥30%, Interactor ≥30% (Moderate Co-Expression)
#             Tissue                                          Cell Type
# 0    bladder organ                             connective tissue cell
# 1    bladder organ                                         fibroblast
# 2            brain                     oligodendrocyte precursor cell
# 3            brain                                    progenitor cell
# 4           breast                         capillary endothelial cell
# 5           breast                             connective tissue cell
# 6           breast                                         fibroblast
# 7           breast                        fibroblast of mammary gland
# 8   exocrine gland                                     malignant cell
# 10  fallopian tube                                 myofibroblast cell
# 11  fallopian tube                         stratified epithelial cell
# 12     gallbladder                             connective tissue cell
# 13     gallbladder                                         fibroblast
# 14        hindlimb                                       Schwann cell
# 16        hindlimb                                        neural cell
# 18  prostate gland                             connective tissue cell
# 19  prostate gland  fibroblast of connective tissue of glandular p...
# 20     spinal cord                     oligodendrocyte precursor cell
# 21     spinal cord                                     precursor cell
# 22     spinal cord                                    progenitor cell
#
# 📊 Scenario 2: Both APOD and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/APOD_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ASNS_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ASNS
# ⚠️ WARNING: ASNS does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing ASNS_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ATPAF2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ATPAF2
# ⚠️ WARNING: ATPAF2 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing ATPAF2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BAG3_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: BAG3
#
# 📊 Scenario 1: BAG3 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#             Tissue                                          Cell Type
# 0      gallbladder                             connective tissue cell
# 2      gallbladder                                         fibroblast
# 4            heart              CD14-positive, CD16-positive monocyte
# 5   prostate gland  fibroblast of connective tissue of nonglandula...
# 6  small intestine                         CD4-positive helper T cell
#
# 📊 Scenario 2: Both BAG3 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/BAG3_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BANF1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: BANF1
#
# 📊 Scenario 1: BANF1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both BANF1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing BANF1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BCL10_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: BCL10
# ⚠️ WARNING: BCL10 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing BCL10_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BFSP2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: BFSP2
#
# 📊 Scenario 1: BFSP2 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#   Tissue             Cell Type
# 0    eye       lens fiber cell
# 1    eye  secondary lens fiber
#
# 📊 Scenario 2: Both BFSP2 and at least one interactor ≥50% (Highly Co-Expressed)
#   Tissue        Cell Type
# 0    eye  lens fiber cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/BFSP2_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/BLK_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: BLK
#
# 📊 Scenario 1: BLK ≥30%, Interactor ≥30% (Moderate Co-Expression)
#             Tissue                Cell Type
# 0   adipose tissue                   B cell
# 1   adipose tissue  lymphocyte of B lineage
# 2            blood             naive B cell
# 3   exocrine gland                   B cell
# 4              eye                   B cell
# 5        intestine                   B cell
# 6       lymph node               fibroblast
# 8       lymph node        muscle fibroblast
# 10         stomach           malignant cell
#
# 📊 Scenario 2: Both BLK and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/BLK_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/C1QA_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: C1QA
#
# 📊 Scenario 1: C1QA ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both C1QA and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing C1QA_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/C1QB_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: C1QB
#
# 📊 Scenario 1: C1QB ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both C1QB and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing C1QB_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/C1QC_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: C1QC
#
# 📊 Scenario 1: C1QC ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both C1QC and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing C1QC_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CA8_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CA8
#
# 📊 Scenario 1: CA8 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CA8 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CA8_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CACNB4_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CACNB4
#
# 📊 Scenario 1: CACNB4 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#    Tissue                                        Cell Type
# 0     eye                          GABAergic amacrine cell
# 1     eye                                    amacrine cell
# 2     eye                          starburst amacrine cell
# 3  kidney         kidney connecting tubule epithelial cell
# 4  kidney  kidney distal convoluted tubule epithelial cell
#
# 📊 Scenario 2: Both CACNB4 and at least one interactor ≥50% (Highly Co-Expressed)
#   Tissue                Cell Type
# 0    eye  starburst amacrine cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CACNB4_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CCBE1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CCBE1
#
# 📊 Scenario 1: CCBE1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CCBE1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CCBE1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CCDC103_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CCDC103
# ⚠️ WARNING: CCDC103 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CCDC103_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CD151_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CD151
#
# 📊 Scenario 1: CD151 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CD151 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CD151_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDA_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CDA
#
# 📊 Scenario 1: CDA ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CDA and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CDA_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDC73_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CDC73
#
# 📊 Scenario 1: CDC73 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CDC73 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CDC73_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDK4_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CDK4
#
# 📊 Scenario 1: CDK4 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#          Tissue                                  Cell Type
# 0         blood  activated CD4-positive, alpha-beta T cell
# 2         blood  activated CD8-positive, alpha-beta T cell
# 4         blood                           type I NK T cell
# 6   bone marrow              megakaryocyte progenitor cell
# 7      hindlimb                                   myoblast
# 8     intestine                     connective tissue cell
# 9     intestine                           contractile cell
# 10    intestine                 interstitial cell of Cajal
# 11    intestine                            mesodermal cell
# 12    intestine                           mesothelial cell
# 13    intestine                                   pericyte
# 14    intestine                         smooth muscle cell
# 15    intestine                               stromal cell
# 16        liver        extracellular matrix secreting cell
# 17        liver                      hepatic stellate cell
# 18        liver                               stromal cell
#
# 📊 Scenario 2: Both CDK4 and at least one interactor ≥50% (Highly Co-Expressed)
#   Tissue                                  Cell Type
# 0  blood  activated CD4-positive, alpha-beta T cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CDK4_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDKN1A_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CDKN1A
#
# 📊 Scenario 1: CDKN1A ≥30%, Interactor ≥30% (Moderate Co-Expression)
#            Tissue                             Cell Type
# 0   adrenal gland       CD4-positive, alpha-beta T cell
# 2   bladder organ               bladder urothelial cell
# 3   bladder organ                       epithelial cell
# 4   bladder organ                            macrophage
# 5   bladder organ                              monocyte
# ..            ...                                   ...
# 61        stomach                            macrophage
# 62        stomach                              monocyte
# 63        stomach                 mononuclear phagocyte
# 64        stomach                       progenitor cell
# 65         uterus  professional antigen presenting cell
#
# [64 rows x 2 columns]
#
# 📊 Scenario 2: Both CDKN1A and at least one interactor ≥50% (Highly Co-Expressed)
#            Tissue                              Cell Type
# 0           blood                          megakaryocyte
# 1          kidney  CD14-positive, CD16-positive monocyte
# 2            lung          myeloid dendritic cell, human
# 3  prostate gland   CD1c-positive myeloid dendritic cell
# 4  prostate gland                         dendritic cell
# 5  prostate gland                 myeloid dendritic cell
# 6         stomach                               monocyte
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CDKN1A_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CDKN2C_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CDKN2C
# ⚠️ WARNING: CDKN2C does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CDKN2C_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CFP_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CFP
#
# 📊 Scenario 1: CFP ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CFP and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CFP_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CHN1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CHN1
#
# 📊 Scenario 1: CHN1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#   Tissue                                          Cell Type
# 0  brain  L5/6 near-projecting glutamatergic neuron of t...
#
# 📊 Scenario 2: Both CHN1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CHN1_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CHRNG_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CHRNG
# ⚠️ WARNING: CHRNG does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CHRNG_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CLCNKA_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CLCNKA
# ⚠️ WARNING: CLCNKA does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CLCNKA_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CLDN19_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CLDN19
# ⚠️ WARNING: CLDN19 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CLDN19_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CLN6_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CLN6
# ⚠️ WARNING: CLN6 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CLN6_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COL10A1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: COL10A1
# ⚠️ WARNING: COL10A1 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing COL10A1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COL2A1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: COL2A1
#
# 📊 Scenario 1: COL2A1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both COL2A1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing COL2A1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COMP_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: COMP
# ⚠️ WARNING: COMP does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing COMP_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/COQ8A_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: COQ8A
# ⚠️ WARNING: COQ8A does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing COQ8A_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRADD_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CRADD
#
# 📊 Scenario 1: CRADD ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CRADD and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CRADD_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CREB1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CREB1
#
# 📊 Scenario 1: CREB1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CREB1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CREB1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRYAA_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CRYAA
# ⚠️ WARNING: CRYAA does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CRYAA_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRYAB_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CRYAB
#
# 📊 Scenario 1: CRYAB ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CRYAB and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CRYAB_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CRYBB1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CRYBB1
#
# 📊 Scenario 1: CRYBB1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CRYBB1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CRYBB1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CSNK1D_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CSNK1D
#
# 📊 Scenario 1: CSNK1D ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CSNK1D and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CSNK1D_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CSNK1E_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CSNK1E
#
# 📊 Scenario 1: CSNK1E ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CSNK1E and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CSNK1E_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CTH_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CTH
# ⚠️ WARNING: CTH does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CTH_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CTNNA3_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CTNNA3
#
# 📊 Scenario 1: CTNNA3 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#             Tissue                                   Cell Type
# 0   adipose tissue                hematopoietic precursor cell
# 1   adipose tissue  myeloid lineage restricted progenitor cell
# 2            brain              oligodendrocyte precursor cell
# 3              eye                   ON-blue cone bipolar cell
# 4            heart                                Schwann cell
# 5            heart       cardiac blood vessel endothelial cell
# 6            heart                     cardiac muscle myoblast
# 8            heart               immature innate lymphoid cell
# 9            heart                        innate lymphoid cell
# 10           heart                                    myoblast
# 12           heart                      neuronal receptor cell
# 13           heart                              precursor cell
# 15           heart         regular ventricular cardiac myocyte
# 17           heart             ventricular cardiac muscle cell
#
# 📊 Scenario 2: Both CTNNA3 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CTNNA3_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CUL3_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CUL3
#
# 📊 Scenario 1: CUL3 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#   Tissue    Cell Type
# 0  blood  granulocyte
# 1  blood   neutrophil
#
# 📊 Scenario 2: Both CUL3 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CUL3_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CXCL16_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CXCL16
#
# 📊 Scenario 1: CXCL16 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both CXCL16 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing CXCL16_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/CYP4F12_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: CYP4F12
# ⚠️ WARNING: CYP4F12 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing CYP4F12_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DCX_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: DCX
#
# 📊 Scenario 1: DCX ≥30%, Interactor ≥30% (Moderate Co-Expression)
#    Tissue               Cell Type
# 0   brain           Purkinje cell
# 1   brain       cerebellar neuron
# 2   brain         efferent neuron
# 3  embryo  inhibitory interneuron
#
# 📊 Scenario 2: Both DCX and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/DCX_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DDX20_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: DDX20
# ⚠️ WARNING: DDX20 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing DDX20_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DIABLO_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: DIABLO
# ⚠️ WARNING: DIABLO does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing DIABLO_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DMC1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: DMC1
# ⚠️ WARNING: DMC1 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing DMC1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DOLK_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: DOLK
# ⚠️ WARNING: DOLK does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing DOLK_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/DUSP23_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: DUSP23
#
# 📊 Scenario 1: DUSP23 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both DUSP23 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing DUSP23_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EFEMP1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EFEMP1
#
# 📊 Scenario 1: EFEMP1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both EFEMP1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing EFEMP1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EFHC1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EFHC1
#
# 📊 Scenario 1: EFHC1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#             Tissue                                        Cell Type
# 0            brain                                    ciliated cell
# 2            brain                         ciliated epithelial cell
# 4            brain                columnar/cuboidal epithelial cell
# 6            brain                                   ependymal cell
# 8   fallopian tube                         ciliated epithelial cell
# 10            lung                                    ciliated cell
# 12            lung  ciliated columnar cell of tracheobronchial tree
# 14            lung                         ciliated epithelial cell
# 16            lung       epithelial cell of lower respiratory tract
# 18            lung                               lung ciliated cell
# 20            lung                   multi-ciliated epithelial cell
# 22            lung                        respiratory ciliated cell
# 24          uterus                                    ciliated cell
#
# 📊 Scenario 2: Both EFHC1 and at least one interactor ≥50% (Highly Co-Expressed)
#            Tissue                                        Cell Type
# 0  fallopian tube                         ciliated epithelial cell
# 2            lung                                    ciliated cell
# 3            lung  ciliated columnar cell of tracheobronchial tree
# 5            lung                         ciliated epithelial cell
# 6            lung                               lung ciliated cell
# 7            lung                   multi-ciliated epithelial cell
# 9            lung                        respiratory ciliated cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/EFHC1_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EIF2B1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EIF2B1
# ⚠️ WARNING: EIF2B1 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing EIF2B1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EIF2B4_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EIF2B4
# ⚠️ WARNING: EIF2B4 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing EIF2B4_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EMD_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EMD
#
# 📊 Scenario 1: EMD ≥30%, Interactor ≥30% (Moderate Co-Expression)
#            Tissue                                          Cell Type
# 0   adrenal gland                    CD4-positive, alpha-beta T cell
# 2   adrenal gland                    CD8-positive, alpha-beta T cell
# 5   adrenal gland                                             T cell
# 7   adrenal gland    effector memory CD8-positive, alpha-beta T cell
# 10  adrenal gland                                          leukocyte
# 11  adrenal gland                                         lymphocyte
# 13  adrenal gland                                      mature T cell
# 16  adrenal gland                           mature alpha-beta T cell
# 19  adrenal gland                                      memory T cell
# 22  adrenal gland                                   mononuclear cell
# 23         kidney                    CD8-positive, alpha-beta T cell
# 24         kidney   activated CD4-positive, alpha-beta T cell, human
# 26         kidney                                       naive T cell
# 28         kidney  naive thymus-derived CD8-positive, alpha-beta ...
#
# 📊 Scenario 2: Both EMD and at least one interactor ≥50% (Highly Co-Expressed)
#           Tissue                                        Cell Type
# 0  adrenal gland  effector memory CD8-positive, alpha-beta T cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/EMD_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ESR2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ESR2
#
# 📊 Scenario 1: ESR2 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ESR2 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ESR2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EXOC8_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EXOC8
# ⚠️ WARNING: EXOC8 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing EXOC8_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/EZH2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: EZH2
#
# 📊 Scenario 1: EZH2 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both EZH2 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing EZH2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FA2H_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FA2H
#
# 📊 Scenario 1: FA2H ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both FA2H and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing FA2H_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FADD_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FADD
# ⚠️ WARNING: FADD does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing FADD_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FAM161A_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FAM161A
#
# 📊 Scenario 1: FAM161A ≥30%, Interactor ≥30% (Moderate Co-Expression)
#   Tissue                        Cell Type
# 0    eye           eye photoreceptor cell
# 2    eye               photoreceptor cell
# 4    eye  retinal pigment epithelial cell
# 8    eye                 retinal rod cell
#
# 📊 Scenario 2: Both FAM161A and at least one interactor ≥50% (Highly Co-Expressed)
#   Tissue         Cell Type
# 0    eye  retinal rod cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/FAM161A_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FAM187A_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FAM187A
# ⚠️ WARNING: FAM187A does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing FAM187A_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FASLG_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FASLG
#
# 📊 Scenario 1: FASLG ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both FASLG and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing FASLG_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FBP1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FBP1
#
# 📊 Scenario 1: FBP1 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both FBP1 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing FBP1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FGD4_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FGD4
#
# 📊 Scenario 1: FGD4 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both FGD4 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing FGD4_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FKBP6_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: FKBP6
# ⚠️ WARNING: FKBP6 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing FKBP6_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/FOXD4_PPI_filtered_S0_17042025.csv...
# ...
#
# 📊 Scenario 2: Both TPM1 and at least one interactor ≥50% (Highly Co-Expressed)
#         Tissue                      Cell Type
# 0  bone marrow  megakaryocyte progenitor cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TPM1_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TPM2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TPM2
#
# 📊 Scenario 1: TPM2 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both TPM2 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing TPM2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TPM3_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TPM3
#
# 📊 Scenario 1: TPM3 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#          Tissue                                          Cell Type
# 0         blood          activated CD4-positive, alpha-beta T cell
# 1         blood          activated CD8-positive, alpha-beta T cell
# 2         blood                                   type I NK T cell
# 3   bone marrow  CD4-positive, CD25-positive, alpha-beta regula...
# 4   bone marrow                      basophil mast progenitor cell
# 5   bone marrow                            basophilic erythroblast
# 6   bone marrow                                   bone marrow cell
# 7   bone marrow     central memory CD4-positive, alpha-beta T cell
# 8   bone marrow                         common lymphoid progenitor
# 9   bone marrow                          common myeloid progenitor
# 10  bone marrow                          erythroid progenitor cell
# 11  bone marrow               granulocyte monocyte progenitor cell
# 12  bone marrow          hematopoietic oligopotent progenitor cell
# 13  bone marrow                       hematopoietic precursor cell
# 14  bone marrow                            hematopoietic stem cell
# 15  bone marrow                                large pre-B-II cell
# 16  bone marrow                                    late pro-B cell
# 17  bone marrow                      megakaryocyte progenitor cell
# 18  bone marrow            megakaryocyte-erythroid progenitor cell
# 19  bone marrow  naive thymus-derived CD8-positive, alpha-beta ...
# 20  bone marrow                    pre-conventional dendritic cell
# 21  bone marrow                                  regulatory T cell
# 22  bone marrow                                          stem cell
# 23        brain                                  hypothalamus cell
# 24    intestine                                       Schwann cell
# 25    intestine                                         glial cell
# 26       kidney           effector CD4-positive, alpha-beta T cell
# 27       kidney                                  regulatory T cell
# 28     pancreas                            pancreatic epsilon cell
#
# 📊 Scenario 2: Both TPM3 and at least one interactor ≥50% (Highly Co-Expressed)
#         Tissue                      Cell Type
# 0  bone marrow  megakaryocyte progenitor cell
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TPM3_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TREX1_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TREX1
# ⚠️ WARNING: TREX1 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing TREX1_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TRIB3_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TRIB3
# ⚠️ WARNING: TRIB3 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing TRIB3_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TRIM32_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TRIM32
# ⚠️ WARNING: TRIM32 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing TRIM32_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TSFM_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TSFM
# ⚠️ WARNING: TSFM does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing TSFM_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TTPA_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TTPA
#
# 📊 Scenario 1: TTPA ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both TTPA and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing TTPA_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TTR_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TTR
#
# 📊 Scenario 1: TTR ≥30%, Interactor ≥30% (Moderate Co-Expression)
#   Tissue                        Cell Type
# 0  liver  centrilobular region hepatocyte
# 1  liver                  epithelial cell
# 2  liver                       hepatocyte
# 3  liver       midzonal region hepatocyte
# 4  liver     periportal region hepatocyte
#
# 📊 Scenario 2: Both TTR and at least one interactor ≥50% (Highly Co-Expressed)
#   Tissue                     Cell Type
# 0  liver    midzonal region hepatocyte
# 1  liver  periportal region hepatocyte
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TTR_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/TUFM_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: TUFM
#
# 📊 Scenario 1: TUFM ≥30%, Interactor ≥30% (Moderate Co-Expression)
#              Tissue                                          Cell Type
# 0       bone marrow  CD4-positive, CD25-positive, alpha-beta regula...
# 1       bone marrow                            basophilic erythroblast
# 2       bone marrow                          common myeloid progenitor
# 3       bone marrow                                       erythroblast
# 4       bone marrow                          erythroid progenitor cell
# 5       bone marrow                            hematopoietic stem cell
# 6       bone marrow                                large pre-B-II cell
# 7       bone marrow                                         osteoclast
# 8       bone marrow                        plasmacytoid dendritic cell
# 9       bone marrow                 plasmacytoid dendritic cell, human
# 10      bone marrow                    pre-conventional dendritic cell
# 11      bone marrow                                          stem cell
# 12            brain                                       Mueller cell
# 13            brain                   cerebral cortex pyramidal neuron
# 14            brain  extratelencephalic-projecting glutamatergic co...
# 15            brain                             eye photoreceptor cell
# 16            brain                        forebrain radial glial cell
# 17            brain                                  hypothalamus cell
# 18            brain                            retinal progenitor cell
# 19         forelimb                                           myoblast
# 20         forelimb                           skeletal muscle myoblast
# 21      gallbladder                                    epithelial cell
# 22        intestine                                       Schwann cell
# 23        intestine                                         brush cell
# 24        intestine                                         glial cell
# 25        intestine                               intestinal tuft cell
# 26        intestine                                        neural cell
# 27        intestine                                     precursor cell
# 28        intestine                                          stem cell
# 29           kidney    effector memory CD8-positive, alpha-beta T cell
# 30           kidney                                      memory T cell
# 31           kidney                                   mesenchymal cell
# 32           kidney         mesonephric nephron tubule epithelial cell
# 33            liver                                      megakaryocyte
# 34             lung                                large pre-B-II cell
# 35             lung        lymphoid lineage restricted progenitor cell
# 36             lung                                         pro-B cell
# 37       lymph node                                    epithelial cell
# 38  small intestine                                       motor neuron
# 39  small intestine                                     precursor cell
# 40  small intestine                                          stem cell
#
# 📊 Scenario 2: Both TUFM and at least one interactor ≥50% (Highly Co-Expressed)
#         Tissue                Cell Type
# 0  bone marrow  basophilic erythroblast
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TUFM_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/UBE3A_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: UBE3A
#
# 📊 Scenario 1: UBE3A ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both UBE3A and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing UBE3A_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/UBQLN2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: UBQLN2
# ⚠️ WARNING: UBQLN2 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing UBQLN2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/UROD_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: UROD
#
# 📊 Scenario 1: UROD ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both UROD and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing UROD_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/VAPB_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: VAPB
# ⚠️ WARNING: VAPB does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing VAPB_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/VHL_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: VHL
#
# 📊 Scenario 1: VHL ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both VHL and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing VHL_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/VPS33B_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: VPS33B
# ⚠️ WARNING: VPS33B does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing VPS33B_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/WRAP53_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: WRAP53
# ⚠️ WARNING: WRAP53 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing WRAP53_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/XRCC2_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: XRCC2
# ⚠️ WARNING: XRCC2 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing XRCC2_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/XRCC4_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: XRCC4
# ⚠️ WARNING: XRCC4 does not meet ≥30% expression in any valid cluster. Skipping file.
# ⚠️ WARNING: No valid data after processing XRCC4_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZCCHC12_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ZCCHC12
#
# 📊 Scenario 1: ZCCHC12 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ZCCHC12 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ZCCHC12_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZMYND10_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ZMYND10
#
# 📊 Scenario 1: ZMYND10 ≥30%, Interactor ≥30% (Moderate Co-Expression)
#            Tissue                                        Cell Type
# 0  fallopian tube                         ciliated epithelial cell
# 1            lung                                    ciliated cell
# 2            lung  ciliated columnar cell of tracheobronchial tree
# 3            lung                         ciliated epithelial cell
# 4            lung                   multi-ciliated epithelial cell
# 5            lung                        respiratory ciliated cell
#
# 📊 Scenario 2: Both ZMYND10 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ✅ Saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/ZMYND10_PPI_filtered_S1_H1_17042025.xlsx
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZNF24_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ZNF24
#
# 📊 Scenario 1: ZNF24 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ZNF24 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ZNF24_PPI_filtered_S0_17042025.csv. Skipping...
#
# 📂 Processing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/Level2/filtered_S0/ZNF624_PPI_filtered_S0_17042025.csv...
# 🧬 Identified Protein of Interest: ZNF624
#
# 📊 Scenario 1: ZNF624 ≥30%, Interactor ≥30% (Moderate Co-Expression)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
#
# 📊 Scenario 2: Both ZNF624 and at least one interactor ≥50% (Highly Co-Expressed)
# Empty DataFrame
# Columns: [Tissue, Cell Type]
# Index: []
# ⚠️ WARNING: No valid data after processing ZNF624_PPI_filtered_S0_17042025.csv. Skipping...

# %%
#Same as per: PPI_CellxGene_coexpression_S1_H1_13032025.ipynb 

#LITAF: need to re-process this by removing UBA52 (dominantly expressed ubiquitin gene in all clusters)
#If a cell type/state pops because of just LITAF & UBA52, maybe it should be skipped. 
#Save output as _V2_noUBA52.xlsx for better clarity. 

def process_LITAF_without_UBA52():
    """ Reprocesses LITAF while removing UBA52 and saves as '_V2_noUBA52.xlsx'. """

    file = "LITAF_PPI_filtered_S1_H1_17042025.xlsx"  #Step 1 H1 output file
    input_path = os.path.join(output_dir, file)  

    if not os.path.exists(input_path):
        print(f"❌ ERROR: {input_path} not found!")
        return
    
    print(f"\n🔄 Reprocessing: {input_path} (Removing UBA52)...")

    #Read Excel file
    df = pd.read_excel(input_path)

    #**Step 1: Remove UBA52 from data**
    df = df[df["Gene Symbol"] != "UBA52"]

    #**Step 2: Identify & remove cell types where only LITAF & UBA52 were present**
    cell_type_counts = df.groupby(["Tissue", "Cell Type"])["Gene Symbol"].nunique().reset_index()
    only_litaf_clusters = cell_type_counts[cell_type_counts["Gene Symbol"] == 1]  # Clusters with only one gene (LITAF)
    
    #**Filter out these clusters**
    df = df[~df.set_index(["Tissue", "Cell Type"]).index.isin(only_litaf_clusters.set_index(["Tissue", "Cell Type"]).index)]

    #**Step 3: Save output as new version**
    output_file = os.path.join(output_dir, file.replace("_S1_H1", "_V2_noUBA52"))
    df.to_excel(output_file, index=False)

    print(f"✅ Successfully saved: {output_file}")

#Run the function
process_LITAF_without_UBA52()
# Out:
# 🔄 Reprocessing: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/LITAF_PPI_filtered_S1_H1_17042025.xlsx (Removing UBA52)...
# ✅ Successfully saved: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/LITAF_PPI_filtered_V2_noUBA52_17042025.xlsx

# %% [markdown]
# Fix required:
#
# - POI Expression (POI_Expression) is extracted correctly.
# - Prioritized PPI pairs are generated without self-interactions.
# - Files are processed dynamically, excluding LITAF when needed.
#
# 1. Priority score fix:
# Instead of normalizing each feature independently, we first compute the raw Priority Score, then apply MinMax Scaling across final scores to ensure they're >0.
# This prevents one feature from dominating and keeps all scores comparable.
#
# 2. Adjust Weights: Higher contribution for mean robustness => Since co-expression strength is crucial, we increase the weight of Mean Robustness.
#
# 3. Recalculate Mean Robustness Using %Cells Expressing POI & %Cells Expressing Interactors
#
# 4. Apply final MinMax scaling on raw Priority Scores (Ensuring No 0s) => if we don't have many PPIs to visualize, it's better to ignore this field.
#     - If MinMax Scaling produces zeros, shift values slightly above 0 to maintain rankings.
#     - Look into columns like Contributing_Interactors & Prioritized_PPI to check #interactors contributing to co-expression. Higher #partners presumably indicate tighter regulatory role.

# %%
from sklearn.preprocessing import MinMaxScaler

#**Define input directory**
input_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/"

#**Find all POI files dynamically**
input_files = [f for f in os.listdir(input_dir) if f.endswith("_S1_H1_17042025.xlsx")]

#**Check if LITAF file exists in input directory**
litaf_filename = "LITAF_PPI_filtered_V2_noUBA52_17042025.xlsx"

if litaf_filename in input_files:
    print(f"✅ LITAF file detected & will be processed.")
else:
    print(f"⚠️ WARNING: LITAF file not found in input directory!")

#**Check if any valid POI files exist**
if not input_files:
    print("❌ ERROR: No valid POI files found in the directory!")
    exit()

print(f"📂 Found {len(input_files)} files for processing.")

#**Processing all POI files independently**
for file in input_files:
    input_path = os.path.join(input_dir, file)

    #**Extract POI dynamically from filename**
    protein_of_interest = file.split("_")[0]

    print(f"\n📂 Processing Priority Ranking for: {input_path}")
    print(f"🧬 Identified Protein of Interest: {protein_of_interest}")

    #**Read the dataset**
    df = pd.read_excel(input_path)

    #**Ensure necessary columns exist**
    required_columns = {"Tissue", "Cell Type", "Gene Symbol", "%Cells Expressing Gene", "Expression", "Cell Count"}
    if not required_columns.issubset(df.columns):
        print(f"❌ ERROR: Missing required columns in {file}. Skipping...")
        continue

    #**Step 1: Identify Robust Interactions (≥30% Expression)**
    interaction_threshold = 30
    df["Robust Interaction"] = df["%Cells Expressing Gene"] >= interaction_threshold

    #**Step 2: Extract POI Expression & %Cells Expressing POI BEFORE groupby**
    poi_df = df[df["Gene Symbol"] == protein_of_interest][["Tissue", "Cell Type", "Expression", "%Cells Expressing Gene"]]
    poi_df.rename(columns={"Expression": "POI_Expression", "%Cells Expressing Gene": "%Cells_Expressing_POI"}, inplace=True)

    #**Step 3: Compute Cluster-Level Metrics**
    cluster_priority = df.groupby(["Tissue", "Cell Type"]).agg(
        Num_Robust_Interactions=("Gene Symbol", lambda x: df.loc[x.index, "Robust Interaction"].sum()),
        Contributing_Interactors=("Gene Symbol", lambda x: ", ".join(sorted(x[df.loc[x.index, "Robust Interaction"]]))),
        Mean_scRNA_score=("scRNA_score", "mean"),
        Total_Cell_Count=("Cell Count", "max")
    ).reset_index()

    #**Step 4: Extract %Cells Expressing Interactors**
    interactors_df = df[df["Robust Interaction"]][["Tissue", "Cell Type", "%Cells Expressing Gene"]]
    interactors_avg = interactors_df.groupby(["Tissue", "Cell Type"])["%Cells Expressing Gene"].mean().reset_index()
    interactors_avg.rename(columns={"%Cells Expressing Gene": "%Cells_Expressing_Interactors"}, inplace=True)

    #**Step 5: Merge POI Expression & %Cells Expressing POI Values**
    cluster_priority = cluster_priority.merge(poi_df, on=["Tissue", "Cell Type"], how="left")
    cluster_priority = cluster_priority.merge(interactors_avg, on=["Tissue", "Cell Type"], how="left")

    #**Step 6: Compute Mean Robustness**
    cluster_priority["Mean_Robustness"] = (cluster_priority["%Cells_Expressing_POI"] + cluster_priority["%Cells_Expressing_Interactors"]) / 2

    #**Step 7: Ensure valid data remains after processing**
    if cluster_priority.empty:
        print(f"⚠️ No valid data remaining for {file}. Skipping...")
        continue

    #**Step 8: Compute Priority Score**
    W_interactions = 0.3
    W_scRNA = 0.25
    W_robustness = 0.45

    cluster_priority["Priority Score"] = (
        W_interactions * cluster_priority["Num_Robust_Interactions"] +
        W_scRNA * cluster_priority["Mean_scRNA_score"] +
        W_robustness * cluster_priority["Mean_Robustness"]
    )

    #**Step 9: Apply MinMax Scaling to Priority Score**
    scaler = MinMaxScaler(feature_range=(0.05, 1))
    cluster_priority["Priority Score"] = scaler.fit_transform(cluster_priority[["Priority Score"]])

    #**Step 10: Generate Prioritized PPI pairs**
    def generate_ppi_pairs(row, poi):
        """Generates PPI pairs while ensuring no self-interactions."""
        interactors = row["Contributing_Interactors"].split(", ")
        interactors = [partner for partner in interactors if partner != poi]
        return ", ".join([f"{poi}-{partner}" for partner in interactors])

    cluster_priority["Prioritized_PPI"] = cluster_priority.apply(lambda row: generate_ppi_pairs(row, protein_of_interest), axis=1)

    #**Step 11: Keep output format consistent**
    cluster_priority = cluster_priority[[
        "Tissue", "Cell Type", "Total_Cell_Count",
        "POI_Expression", "%Cells_Expressing_POI", "%Cells_Expressing_Interactors",
        "Num_Robust_Interactions", "Contributing_Interactors", "Prioritized_PPI",
        "Mean_scRNA_score", "Mean_Robustness", "Priority Score"
    ]]

    #**Step 12: Sort by Num_Robust_Interactions (primary) and Priority Score (secondary)**
    cluster_priority = cluster_priority.sort_values(by=["Num_Robust_Interactions", "Priority Score"], ascending=[False, False]).reset_index(drop=True)

    #**Step 13: Save output file with correct naming**
    output_file = os.path.join(input_dir, file.replace("_S1_H1", "_Ranked_Priority_Final"))
    cluster_priority.to_excel(output_file, index=False)

    print(f"✅ Successfully saved prioritized clusters: {output_file}")

    #**Step 14: Display Top Ranked Clusters**
    print("\n🏆 Top 10 Ranked Clusters:\n", cluster_priority.head(10))
# Out:
# ⚠️ WARNING: LITAF file not found in input directory!
# 📂 Found 51 files for processing.
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TPM3_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: TPM3
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TPM3_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#          Tissue                                  Cell Type  Total_Cell_Count  \
# 0  bone marrow              megakaryocyte progenitor cell              2656
# 1  bone marrow            pre-conventional dendritic cell              3704
# 2        blood  activated CD4-positive, alpha-beta T cell             14124
# 3       kidney   effector CD4-positive, alpha-beta T cell              2205
# 4        blood  activated CD8-positive, alpha-beta T cell              6248
# 5  bone marrow                  common myeloid progenitor             12587
# 6        blood                           type I NK T cell              4988
# 7  bone marrow  hematopoietic oligopotent progenitor cell             52222
# 8  bone marrow       granulocyte monocyte progenitor cell             23265
# 9       kidney                          regulatory T cell              8396
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.088763              84.977410                      67.582831
# 1        2.314410              91.684665                      61.298596
# 2        2.142077              80.876522                      59.214812
# 3        2.422316              81.587302                      58.344671
# 4        2.156453              80.505762                      58.930858
# 5        2.040137              77.595932                      58.560419
# 6        2.290747              78.969527                      56.405373
# 7        2.038578              71.699667                      54.926085
# 8        2.045464              70.810230                      54.627122
# 9        2.224527              72.868032                      52.751310
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2              PSMC5, TPM3      TPM3-PSMC5
# 1                        2              PSMC5, TPM3      TPM3-PSMC5
# 2                        2              PSMC5, TPM3      TPM3-PSMC5
# 3                        2              PSMC5, TPM3      TPM3-PSMC5
# 4                        2              PSMC5, TPM3      TPM3-PSMC5
# 5                        2              PSMC5, TPM3      TPM3-PSMC5
# 6                        2              PSMC5, TPM3      TPM3-PSMC5
# 7                        2              PSMC5, TPM3      TPM3-PSMC5
# 8                        2              PSMC5, TPM3      TPM3-PSMC5
# 9                        2              PSMC5, TPM3      TPM3-PSMC5
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         27.386854        76.280120        1.000000
# 1         24.904748        76.491631        0.979306
# 2         23.991419        70.045667        0.856050
# 3         23.715843        69.965986        0.851924
# 4         23.885277        69.718310        0.849202
# 5         23.760098        68.078176        0.818897
# 6         22.905025        67.687450        0.803550
# 7         22.311741        63.312876        0.720164
# 8         22.195171        62.718676        0.708483
# 9         21.440897        62.809671        0.702668
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PRKAR1A_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: PRKAR1A
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PRKAR1A_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#          Tissue         Cell Type  Total_Cell_Count  POI_Expression  \
# 0        blood     megakaryocyte             13528        2.066778
# 1  spinal cord  GABAergic neuron              1777        2.092861
# 2  spinal cord    secretory cell              2587        2.082986
#
#    %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0              30.004435                      42.758230
# 1              44.344401                      49.915588
# 2              39.311944                      44.027831
#
#    Num_Robust_Interactions   Contributing_Interactors  \
# 0                        3  C2orf88, PRKAR1A, PRKAR1B
# 1                        2           PRKAR1A, PRKAR1B
# 2                        2           PRKAR1A, PRKAR1B
#
#                     Prioritized_PPI  Mean_scRNA_score  Mean_Robustness  \
# 0  PRKAR1A-C2orf88, PRKAR1A-PRKAR1B         17.506678        36.381333
# 1                   PRKAR1A-PRKAR1B         20.353663        47.129994
# 2                   PRKAR1A-PRKAR1B         17.991646        41.669888
#
#    Priority Score
# 0        0.050000
# 1        1.000000
# 2        0.448396
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PKP2_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: PKP2
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PKP2_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue                              Cell Type  Total_Cell_Count  \
# 0  heart                cardiac muscle myoblast             66162
# 1  heart                               myoblast             69045
# 2  heart    regular ventricular cardiac myocyte            195378
# 3  heart                    cardiac muscle cell            654429
# 4  heart                         precursor cell             82166
# 5  heart                            muscle cell            701306
# 6    eye  non-pigmented ciliary epithelial cell              5330
# 7  heart                       contractile cell            824559
# 8  heart         regular atrial cardiac myocyte             53855
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.137366              83.437623                      70.486080
# 1        2.135870              80.599609                      68.048374
# 2        2.328445              76.857169                      67.562622
# 3        2.213651              66.872342                      61.387255
# 4        2.135588              69.032203                      58.159701
# 5        2.212800              62.670218                      57.560109
# 6        2.228053              64.821764                      51.538462
# 7        2.209991              54.345899                      49.823057
# 8        2.120354              46.894439                      46.121066
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2              MTUS2, PKP2      PKP2-MTUS2
# 1                        2              MTUS2, PKP2      PKP2-MTUS2
# 2                        2              MTUS2, PKP2      PKP2-MTUS2
# 3                        2              MTUS2, PKP2      PKP2-MTUS2
# 4                        2              MTUS2, PKP2      PKP2-MTUS2
# 5                        2              MTUS2, PKP2      PKP2-MTUS2
# 6                        2              MTUS2, PKP2      PKP2-MTUS2
# 7                        2              MTUS2, PKP2      PKP2-MTUS2
# 8                        2              MTUS2, PKP2      PKP2-MTUS2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         28.402627        76.961851        1.000000
# 1         27.427367        74.323992        0.915743
# 2         27.282961        72.209896        0.857596
# 3         24.803819        64.129799        0.606988
# 4         23.472187        63.595952        0.573238
# 5         23.272799        60.115164        0.478066
# 6         20.814264        58.180113        0.390596
# 7         20.177353        52.084478        0.219694
# 8         18.688521        46.507752        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/SFTPC_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: SFTPC
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/SFTPC_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue                             Cell Type  Total_Cell_Count  \
# 0   lung                    type II pneumocyte            361020
# 1   lung                   lung secretory cell            391441
# 2   lung                            pneumocyte            552205
# 3   lung   epithelial cell of alveolus of lung            590956
# 4   lung                        secretory cell            537340
# 5   lung               epithelial cell of lung            725534
# 6   lung                       epithelial cell           1205592
# 7   lung                pancreatic acinar cell              1111
# 8   lung  epithelial cell of exocrine pancreas              1112
# 9   lung                     type I pneumocyte            185900
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        5.750172              87.106808                      73.059803
# 1        5.633969              84.093388                      71.237300
# 2        5.605911              71.922565                      61.811918
# 3        5.521359              70.449407                      59.594031
# 4        5.362744              67.902259                      58.149123
# 5        5.369572              61.015611                      52.884427
# 6        4.843153              46.817995                      39.855731
# 7        4.396355              46.444644                      38.253825
# 8        4.396355              46.402878                      38.219424
# 9        4.963540              41.724583                      39.060785
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2              MUC1, SFTPC      SFTPC-MUC1
# 1                        2              MUC1, SFTPC      SFTPC-MUC1
# 2                        2              MUC1, SFTPC      SFTPC-MUC1
# 3                        2              MUC1, SFTPC      SFTPC-MUC1
# 4                        2              MUC1, SFTPC      SFTPC-MUC1
# 5                        2              MUC1, SFTPC      SFTPC-MUC1
# 6                        2              MUC1, SFTPC      SFTPC-MUC1
# 7                        2              MUC1, SFTPC      SFTPC-MUC1
# 8                        2              MUC1, SFTPC      SFTPC-MUC1
# 9                        2              MUC1, SFTPC      SFTPC-MUC1
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         29.669574        80.083306        1.000000
# 1         28.935632        77.665344        0.945109
# 2         25.165201        66.867241        0.694662
# 3         24.274013        65.021719        0.649194
# 4         23.686888        63.025691        0.604084
# 5         21.582672        56.950019        0.463354
# 6         16.344939        43.336863        0.142387
# 7         15.669838        42.349235        0.115917
# 8         15.656078        42.311151        0.115028
# 9         16.039964        40.392684        0.081904
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/FOXP3_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: FOXP3
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/FOXP3_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#     Tissue                                          Cell Type  \
# 0  kidney  CD4-positive, CD25-positive, alpha-beta regula...
#
#    Total_Cell_Count  POI_Expression  %Cells_Expressing_POI  \
# 0              4216        2.242062              64.136622
#
#    %Cells_Expressing_Interactors  Num_Robust_Interactions  \
# 0                      47.829696                        2
#
#   Contributing_Interactors Prioritized_PPI  Mean_scRNA_score  Mean_Robustness  \
# 0              FOSB, FOXP3      FOXP3-FOSB         19.464364        55.983159
#
#    Priority Score
# 0            0.05
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CACNB4_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: CACNB4
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CACNB4_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#     Tissue                                        Cell Type  Total_Cell_Count  \
# 0     eye                          starburst amacrine cell             17384
# 1     eye                          GABAergic amacrine cell            350906
# 2     eye                                    amacrine cell            594222
# 3  kidney  kidney distal convoluted tubule epithelial cell             31921
# 4  kidney         kidney connecting tubule epithelial cell             20625
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.440478              91.158537                      78.060285
# 1        1.944360              47.138550                      52.379697
# 2        2.056682              49.479656                      48.972943
# 3        2.346652              50.681370                      42.033458
# 4        2.180710              31.660606                      31.619394
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2            CACNB4, CTBP2    CACNB4-CTBP2
# 1                        2            CACNB4, CTBP2    CACNB4-CTBP2
# 2                        2            CACNB4, CTBP2    CACNB4-CTBP2
# 3                        2            CACNB4, CTBP2    CACNB4-CTBP2
# 4                        2            CACNB4, CTBP2    CACNB4-CTBP2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         31.622135        84.609411        1.000000
# 1         21.255635        49.759124        0.390576
# 2         19.909727        49.226299        0.371359
# 3         17.223422        46.357414        0.305910
# 4         13.019831        31.640000        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TTR_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: TTR
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TTR_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue                        Cell Type  Total_Cell_Count  POI_Expression  \
# 0  liver       midzonal region hepatocyte             19814        3.375277
# 1  liver     periportal region hepatocyte             80524        2.943111
# 2  liver                       hepatocyte            253716        2.885486
# 3  liver  centrilobular region hepatocyte             46319        3.186724
# 4  liver                  epithelial cell            374588        2.828624
#
#    %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0              75.270011                      69.435752
# 1              55.348716                      52.781158
# 2              55.810828                      52.018990
# 3              50.417755                      47.534489
# 4              44.145568                      39.510742
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2                ATF5, TTR        TTR-ATF5
# 1                        2                ATF5, TTR        TTR-ATF5
# 2                        2                ATF5, TTR        TTR-ATF5
# 3                        2                ATF5, TTR        TTR-ATF5
# 4                        2                ATF5, TTR        TTR-ATF5
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         28.139980        72.352882        1.000000
# 1         21.446861        54.064937        0.438072
# 2         21.125242        53.914909        0.429679
# 3         19.358480        48.976122        0.278505
# 4         16.117049        41.828155        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/SMAD1_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: SMAD1
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/SMAD1_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#       Tissue                          Cell Type  Total_Cell_Count  \
# 0     liver             endothelial stalk cell              4224
# 1  placenta       endothelial cell of placenta             24814
# 2     liver      blood vessel endothelial cell             15712
# 3     liver           squamous epithelial cell             15895
# 4     liver  endothelial cell of vascular tree             16596
# 5  placenta                   endothelial cell             33512
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        1.613439              40.601326                      65.790720
# 1        1.928114              50.628677                      43.507697
# 2        1.839766              37.856415                      46.467668
# 3        1.840010              37.439446                      45.960994
# 4        1.847749              36.255724                      44.848156
# 5        1.936299              45.204703                      38.435486
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2            SMAD1, SMURF2    SMAD1-SMURF2
# 1                        2            SMAD1, SMURF2    SMAD1-SMURF2
# 2                        2            SMAD1, SMURF2    SMAD1-SMURF2
# 3                        2            SMAD1, SMURF2    SMAD1-SMURF2
# 4                        2            SMAD1, SMURF2    SMAD1-SMURF2
# 5                        2            SMAD1, SMURF2    SMAD1-SMURF2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         26.525417        53.196023        1.000000
# 1         17.678250        47.068187        0.397524
# 2         18.831858        42.162042        0.164822
# 3         18.629300        41.700220        0.133487
# 4         18.188441        40.551940        0.057477
# 5         15.659081        41.820094        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TUFM_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: TUFM
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/TUFM_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#          Tissue                        Cell Type  Total_Cell_Count  \
# 0  bone marrow          basophilic erythroblast              5253
# 1  bone marrow        erythroid progenitor cell             24451
# 2    intestine                     Schwann cell              2612
# 3  bone marrow        common myeloid progenitor             12587
# 4  bone marrow              large pre-B-II cell              3488
# 5        brain           eye photoreceptor cell              1797
# 6    intestine                       glial cell              3034
# 7  bone marrow  pre-conventional dendritic cell              3704
# 8  bone marrow                       osteoclast              1238
# 9        brain                hypothalamus cell              1282
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        1.929022              70.588235                      60.346469
# 1        2.035837              77.187027                      54.179788
# 2        1.786318              65.658499                      53.349923
# 3        2.020327              66.687853                      48.633511
# 4        1.894873              55.131881                      51.390482
# 5        1.978754              48.692265                      54.924875
# 6        1.793314              57.020435                      46.786421
# 7        1.862057              53.671706                      46.287797
# 8        1.777964              55.008078                      44.830372
# 9        1.911365              40.717629                      50.546022
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 1                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 2                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 3                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 4                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 5                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 6                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 7                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 8                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
# 9                        2            ARL6IP1, TUFM    TUFM-ARL6IP1
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         24.466176        65.467352        1.000000
# 1         21.996700        65.683408        0.972730
# 2         21.556985        59.504211        0.821182
# 3         19.805952        57.660682        0.754737
# 4         20.926156        53.261181        0.665623
# 5         22.257833        51.808570        0.648807
# 6         18.934638        51.903428        0.607487
# 7         18.832265        49.979752        0.560760
# 8         18.206301        49.919225        0.551128
# 9         20.499007        45.631825        0.480027
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CDKN1A_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: CDKN1A
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CDKN1A_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#             Tissue                                          Cell Type  \
# 0   adrenal gland                    CD4-positive, alpha-beta T cell
# 1          kidney   activated CD4-positive, alpha-beta T cell, human
# 2           blood                                      megakaryocyte
# 3  prostate gland               CD1c-positive myeloid dendritic cell
# 4  prostate gland                             myeloid dendritic cell
# 5   bladder organ                            bladder urothelial cell
# 6   bladder organ                                    epithelial cell
# 7  prostate gland                                     dendritic cell
# 8         stomach                                           monocyte
# 9  prostate gland  fibroblast of connective tissue of nonglandula...
#
#    Total_Cell_Count  POI_Expression  %Cells_Expressing_POI  \
# 0              1418        1.850276              39.351199
# 1              7465        2.347333              42.612190
# 2             13528        2.556910              55.492312
# 3              3597        2.024432              53.489019
# 4              3781        2.018671              53.160540
# 5             27240        1.925837              64.038179
# 6             28620        1.954694              63.871419
# 7              6833        2.053914              53.153812
# 8              1233        2.058704              57.988646
# 9              3825        2.105209              56.915033
#
#    %Cells_Expressing_Interactors  Num_Robust_Interactions  \
# 0                      48.871650                        3
# 1                      45.018977                        3
# 2                      64.588261                        2
# 3                      63.691966                        2
# 4                      63.647183                        2
# 5                      55.657122                        2
# 6                      54.612159                        2
# 7                      60.844431                        2
# 8                      54.987835                        2
# 9                      52.562092                        2
#
#   Contributing_Interactors           Prioritized_PPI  Mean_scRNA_score  \
# 0       CCND3, CDKN1A, REL  CDKN1A-CCND3, CDKN1A-REL         19.691100
# 1       CCND3, CDKN1A, REL  CDKN1A-CCND3, CDKN1A-REL         18.396138
# 2            CCND3, CDKN1A              CDKN1A-CCND3         26.338143
# 3              CDKN1A, REL                CDKN1A-REL         25.794831
# 4              CDKN1A, REL                CDKN1A-REL         25.777757
# 5              CDKN1A, REL                CDKN1A-REL         22.440905
# 6              CDKN1A, REL                CDKN1A-REL         22.028303
# 7              CDKN1A, REL                CDKN1A-REL         24.655690
# 8              CDKN1A, REL                CDKN1A-REL         22.235821
# 9              CDKN1A, REL                CDKN1A-REL         21.324242
#
#    Mean_Robustness  Priority Score
# 0        44.111425        0.493256
# 1        43.815584        0.466114
# 2        60.040287        1.000000
# 3        58.590492        0.953172
# 4        58.403861        0.947929
# 5        59.847651        0.936967
# 6        59.241789        0.914642
# 7        56.999122        0.893709
# 8        56.488240        0.844111
# 9        54.738562        0.783796
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/NEUROD1_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: NEUROD1
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/NEUROD1_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#              Tissue                                  Cell Type  \
# 0            brain  neuron associated cell (sensu Vertebrata)
# 1            brain                        neuronal brush cell
# 2  endocrine gland     neuro-medullary thymic epithelial cell
# 3  small intestine            intestinal enteroendocrine cell
# 4  small intestine    enteroendocrine cell of small intestine
# 5           embryo           peripheral nervous system neuron
#
#    Total_Cell_Count  POI_Expression  %Cells_Expressing_POI  \
# 0             30577        2.662529              50.521634
# 1             10918        2.713600              43.258839
# 2              1724        2.579993              80.104408
# 3              1246        2.129173              39.406100
# 4              1208        2.116984              38.327815
# 5              2688        2.202879              48.511905
#
#    %Cells_Expressing_Interactors  Num_Robust_Interactions  \
# 0                      68.265908                        3
# 1                      48.146791                        3
# 2                      82.250580                        2
# 3                      49.357945                        2
# 4                      49.751656                        2
# 5                      40.066964                        2
#
#   Contributing_Interactors              Prioritized_PPI  Mean_scRNA_score  \
# 0     NEUROD1, TCF12, TCF4  NEUROD1-TCF12, NEUROD1-TCF4         27.840767
# 1     NEUROD1, TCF12, TCF4  NEUROD1-TCF12, NEUROD1-TCF4         19.778233
# 2            NEUROD1, TCF4                 NEUROD1-TCF4         33.350609
# 3           NEUROD1, TCF12                NEUROD1-TCF12         20.067797
# 4           NEUROD1, TCF12                NEUROD1-TCF12         20.223658
# 5            NEUROD1, TCF4                 NEUROD1-TCF4         16.159239
#
#    Mean_Robustness  Priority Score
# 0        59.393771        0.505388
# 1        45.702815        0.133681
# 2        81.177494        1.000000
# 3        44.382022        0.096315
# 4        44.039735        0.091084
# 5        44.289435        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/MID1_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: MID1
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/MID1_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#             Tissue                             Cell Type  Total_Cell_Count  \
# 0             eye  endothelial cell of lymphatic vessel              1030
# 1  adipose tissue      fibro/adipogenic progenitor cell             15985
# 2       esophagus  endothelial cell of lymphatic vessel              1108
# 3          embryo                        epidermal cell              1212
# 4             eye                    H1 horizontal cell             58223
# 5  adipose tissue                subcutaneous adipocyte             12205
# 6             eye                retina horizontal cell             86242
# 7  adipose tissue                             adipocyte             72587
# 8  adipose tissue           adipocyte of omentum tissue             15436
# 9          embryo          intermediate mesodermal cell              3918
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.022608              34.174757                      40.938511
# 1        2.112774              31.223022                      42.066521
# 2        2.435517              31.949458                      35.649819
# 3        3.084887              79.537954                      60.849835
# 4        2.305397              74.654346                      55.875685
# 5        1.958576              44.022941                      68.451454
# 6        2.285487              63.284710                      50.364092
# 7        2.076700              42.059873                      63.939135
# 8        2.075437              42.323141                      62.765613
# 9        2.343947              53.598775                      51.097499
#
#    Num_Robust_Interactions Contributing_Interactors         Prioritized_PPI  \
# 0                        3       EPN2, MID1, UBE2E2  MID1-EPN2, MID1-UBE2E2
# 1                        3       EPN2, MID1, UBE2E2  MID1-EPN2, MID1-UBE2E2
# 2                        3       EPN2, MID1, UBE2E2  MID1-EPN2, MID1-UBE2E2
# 3                        2             MID1, UBE2E2             MID1-UBE2E2
# 4                        2             MID1, UBE2E2             MID1-UBE2E2
# 5                        2             MID1, UBE2E2             MID1-UBE2E2
# 6                        2             MID1, UBE2E2             MID1-UBE2E2
# 7                        2             MID1, UBE2E2             MID1-UBE2E2
# 8                        2             MID1, UBE2E2             MID1-UBE2E2
# 9                        2             MID1, UBE2E2             MID1-UBE2E2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         16.743955        37.556634        0.183586
# 1         17.149073        36.644771        0.168175
# 2         14.629435        33.799639        0.072925
# 3         24.688774        70.193894        1.000000
# 4         22.730062        65.265016        0.864986
# 5         27.741054        56.237198        0.724881
# 6         20.529252        56.824401        0.648155
# 7         25.957561        52.999504        0.629999
# 8         25.479510        52.544377        0.613827
# 9         20.687736        52.348137        0.549690
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/SMAD3_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: SMAD3
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/SMAD3_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#             Tissue                         Cell Type  Total_Cell_Count  \
# 0          embryo                    epidermal cell              1212
# 1          embryo        splanchnic mesodermal cell              6018
# 2  adipose tissue  fibro/adipogenic progenitor cell             15985
# 3          embryo                        fibroblast              1363
# 4          embryo           lateral mesodermal cell             10989
# 5          embryo      intermediate mesodermal cell              3918
# 6          embryo                   mesodermal cell             17289
# 7  adipose tissue                   progenitor cell             22033
# 8  adipose tissue                    precursor cell             51326
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.507158              59.900990                      45.915842
# 1        2.633781              46.510469                      50.224327
# 2        2.075717              47.782296                      45.289334
# 3        2.651082              44.607483                      40.645635
# 4        2.559009              41.659842                      41.127491
# 5        2.213324              44.129658                      38.042369
# 6        2.461465              41.072358                      38.385679
# 7        2.050725              40.348568                      38.501339
# 8        2.026420              38.343140                      35.524880
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 1                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 2                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 3                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 4                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 5                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 6                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 7                        2            SMAD3, SMURF2    SMAD3-SMURF2
# 8                        2            SMAD3, SMURF2    SMAD3-SMURF2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         18.654506        52.908416        1.000000
# 1         20.493525        48.367398        0.816647
# 2         18.529820        46.535815        0.664387
# 3         16.617869        42.626559        0.405381
# 4         16.822412        41.393666        0.347069
# 5         15.448621        41.086013        0.291278
# 6         15.688216        39.729018        0.227515
# 7         15.794584        39.424953        0.214753
# 8         14.586104        36.934010        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/OPTN_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: OPTN
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/OPTN_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#     Tissue       Cell Type  Total_Cell_Count  POI_Expression  \
# 0  testis       spermatid              4009        1.793493
# 1  testis    spermatocyte              3070        1.699915
# 2  testis  male germ cell              7259        1.755087
#
#    %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0              47.493140                      48.578199
# 1              42.312704                      49.983713
# 2              44.220967                      48.085136
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2             OPTN, WASHC3     OPTN-WASHC3
# 1                        2             OPTN, WASHC3     OPTN-WASHC3
# 2                        2             OPTN, WASHC3     OPTN-WASHC3
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         19.551796        48.035670        1.000000
# 1         20.098445        46.148208        0.246133
# 2         19.348043        46.153051        0.050000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/MYOZ2_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: MYOZ2
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/MYOZ2_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue                Cell Type  Total_Cell_Count  POI_Expression  \
# 0  heart  cardiac muscle myoblast             66162        2.223306
# 1  heart                 myoblast             69045        2.220762
# 2  heart           precursor cell             82166        2.218487
#
#    %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0              82.502040                      58.965116
# 1              79.917445                      57.752191
# 2              68.813134                      50.739357
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2             ACTN4, MYOZ2     MYOZ2-ACTN4
# 1                        2             ACTN4, MYOZ2     MYOZ2-ACTN4
# 2                        2             ACTN4, MYOZ2     MYOZ2-ACTN4
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         23.856328        70.733578         1.00000
# 1         23.373360        68.834818         0.83894
# 2         20.571352        59.776246         0.05000
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PMP22_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: PMP22
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PMP22_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#              Tissue                                          Cell Type  \
# 0  small intestine               endothelial cell of lymphatic vessel
# 1   fallopian tube                  endothelial cell of vascular tree
# 2   fallopian tube                      blood vessel endothelial cell
# 3   prostate gland      prostate gland microvascular endothelial cell
# 4             lung  endothelial cell of respiratory system lymphat...
# 5           breast                           vascular lymphangioblast
# 6   prostate gland                  endothelial cell of vascular tree
# 7   prostate gland                                   endothelial cell
# 8   adipose tissue                                         macrophage
# 9           uterus                                   endothelial cell
#
#    Total_Cell_Count  POI_Expression  %Cells_Expressing_POI  \
# 0              3060        2.099632              42.287582
# 1             10868        1.904773              35.590725
# 2              4570        1.978114              43.632385
# 3             11768        2.024283              42.717539
# 4              1497        1.971434              33.800935
# 5              8794        1.987107              34.671367
# 6             14231        2.033474              37.769658
# 7             15459        2.024251              35.985510
# 8             55294        2.027488              34.750606
# 9             17031        2.098152              31.765604
#
#    %Cells_Expressing_Interactors  Num_Robust_Interactions  \
# 0                      58.415033                        2
# 1                      52.346338                        2
# 2                      45.700219                        2
# 3                      44.412814                        2
# 4                      50.467602                        2
# 5                      45.042074                        2
# 6                      41.718783                        2
# 7                      40.361602                        2
# 8                      39.346945                        2
# 9                      40.144442                        2
#
#   Contributing_Interactors Prioritized_PPI  Mean_scRNA_score  Mean_Robustness  \
# 0             CLDN5, PMP22     PMP22-CLDN5         23.735739        50.351307
# 1             CLDN5, PMP22     PMP22-CLDN5         21.233632        43.968531
# 2             CLDN5, PMP22     PMP22-CLDN5         18.533197        44.666302
# 3             CLDN5, PMP22     PMP22-CLDN5         18.071803        43.565177
# 4             CLDN5, PMP22     PMP22-CLDN5         20.588263        42.134269
# 5             CLDN5, PMP22     PMP22-CLDN5         18.377321        39.856720
# 6             CLDN5, PMP22     PMP22-CLDN5         17.006700        39.744220
# 7             CLDN5, PMP22     PMP22-CLDN5         16.461497        38.173556
# 8               EDA, PMP22       PMP22-EDA         16.056245        37.048776
# 9             CLDN5, PMP22     PMP22-CLDN5         16.386647        35.955023
#
#    Priority Score
# 0        1.000000
# 1        0.685414
# 2        0.652936
# 3        0.597996
# 4        0.596666
# 5        0.454775
# 6        0.419404
# 7        0.343577
# 8        0.288942
# 9        0.252104
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CUL3_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: CUL3
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CUL3_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue    Cell Type  Total_Cell_Count  POI_Expression  \
# 0  blood   neutrophil             36783        1.916656
# 1  blood  granulocyte             38067        1.916823
#
#    %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0              39.833619                      35.517766
# 1              38.800011                      34.600835
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2             CUL3, SHKBP1     CUL3-SHKBP1
# 1                        2             CUL3, SHKBP1     CUL3-SHKBP1
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         14.536503        37.675693            1.00
# 1         14.169936        36.700423            0.05
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CHN1_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: CHN1
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/CHN1_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue                                          Cell Type  Total_Cell_Count  \
# 0  brain  L5/6 near-projecting glutamatergic neuron of t...              1215
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0         2.41158              97.860082                      64.279835
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2               CHN1, NCK2       CHN1-NCK2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         26.087276        81.069959            0.05
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/MSRB3_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: MSRB3
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/MSRB3_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#             Tissue                               Cell Type  Total_Cell_Count  \
# 0           liver         blood vessel smooth muscle cell              2622
# 1           heart                  smooth muscle myoblast              2883
# 2  adipose tissue                      smooth muscle cell              7560
# 3             eye    endothelial cell of lymphatic vessel              1030
# 4           brain  vascular associated smooth muscle cell              2157
# 5           brain                      smooth muscle cell              4189
# 6  adipose tissue    endothelial cell of lymphatic vessel              6146
# 7            lung           secondary crest myofibroblast              4701
# 8             eye                  diffuse bipolar 4 cell             44875
# 9           heart          mesothelial cell of epicardium              4332
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.168878              77.917620                      63.062548
# 1        2.295005              62.192161                      49.947971
# 2        2.281407              64.285714                      47.347884
# 3        2.176077              59.029126                      47.718447
# 4        2.307649              51.784886                      45.850719
# 5        2.272433              49.606111                      43.960372
# 6        2.097221              49.072568                      41.563619
# 7        2.253015              39.225697                      37.991917
# 8        1.880732              40.000000                      37.267967
# 9        1.956246              39.312096                      35.283934
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 1                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 2                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 3                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 4                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 5                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 6                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 7                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 8                        2             CTBP2, MSRB3     MSRB3-CTBP2
# 9                        2             CTBP2, MSRB3     MSRB3-CTBP2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         25.542838        70.490084        1.000000
# 1         20.325427        56.070066        0.645347
# 2         19.299334        55.816799        0.628487
# 3         19.440473        53.373786        0.580064
# 4         18.776359        48.817803        0.479210
# 5         18.022813        46.783242        0.428973
# ...
# 0              42.164782                      37.964459
# 1              32.917279                      36.566936
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2              MAGED1, TFG      TFG-MAGED1
# 1                        2              MAGED1, TFG      TFG-MAGED1
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         15.487732        40.064620            1.00
# 1         14.788661        34.742107            0.05
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PITX1_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: PITX1
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PITX1_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#             Tissue                     Cell Type  Total_Cell_Count  \
# 0       esophagus    stratified epithelial cell             48057
# 1       esophagus  epithelial cell of esophagus             19305
# 2       esophagus               epithelial cell            109100
# 3       esophagus          endo-epithelial cell             24068
# 4           colon            myofibroblast cell              4798
# 5  exocrine gland                    basal cell             11143
# 6  exocrine gland                     stem cell             11144
# 7           colon              mesenchymal cell              7417
# 8       esophagus                    basal cell              4536
# 9       intestine                    basal cell              4700
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.014034              71.818882                      67.323526
# 1        1.973039              72.732453                      63.855651
# 2        1.997782              59.810266                      57.972808
# 3        1.970643              58.862390                      56.609052
# 4        2.320146              61.650688                      69.841601
# 5        2.217798              61.401777                      64.493404
# 6        2.217798              61.396267                      64.487617
# 7        2.055018              46.487798                      68.659836
# 8        1.836531              44.863316                      66.358025
# 9        2.014301              36.297872                      67.095745
#
#    Num_Robust_Interactions Contributing_Interactors  \
# 0                        3     CYSRT1, PFDN5, PITX1
# 1                        3     CYSRT1, PFDN5, PITX1
# 2                        3     CYSRT1, PFDN5, PITX1
# 3                        3     CYSRT1, PFDN5, PITX1
# 4                        2             PFDN5, PITX1
# 5                        2             PFDN5, PITX1
# 6                        2             PFDN5, PITX1
# 7                        2             PFDN5, PITX1
# 8                        2             PFDN5, PITX1
# 9                        2             PFDN5, PITX1
#
#              Prioritized_PPI  Mean_scRNA_score  Mean_Robustness  \
# 0  PITX1-CYSRT1, PITX1-PFDN5         27.204452        69.571204
# 1  PITX1-CYSRT1, PITX1-PFDN5         25.829410        68.294052
# 2  PITX1-CYSRT1, PITX1-PFDN5         23.488045        58.891537
# 3  PITX1-CYSRT1, PITX1-PFDN5         22.928590        57.735721
# 4                PITX1-PFDN5         28.295428        65.746144
# 5                PITX1-PFDN5         26.089537        62.947590
# 6                PITX1-PFDN5         26.087223        62.941942
# 7                PITX1-PFDN5         27.793549        57.573817
# 8                PITX1-PFDN5         26.802530        55.610670
# 9                PITX1-PFDN5         27.125955        51.696809
#
#    Priority Score
# 0        1.000000
# 1        0.946663
# 2        0.666967
# 3        0.628641
# 4        0.898461
# 5        0.793306
# 6        0.793124
# 7        0.677617
# 8        0.611929
# 9        0.514348
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/EMD_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: EMD
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/EMD_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#            Tissue                                          Cell Type  \
# 0  adrenal gland    effector memory CD8-positive, alpha-beta T cell
# 1  adrenal gland                                      memory T cell
# 2  adrenal gland                    CD8-positive, alpha-beta T cell
# 3  adrenal gland                           mature alpha-beta T cell
# 4  adrenal gland                                      mature T cell
# 5  adrenal gland                                             T cell
# 6  adrenal gland                    CD4-positive, alpha-beta T cell
# 7  adrenal gland                                         lymphocyte
# 8         kidney   activated CD4-positive, alpha-beta T cell, human
# 9         kidney  naive thymus-derived CD8-positive, alpha-beta ...
#
#    Total_Cell_Count  POI_Expression  %Cells_Expressing_POI  \
# 0              1069        1.657950              53.320861
# 1              1101        1.655295              52.770209
# 2              4761        1.625448              46.544844
# 3              7092        1.631731              46.291596
# 4              7110        1.631731              46.174402
# 5              9720        1.650395              38.888889
# 6              1418        1.594259              40.479549
# 7             11091        1.653837              36.804616
# 8              7465        2.002082              37.977227
# 9             22369        1.984974              32.719388
#
#    %Cells_Expressing_Interactors  Num_Robust_Interactions  \
# 0                      46.328344                        4
# 1                      46.253406                        4
# 2                      43.063432                        4
# 3                      41.465736                        4
# 4                      41.381857                        4
# 5                      40.613855                        3
# 6                      38.410907                        3
# 7                      38.683016                        3
# 8                      36.798392                        3
# 9                      40.423503                        3
#
#     Contributing_Interactors                   Prioritized_PPI  \
# 0  EMD, LIME1, REL, TRAF3IP3  EMD-LIME1, EMD-REL, EMD-TRAF3IP3
# 1  EMD, LIME1, REL, TRAF3IP3  EMD-LIME1, EMD-REL, EMD-TRAF3IP3
# 2  EMD, LIME1, REL, TRAF3IP3  EMD-LIME1, EMD-REL, EMD-TRAF3IP3
# 3  EMD, LIME1, REL, TRAF3IP3  EMD-LIME1, EMD-REL, EMD-TRAF3IP3
# 4  EMD, LIME1, REL, TRAF3IP3  EMD-LIME1, EMD-REL, EMD-TRAF3IP3
# 5         EMD, REL, TRAF3IP3             EMD-REL, EMD-TRAF3IP3
# 6         EMD, REL, TRAF3IP3             EMD-REL, EMD-TRAF3IP3
# 7         EMD, REL, TRAF3IP3             EMD-REL, EMD-TRAF3IP3
# 8         EMD, REL, TRAF3IP3             EMD-REL, EMD-TRAF3IP3
# 9       BANF1, EMD, TRAF3IP3           EMD-BANF1, EMD-TRAF3IP3
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         18.603500        49.824602        1.000000
# 1         18.573775        49.511807        0.985043
# 2         17.295143        44.804138        0.738966
# 3         16.656523        43.878666        0.680819
# 4         16.623023        43.778129        0.675407
# 5         16.331613        39.751372        0.454887
# 6         15.431407        39.445228        0.418268
# 7         15.560479        37.743816        0.344249
# 8         15.008827        37.387810        0.314161
# 9         16.456284        36.571446        0.313605
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/GRN_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: GRN
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/GRN_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#              Tissue                             Cell Type  Total_Cell_Count  \
# 0       lymph node  endothelial cell of lymphatic vessel              4847
# 1       lymph node     endothelial cell of vascular tree              5638
# 2        esophagus          epithelial cell of esophagus             19305
# 3       lymph node                      endothelial cell              6233
# 4  small intestine                         M cell of gut              6441
# 5          stomach                 mononuclear phagocyte              9073
# 6   exocrine gland  professional antigen presenting cell              4553
# 7    bladder organ                            macrophage              3188
# 8    bladder organ  professional antigen presenting cell              3221
# 9   exocrine gland                 mononuclear phagocyte              4979
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        2.031684              67.464411                      55.508562
# 1        2.074189              63.887904                      52.358993
# 2        1.945027              60.890961                      53.488733
# 3        2.062353              61.671747                      50.240655
# 4        1.913277              61.201677                      50.031051
# 5        1.964847              56.750799                      47.514604
# 6        2.222183              59.455304                      45.343729
# 7        1.919450              52.540778                      49.937265
# 8        1.926099              52.561316                      49.736107
# 9        2.224336              58.646315                      44.577224
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2              GRN, TSPAN4      GRN-TSPAN4
# 1                        2              GRN, TSPAN4      GRN-TSPAN4
# 2                        2              CYSRT1, GRN      GRN-CYSRT1
# 3                        2              GRN, TSPAN4      GRN-TSPAN4
# 4                        2               CXCL5, GRN       GRN-CXCL5
# 5                        2              GRN, NUFIP2      GRN-NUFIP2
# 6                        2              GRN, NUFIP2      GRN-NUFIP2
# 7                        2              GRN, NUFIP2      GRN-NUFIP2
# 8                        2              GRN, NUFIP2      GRN-NUFIP2
# 9                        2              GRN, NUFIP2      GRN-NUFIP2
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         22.421879        61.486486        1.000000
# 1         21.169713        58.123448        0.889724
# 2         21.671278        57.189847        0.871929
# 3         20.320234        55.956201        0.818017
# 4         20.291429        55.616364        0.808348
# 5         19.206781        52.132701        0.697324
# 6         18.395983        52.399517        0.692334
# 7         20.062857        51.239021        0.685964
# 8         19.982753        51.148712        0.682301
# 9         18.091220        51.611769        0.666331
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/KRT4_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: KRT4
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/KRT4_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#        Tissue                        Cell Type  Total_Cell_Count  \
# 0  esophagus     epithelial cell of esophagus             19305
# 1  esophagus       stratified epithelial cell             48057
# 2  esophagus                  epithelial cell            109100
# 3  esophagus             endo-epithelial cell             24068
# 4  esophagus                       basal cell              4536
# 5        eye     conjunctival epithelial cell             14681
# 6  esophagus                        stem cell              5316
# 7  esophagus                   precursor cell              5524
# 8  esophagus  CD4-positive, alpha-beta T cell              1108
# 9  esophagus         mature alpha-beta T cell              2051
#
#    POI_Expression  %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0        4.053944              84.801865                      51.812138
# 1        4.013225              76.717232                      55.886413
# 2        3.735560              67.654445                      51.081577
# 3        3.993733              69.906099                      50.492355
# 4        2.558176              44.775132                      53.626543
# 5        2.359026              47.510388                      46.117431
# 6        2.539609              39.127163                      46.237773
# 7        2.536867              37.925416                      44.686821
# 8        2.551203              40.072202                      39.846570
# 9        2.550155              37.347635                      34.592882
#
#    Num_Robust_Interactions Contributing_Interactors         Prioritized_PPI  \
# 0                        3       KRT15, KRT16, KRT4  KRT4-KRT15, KRT4-KRT16
# 1                        3       KRT15, KRT16, KRT4  KRT4-KRT15, KRT4-KRT16
# 2                        3       KRT15, KRT16, KRT4  KRT4-KRT15, KRT4-KRT16
# 3                        2              KRT15, KRT4              KRT4-KRT15
# 4                        2              KRT15, KRT4              KRT4-KRT15
# 5                        2              KRT15, KRT4              KRT4-KRT15
# 6                        2              KRT15, KRT4              KRT4-KRT15
# 7                        2              KRT15, KRT4              KRT4-KRT15
# 8                        2              KRT16, KRT4              KRT4-KRT16
# 9                        2              KRT16, KRT4              KRT4-KRT16
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         21.087699        68.307002        1.000000
# 1         22.697928        66.301822        0.972096
# 2         20.768584        59.368011        0.770952
# 3         20.605429        60.199227        0.772809
# 4         21.739436        49.200838        0.512302
# 5         18.797444        46.813909        0.411264
# 6         18.782435        42.682468        0.307252
# 7         18.161694        41.306119        0.264006
# 8         16.138216        39.959386        0.201925
# 9         14.033217        35.970258        0.072315
#
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PLN_PPI_filtered_S1_H1_17042025.xlsx
# 🧬 Identified Protein of Interest: PLN
# ✅ Successfully saved prioritized clusters: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/PLN_PPI_filtered_Ranked_Priority_Final_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters:
#    Tissue                       Cell Type  Total_Cell_Count  POI_Expression  \
# 0  heart  regular atrial cardiac myocyte             53855        2.292965
#
#    %Cells_Expressing_POI  %Cells_Expressing_Interactors  \
# 0              44.918763                      42.448241
#
#    Num_Robust_Interactions Contributing_Interactors Prioritized_PPI  \
# 0                        2                 EDA, PLN         PLN-EDA
#
#    Mean_scRNA_score  Mean_Robustness  Priority Score
# 0         17.277791        43.683502            0.05

# %%
#Manually compute ranked PPI list for LITAF_PPI_filtered_V2_noUBA52_17042025.xlsx 

input_dir = "./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/"

#**Check if LITAF file exists in input directory**
litaf_filename = "LITAF_PPI_filtered_V2_noUBA52_17042025.xlsx"
litaf_path = os.path.join(input_dir, litaf_filename)

#**Check if LITAF file exists**
if not os.path.exists(litaf_path):
    print(f"❌ ERROR: LITAF file not found in {input_dir}!")
    exit()

print(f"\n📂 Processing Priority Ranking for: {litaf_path}")
protein_of_interest = "LITAF"  # Manually set POI

#**Read the dataset**
df = pd.read_excel(litaf_path)

#**Ensure necessary columns exist**
required_columns = {"Tissue", "Cell Type", "Gene Symbol", "%Cells Expressing Gene", "Expression", "Cell Count"}

if not required_columns.issubset(df.columns):
    print(f"❌ ERROR: Missing required columns in {litaf_filename}. Skipping...")
    exit()

#**Step 1: Identify Robust Interactions (≥30% Expression)**
interaction_threshold = 30
df["Robust Interaction"] = df["%Cells Expressing Gene"] >= interaction_threshold

#**Step 2: Extract POI Expression & %Cells Expressing POI BEFORE groupby**
poi_df = df[df["Gene Symbol"] == protein_of_interest][["Tissue", "Cell Type", "Expression", "%Cells Expressing Gene"]]
poi_df.rename(columns={"Expression": "POI_Expression", "%Cells Expressing Gene": "%Cells_Expressing_POI"}, inplace=True)

#**Step 3: Compute Cluster-Level Metrics**
cluster_priority = df.groupby(["Tissue", "Cell Type"]).agg(
    Num_Robust_Interactions=("Gene Symbol", lambda x: df.loc[x.index, "Robust Interaction"].sum()),
    Contributing_Interactors=("Gene Symbol", lambda x: ", ".join(sorted(x[df.loc[x.index, "Robust Interaction"]]))),
    Mean_scRNA_score=("scRNA_score", "mean"),
    Total_Cell_Count=("Cell Count", "max")
).reset_index()

#**Step 4: Extract %Cells Expressing Interactors**
interactors_df = df[df["Robust Interaction"]][["Tissue", "Cell Type", "%Cells Expressing Gene"]]
interactors_avg = interactors_df.groupby(["Tissue", "Cell Type"])["%Cells Expressing Gene"].mean().reset_index()
interactors_avg.rename(columns={"%Cells Expressing Gene": "%Cells_Expressing_Interactors"}, inplace=True)

#**Step 5: Merge POI Expression & %Cells Expressing POI Values**
cluster_priority = cluster_priority.merge(poi_df, on=["Tissue", "Cell Type"], how="left")
cluster_priority = cluster_priority.merge(interactors_avg, on=["Tissue", "Cell Type"], how="left")

#**Step 6: Compute Mean Robustness**
cluster_priority["Mean_Robustness"] = (cluster_priority["%Cells_Expressing_POI"] + cluster_priority["%Cells_Expressing_Interactors"]) / 2

#**Step 7: Ensure valid data remains after processing**
if cluster_priority.empty:
    print(f"⚠️ No valid data remaining for {litaf_filename}. Skipping...")
    exit()

#**Step 8: Compute Priority Score**
W_interactions = 0.3
W_scRNA = 0.25
W_robustness = 0.45

cluster_priority["Priority Score"] = (
    W_interactions * cluster_priority["Num_Robust_Interactions"] +
    W_scRNA * cluster_priority["Mean_scRNA_score"] +
    W_robustness * cluster_priority["Mean_Robustness"]
)

#**Step 9: Apply MinMax Scaling to Priority Score**
scaler = MinMaxScaler(feature_range=(0.05, 1))
cluster_priority["Priority Score"] = scaler.fit_transform(cluster_priority[["Priority Score"]])

#**Step 10: Generate Prioritized PPI pairs**
def generate_ppi_pairs(row, poi):
    """Generates PPI pairs while ensuring no self-interactions."""
    interactors = row["Contributing_Interactors"].split(", ")
    interactors = [partner for partner in interactors if partner != poi]
    return ", ".join([f"{poi}-{partner}" for partner in interactors])

cluster_priority["Prioritized_PPI"] = cluster_priority.apply(lambda row: generate_ppi_pairs(row, protein_of_interest), axis=1)

#**Step 11: Keep output format consistent**
cluster_priority = cluster_priority[[
    "Tissue", "Cell Type", "Total_Cell_Count",
    "POI_Expression", "%Cells_Expressing_POI", "%Cells_Expressing_Interactors",
    "Num_Robust_Interactions", "Contributing_Interactors", "Prioritized_PPI",
    "Mean_scRNA_score", "Mean_Robustness", "Priority Score"
]]

#**Step 12: Sort by Num_Robust_Interactions & Priority Score**
cluster_priority = cluster_priority.sort_values(by=["Num_Robust_Interactions", "Priority Score"], ascending=[False, False]).reset_index(drop=True)

#**Step 13: Save output file with correct naming**
output_file = os.path.join(input_dir, "LITAF_CELLxGENE_gene_expression_Ranked_Priority_Final_V2_noUBA52_17042025.xlsx")
cluster_priority.to_excel(output_file, index=False)

print(f"✅ Successfully saved prioritized clusters for LITAF: {output_file}")

#**Step 14: Display Top ranked Clusters**
print("\n🏆 Top 10 Ranked Clusters for LITAF:\n", cluster_priority.head(10))
# Out:
# 📂 Processing Priority Ranking for: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/LITAF_PPI_filtered_V2_noUBA52_17042025.xlsx
# ✅ Successfully saved prioritized clusters for LITAF: ./results_11032025/Jess_PPI_21032025/PPI_preprocessed_15042025/PPI_contextualization/filtered_Step1_H1/LITAF_CELLxGENE_gene_expression_Ranked_Priority_Final_V2_noUBA52_17042025.xlsx
#
# 🏆 Top 10 Ranked Clusters for LITAF:
#             Tissue                                        Cell Type  \
# 0           heart                                       neutrophil
# 1           heart                                      granulocyte
# 2           heart                                       blood cell
# 3   adrenal gland  effector memory CD8-positive, alpha-beta T cell
# 4   adrenal gland                                    memory T cell
# 5  adipose tissue                             innate lymphoid cell
# 6  adipose tissue                              natural killer cell
# 7           blood         effector CD8-positive, alpha-beta T cell
# 8          spleen                                       neutrophil
# 9  adipose tissue                                       neutrophil
#
#    Total_Cell_Count  POI_Expression  %Cells_Expressing_POI  \
# 0              1120        3.027390              91.071429
# 1              1171        2.996636              89.325363
# 2              1292        2.995289              81.037152
# 3              1069        2.054429              82.226380
# 4              1101        2.050013              81.017257
# 5              1031        2.321415              83.026188
# 6              1022        2.324597              82.974560
# 7             62479        2.213000              72.173050
# 8             15342        3.116583              92.784513
# 9              3456        2.999241              90.856481
#
#    %Cells_Expressing_Interactors  Num_Robust_Interactions  \
# 0                      49.892857                        5
# 1                      49.257045                        5
# 2                      45.603715                        5
# 3                      71.702526                        4
# 4                      71.389646                        4
# 5                      65.009699                        4
# 6                      64.995108                        4
# 7                      68.290946                        4
# 8                      53.928758                        4
# 9                      55.034722                        4
#
#                  Contributing_Interactors  \
# 0  DAZAP2, LITAF, RASSF3, RPS27A, TAX1BP1
# 1  DAZAP2, LITAF, RASSF3, RPS27A, TAX1BP1
# 2  DAZAP2, LITAF, RASSF3, RPS27A, TAX1BP1
# 3          DAZAP2, LITAF, RPS27A, TAX1BP1
# 4          DAZAP2, LITAF, RPS27A, TAX1BP1
# 5           LITAF, NCALD, RPS27A, TAX1BP1
# 6           LITAF, NCALD, RPS27A, TAX1BP1
# 7          DAZAP2, LITAF, RPS27A, TAX1BP1
# 8          DAZAP2, LITAF, RASSF3, TAX1BP1
# 9          DAZAP2, LITAF, RASSF3, TAX1BP1
#
#                                      Prioritized_PPI  Mean_scRNA_score  \
# 0  LITAF-DAZAP2, LITAF-RASSF3, LITAF-RPS27A, LITA...         20.191998
# 1  LITAF-DAZAP2, LITAF-RASSF3, LITAF-RPS27A, LITA...         19.939630
# 2  LITAF-DAZAP2, LITAF-RASSF3, LITAF-RPS27A, LITA...         18.477781
# 3          LITAF-DAZAP2, LITAF-RPS27A, LITAF-TAX1BP1         28.837331
# 4          LITAF-DAZAP2, LITAF-RPS27A, LITAF-TAX1BP1         28.712074
# 5           LITAF-NCALD, LITAF-RPS27A, LITAF-TAX1BP1         26.198306
# 6           LITAF-NCALD, LITAF-RPS27A, LITAF-TAX1BP1         26.192383
# 7          LITAF-DAZAP2, LITAF-RPS27A, LITAF-TAX1BP1         27.598548
# 8          LITAF-DAZAP2, LITAF-RASSF3, LITAF-TAX1BP1         21.755954
# 9          LITAF-DAZAP2, LITAF-RASSF3, LITAF-TAX1BP1         22.187891
#
#    Mean_Robustness  Priority Score
# 0        70.482143        0.719610
# 1        69.291204        0.699661
# 2        63.320433        0.598011
# 3        76.964453        0.878743
# 4        76.203451        0.866296
# 5        74.017944        0.812614
# 6        73.984834        0.812069
# 7        70.231998        0.767535
# 8        73.356635        0.765718
# 9        72.945602        0.763154

# %% [markdown]
# Each {POI}_filtered_Ranked_Priority_Final_17042025.xlsx has the following structure
#
# | Column Name                     | Description                                                                 |
# |--------------------------------|-----------------------------------------------------------------------------|
# | Tissue                         | Name of the tissue where the cluster was identified in CZ Cell*Gene                         |
# | Cell Type                      | Specific cell type/state within the tissue                                       |
# | Total_Cell_Count               | Total number of cells profiled in that tissue–cell type combination        |
# | POI_Expression                 | Average normalized expression level of the protein of interest (POI) in this cluster  |
# | %Cells_Expressing_POI         | Percentage of cells in the cluster expressing the POI                      |
# | %Cells_Expressing_Interactors | Average percentage of cells expressing the interactors in the cluster      |
# | Num_Robust_Interactions        | Number of interactors co-expressed with ≥30% expression cut-off in the cluster     |
# | Contributing_Interactors       | List of interactors contributing to robust co-expression with the POI      |
# | Prioritized_PPI                | Formatted PPI pairs (POI–Interactor) prioritized for each cluster          |
# | Mean_scRNA_score               | Average scRNA-based functional score for all genes in the cluster          |
# | Mean_Robustness                | Mean of `%Cells_Expressing_POI` & `%Cells_Expressing_Interactors`        |
# | Priority Score                 | Final scaled score combining robustness, interactions, and expression (not necessary to use)      |
